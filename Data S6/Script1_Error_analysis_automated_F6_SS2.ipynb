# %%
import numpy as np
from scipy import linalg # had to update the scipy to 1.1 instead of 1.01 
# from sympy import Matrix
from scipy import sparse
import pandas as pd

# %%
# def read_sheet(pathtofile,sheetname):
#     data = pd.DataFrame(pathtofile,sheet_name =sheetname)

# %%
def find_h(reactor,timepoint,val_ls):
    print("Reactor: ",reactor)
    print("Time point: ", timepoint)
    
    # initialize list that will be used for the results of all the h's
    h_ls = [] # h, hco2, hh2, hbio, hch4
    
    # ------------------------------------------------
    # Assumptions
    # STEADY STATE
    # Two degrees of freedom... don't measure NH3 or H20 so make matrix to two rows
    error= 0.1 # assumed 10% measurement error
    X2 = 5.99 # chi-squared for 2 degrees of freedom at 95% confidence interval
    I = np.identity(2) # 2 degress of freedom for the identity matrix
    
    # Rows of "A" are C, H, O, N
    # Columns of "A" are CO2, H2, NH3, Biomass, H2O, CH4

    # stochiometric coefficients
    A = np.array([[-1,0,1,1], [2,-1,0.0265,2]])

    # ---------------------------------------------------------------------------------
    co2 = val_ls[0]
    h2 = val_ls[1]
    bio = val_ls[2]
    ch4 = val_ls[3]
       
    # measured variables
    x = np.array([[co2, h2, bio,ch4]]).T
#     print("A: ",A)
#     print("x: ",x)
    
    # vector of residuals
    E = -A.dot(x)
#     print("E: ",E)
    # variance-covariance matrix 
    
    # assume measurement error is independent and uncorrelated
    Y = np.array([[(co2*error)**2,0,0,0], [0,(h2*error)**2,0,0],[0,0,(bio*error)**2,0], [0,0,0,(ch4*error)**2]])
#     print("Y: ",Y)
    
    # net rate of input of components into system
    O = (A.dot(Y)).dot(A.T)
#     print("O: ",O)
    
    # inverse of net rate of input of components into system
    Oin = np.linalg.inv(O)
#     print("Oin: ", Oin)
    
    # test function
    h = (E.T.dot(Oin)).dot(E)
    hactual = h[0][0]
    h_ls.append(hactual)
#     print("h: ",hactual)
    
    # measurement error
    d = ((Y.dot(A.T)).dot(Oin)).dot(E)
#     print("d: ",d)
    
    # true values
    xt = x + d
#     print("xt: ",xt)

    # stop here if the hypothesis is passed ((chi_squared for 2 degrees of freedom) > htest)
    if hactual > X2:
        print("The test failed with an h value of: ", round(hactual,3))
        # and continue
    else:
        print("The test passed with an h value of: ", round(hactual,3))
    
    #--------------------------------------------------------------------------
    # Start finding the hs for the individual measurments
    
    # dictionary with which measurments to delete
    measure_list = ["co2","h2","bio","ch4"]
    
    # new product vectors without various conditions
    # CO2
    xuco2 = np.array([[h2, bio,ch4]]).T
    xcco2 = np.array([[co2]]).T

    # H2
    xuh2 = np.array([[co2, bio,ch4]]).T
    xch2 = np.array([[h2]]).T

    # Bio
    xubio = np.array([[co2, h2,ch4]]).T
    xcbio = np.array([[bio]]).T

    # CH4
    xuch4 = np.array([[co2, h2,bio]]).T
    xcch4 = np.array([[ch4]]).T

    measured_xu_dict = {"co2":xuco2,"h2":xuh2,"bio":xubio,"ch4":xuch4}
    measured_xc_dict = {"co2":xcco2,"h2":xch2,"bio":xcbio,"ch4":xcch4}
    
    # new variance-covariance matrices
    
    # CO2
    Yuco2 = np.array([[(h2*error)**2,0,0],[0,(bio*error)**2,0], [0,0,(ch4*error)**2]])
    Ycco2 = np.array([[(co2*error)**2]])

    # H2
    Yuh2 = np.array([[(co2*error)**2,0,0],[0,(bio*error)**2,0], [0,0,(ch4*error)**2]])
    Ych2 = np.array([[(h2*error)**2]])

    # Bio
    Yubio = np.array([[(co2*error)**2,0,0],[0,(h2*error)**2,0], [0,0,(ch4*error)**2]])
    Ycbio = np.array([[(bio*error)**2]])

    # CH4
    Yuch4 = np.array([[(co2*error)**2,0,0],[0,(h2*error)**2,0], [0,0,(bio*error)**2]])
    Ycch4 = np.array([[(ch4*error)**2]])

    measured_yu_dict = {"co2":Yuco2,"h2":Yuh2,"bio":Yubio,"ch4":Yuch4}
    measured_yc_dict = {"co2":Ycco2,"h2":Ych2,"bio":Ycbio,"ch4":Ycch4}
    
    #go through each gas
    for g in range(len(measure_list)):
        gas = measure_list[g]
        print(gas)
        xu = measured_xu_dict[gas]
        xc = measured_xc_dict[gas]
#         print(g)
#         print(xu)
#         print(xc)
        print("\n")

        Au = np.delete(A,g,axis=1)
        Ac = A[:,[g]]
#         print(Au)
#         print(Ac)
#         print("\n")

        Yu = measured_yu_dict[gas]
        Yc = measured_yc_dict[gas]
#         print(Yu)
#         print(Yc)
#         print("\n")

        scalar = (Ac.T.dot(Oin)).dot(Ac)
#         print(scalar)
        scalar_inv = np.linalg.inv(scalar)
#         print(scalar_inv)
#         print("\n")

        inbracketr = ((Ac.dot(scalar_inv)).dot(Ac.T)).dot(Oin)
#         print(inbracketr)
        Ouinv = Oin.dot(I-inbracketr)
        Ouinv = Ouinv.round(3)
#         print(Ouinv)
#         print("\n")
        ha = ((E.T).dot(Ouinv)).dot(E)
#         print(ha)
        hactual = ha[0][0]
        h_ls.append(hactual)
        if hactual > X2:
            print("The test failed with an h value of: ", round(hactual,3))
            # and continue
#         else:
#             print("The test passed with an h value of: ", round(hactual,3))
    return h_ls

# %%
def find_adjustments(reactor,timepoint,val_ls,drop_gas):
#     print("Reactor: ",reactor)
#     print("Time point: ", timepoint)
    
    # initialize list that will be used for the results of all the h's
#     h_ls = [] # h, hco2, hh2, hbio, hch4
    
    # ------------------------------------------------
    # Assumptions
    # STEADY STATE
    # Two degrees of freedom... don't measure NH3 or H20 so make matrix to two rows
    error= 0.1 # assumed 10% measurement error
    X2 = 5.99 # chi-squared for 2 degrees of freedom at 95% confidence interval
    I = np.identity(2) # 2 degress of freedom for the identity matrix
    
    # Rows of "A" are C, H, O, N
    # Columns of "A" are CO2, H2, NH3, Biomass, H2O, CH4

    # stochiometric coefficients
    A = np.array([[-1,0,1,1], [2,-1,0.0265,2]])

    # ---------------------------------------------------------------------------------
    co2 = val_ls[0]
    h2 = val_ls[1]
    bio = val_ls[2]
    ch4 = val_ls[3]
    
    # required to find adjustments
    val_ls_dict = {"co2":co2,"h2":h2,"bio":bio,"ch4":ch4}
       
    # measured variables
    x = np.array([[co2, h2, bio, ch4]]).T
#     print("A: ",A)
#     print("x: ",x)
    
    # vector of residuals
    E = -A.dot(x)
#     print("E: ",E)

#     # variance-covariance matrix 
#     # assume measurement error is independent and uncorrelated
    Y = np.array([[(co2*error)**2,0,0,0], [0,(h2*error)**2,0,0],[0,0,(bio*error)**2,0], [0,0,0,(ch4*error)**2]])
# #     print("Y: ",Y)
    
#     # net rate of input of components into system
    O = (A.dot(Y)).dot(A.T)
# #     print("O: ",O)
    
#     # inverse of net rate of input of components into system
    Oin = np.linalg.inv(O)
# #     print("Oin: ", Oin)
    
#     # test function
#     h = (E.T.dot(Oin)).dot(E)
#     hactual = h[0][0]
# #     h_ls.append(hactual)
# #     print("h: ",hactual)
    
#     # measurement error
#     d = ((Y.dot(A.T)).dot(Oin)).dot(E)
# #     print("d: ",d)
    
#     # true values
#     xt = x + d
#     print("xt: ",xt)

#     # stop here if the hypothesis is passed ((chi_squared for 2 degrees of freedom) > htest)
#     if hactual > X2:
#         print("The test failed with an h value of: ", round(hactual,3))
#         # and continue
#     else:
#         print("The test passed with an h value of: ", round(hactual,3))
    
    #--------------------------------------------------------------------------
    # Start finding the hs for the individual measurments
    
    # dictionary with which measurments to delete
#     measure_list = ["co2","h2","bio","ch4"]
    
    # new product vectors without various conditions
    # CO2
    xuco2 = np.array([[h2, bio,ch4]]).T
    xcco2 = np.array([[co2]]).T

    # H2
    xuh2 = np.array([[co2, bio,ch4]]).T
    xch2 = np.array([[h2]]).T

    # Bio
    xubio = np.array([[co2, h2,ch4]]).T
    xcbio = np.array([[bio]]).T

    # CH4
    xuch4 = np.array([[co2, h2,bio]]).T
    xcch4 = np.array([[ch4]]).T

    measured_xu_dict = {"co2":xuco2,"h2":xuh2,"bio":xubio,"ch4":xuch4}
    measured_xc_dict = {"co2":xcco2,"h2":xch2,"bio":xcbio,"ch4":xcch4}
    
    # new variance-covariance matrices
    
    # CO2
    Yuco2 = np.array([[(h2*error)**2,0,0],[0,(bio*error)**2,0], [0,0,(ch4*error)**2]])
    Ycco2 = np.array([[(co2*error)**2]])

    # H2
    Yuh2 = np.array([[(co2*error)**2,0,0],[0,(bio*error)**2,0], [0,0,(ch4*error)**2]])
    Ych2 = np.array([[(h2*error)**2]])

    # Bio
    Yubio = np.array([[(co2*error)**2,0,0],[0,(h2*error)**2,0], [0,0,(ch4*error)**2]])
    Ycbio = np.array([[(bio*error)**2]])

    # CH4
    Yuch4 = np.array([[(co2*error)**2,0,0],[0,(h2*error)**2,0], [0,0,(bio*error)**2]])
    Ycch4 = np.array([[(ch4*error)**2]])

    measured_yu_dict = {"co2":Yuco2,"h2":Yuh2,"bio":Yubio,"ch4":Yuch4}
    measured_yc_dict = {"co2":Ycco2,"h2":Ych2,"bio":Ycbio,"ch4":Ycch4}
    
#     #go through each gas
#     for g in range(len(measure_list)):
#         gas = measure_list[g]
#         print(gas)
    # defines which reactions to drop
    gas = drop_gas
    measure_dict = {"co2":0,"h2":1,"bio":2,"ch4":3}
    g = measure_dict[gas]
    xu = measured_xu_dict[gas]
    xc = measured_xc_dict[gas]
#         print(g)
#         print(xu)
#         print(xc)
#     print("\n")
    Au = np.delete(A,g,axis=1)
    Ac = A[:,[g]]
#         print(Au)
#         print(Ac)
#         print("\n")

    Yu = measured_yu_dict[gas]
    Yc = measured_yc_dict[gas]
#         print(Yu)
#         print(Yc)
#         print("\n")

    scalar = (Ac.T.dot(Oin)).dot(Ac)
#         print(scalar)
    scalar_inv = np.linalg.inv(scalar)
#         print(scalar_inv)
#         print("\n")

    inbracketr = ((Ac.dot(scalar_inv)).dot(Ac.T)).dot(Oin)
#         print(inbracketr)
    Ouinv = Oin.dot(I-inbracketr)
#     Ouinv = Ouinv.round(3)
#         print(Ouinv)
#         print("\n")
    ha = ((E.T).dot(Ouinv)).dot(E)
#         print(ha)
    hactual = ha[0][0]
    
    
    # measurement adjustments error
    du = ((Yu.dot(Au.T)).dot(Ouinv)).dot(E)
#     print("du",du)
    
    # convert to a list
    du_ls_temp = du.tolist()
#     du_ls_temp = pd.Series(du)
#     print(du_ls_temp)
    du_ls = []    
    for i in du_ls_temp:
#         print(i)
        i_new = list(i)
#         print(i_new[0])
        du_ls.append(i_new[0])
    du_dict = make_dict_gas(du_ls,gas)
        
    
#     h_ls.append(hactual)
#         if hactual > X2:
#             print("The test failed with an h value of: ", round(hactual,3))
#             # and continue
# #         else:
# #             print("The test passed with an h value of: ", round(hactual,3))
#     return h_ls
    return du_dict

# %%
def make_dict_gas(lst,dropped_gas):
#     print("Dropped gas: ", dropped_gas)
    gas_ls = ["co2","h2","bio","ch4"]
    gas_ls.remove(dropped_gas)
    dict_out ={}
    for g in range(len(gas_ls)):
        gas = gas_ls[g]
#         if gas != dropped_gas:
        dict_out[gas] = lst[g]
    return dict_out

# %%
def last_measurement(old_values_dict, adj_vector_dict, dropped_gas):

    if dropped_gas == "co2":
        print("CO2 dropped, calc new values")
        h2 = old_values_dict["h2"] + adj_vector_dict["h2"]
        bio = old_values_dict["bio"] + adj_vector_dict["bio"]
        ch4 = old_values_dict["ch4"] + adj_vector_dict["ch4"]
#         co2 = bio + ch4
        co2 = (h2-0.0265*bio - 2*ch4)/2
        result_ls = [co2,h2,bio,ch4]
        
    elif dropped_gas == "h2":
        print("H2 dropped, calc new values")
        co2 = old_values_dict["co2"] + adj_vector_dict["co2"]
        bio = old_values_dict["bio"] + adj_vector_dict["bio"]
        ch4 = old_values_dict["ch4"] + adj_vector_dict["ch4"]
        h2 = 2*co2 + 0.0265*bio + 2*ch4
        result_ls = [co2,h2,bio,ch4]
    elif dropped_gas == "bio":
        print("Bio dropped, calc new values")
        co2 = old_values_dict["co2"] + adj_vector_dict["co2"]
        h2 = old_values_dict["h2"] + adj_vector_dict["h2"]
        ch4 = old_values_dict["ch4"] + adj_vector_dict["ch4"]
#         bio = co2 - ch4
        bio = (h2-2*co2 - 2*ch4)/0.0265

        result_ls = [co2,h2,bio,ch4]
    elif dropped_gas == "ch4":
        print("CH4 dropped, calc new values")
        co2 = old_values_dict["co2"] + adj_vector_dict["co2"]
        h2 = old_values_dict["h2"] + adj_vector_dict["h2"]
        bio = old_values_dict["bio"] + adj_vector_dict["bio"]
#         ch4 = co2 - bio
        ch4 = (h2-2*co2 - 0.0265*bio)/2

        result_ls = [co2,h2,bio,ch4]
    else:
        print("error in dropped value")
        result_ls = []
    return result_ls

# %% [markdown]
# ## Trial with M.t.
#
# ### biomass - CO2 - H2 + CH4 + H2O - NH3 = 0
# #### ignore Sulfur in biomass
# ### CH<sub>1.681</sub>O<sub>0.481</sub>N<sub>0.222</sub>S<sub>0.0004</sub> -YCO<sub>2</sub> - YH<sub>2</sub> + YCH<sub>4</sub> + YH<sub>2</sub>O - YNH<sub>3</sub> = 0
# #### unknowns are H2O and NH3

# %% [markdown]
# # Example from paper Wang 1983

# %%
# Read in Data
# should have this format each column is a reactor
# the rows should be the CO2, H2, Biomass, CH4
# Units should all be the same (mmol/h)

pathtodata = r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\Error_Analysis_Data_SS2.xlsx"
pathtoresult = r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\Error_Analysis_h_Results_SS2.xlsx"
pathtoresult_drop = r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\Error_Analysis_h_Results_drop_SS2.xlsx"

# %%
df = pd.read_excel(pathtodata, sheet_name = None,engine="openpyxl",index_col="Timepoint") # read all sheets

# %%
sheet_ls = ["S1R2","S2R1","S2R3","S2R7","S1R4","S1R5","S2R6","S2R8","S1R7","S2R2","S2R4","S2R5"]
time_point_ls = [4.1,4.8,5.6,6.8]

# %%
h_dict= {}
for i in sheet_ls:
    print(i)
    df_temp = df[i]
#     print(df_temp)
    temp_dict = {}
    for t in time_point_ls:
        col = df_temp[t]
#         print(col)
        co2 = df_temp[t].loc["CO2"]
        h2 = df_temp[t].loc["H2"]
        bio = df_temp[t].loc["Biomass"]
        ch4 = df_temp[t].loc["CH4"]
        val_ls = [co2,h2,bio,ch4]
#         print("CO2: ",co2)
#         print("H2: ",h2)
#         print("Biomass: ",bio)
#         print("CH4: ",ch4)
        h_list = find_h(reactor=i,timepoint=t,val_ls=val_ls)
        print(h_list)
        temp_dict[t]=h_list
    h_dict[i]=temp_dict
print("h_dict:\n",h_dict)
# Out:
# S1R2
# Reactor:  S1R2
# Time point:  4.1
# The test passed with an h value of:  3.453
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.4525059418758532, 2.1638826989789406, 2.5515173310010746, 0.4533841991576875, 0.024858611864535834]
# Reactor:  S1R2
# Time point:  4.8
# The test passed with an h value of:  4.078
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [4.078448070483947, 4.068820972290023, 0.7056388338346563, 3.0260525402814, 1.3220234870860157]
# Reactor:  S1R2
# Time point:  5.6
# The test passed with an h value of:  5.011
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [5.011363251979268, 4.5496241586926445, 1.9240097112714403, 2.395286055654171, 0.5297511277508339]
# Reactor:  S1R2
# Time point:  6.8
# The test passed with an h value of:  3.941
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.9409663866578724, 2.0756816942710508, 3.2161954267513413, 0.25526257484944936, 0.15370170608089917]
# S2R1
# Reactor:  S2R1
# Time point:  4.1
# The test passed with an h value of:  1.895
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.894828354096774, 1.8775588794875984, 0.45701408753933587, 1.2864623144899556, 0.4534102858153997]
# Reactor:  S2R1
# Time point:  4.8
# The test passed with an h value of:  1.219
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.219360188444546, 1.0972875684778507, 0.018986831990433668, 1.1806776409129844, 0.7782693630893877]
# Reactor:  S2R1
# Time point:  5.6
# The test passed with an h value of:  2.547
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.5469808544553247, 2.155340393486413, 1.3067547183625041, 0.9236607170033756, 0.09200178021940661]
# Reactor:  S2R1
# Time point:  6.8
# The test passed with an h value of:  3.098
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.0977216345250502, 1.846478267895493, 2.392788757675732, 0.3376702837819612, 0.04660208807661764]
# S2R3
# Reactor:  S2R3
# Time point:  4.1
# The test passed with an h value of:  0.61
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.6103852147323772, 0.5794941001862127, 0.23827843332635984, 0.3239965092204049, 0.0667635058667662]
# Reactor:  S2R3
# Time point:  4.8
# The test passed with an h value of:  1.118
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.1184522292418437, 1.1183325480598498, 0.19966131211326008, 0.8475219706850636, 0.3452936969540549]
# Reactor:  S2R3
# Time point:  5.6
# The test passed with an h value of:  2.731
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.730608157632672, 2.731082718071633, 0.42065108693798786, 2.1163472412190907, 0.9505004216727397]
# Reactor:  S2R3
# Time point:  6.8
# The test passed with an h value of:  0.77
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.7697297907700624, 0.682360206152218, 0.3826135803176719, 0.3171551681544246, 0.036707035689259405]
# S2R7
# Reactor:  S2R7
# Time point:  4.1
# The test passed with an h value of:  0.029
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.02880295627782438, 0.022726311243794577, 2.8976637414116838e-05, 0.028667423285121715, 0.020088300204541314]
# Reactor:  S2R7
# Time point:  4.8
# The test passed with an h value of:  1.061
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.0611926679098223, 0.00921995750921107, 0.8612512869250586, 0.17109168027510877, 0.6771252735897259]
# Reactor:  S2R7
# Time point:  5.6
# The test passed with an h value of:  0.096
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.09571193587177448, 0.08705224822966809, 0.0031647994221984813, 0.0910191108710692, 0.05404886471789512]
# Reactor:  S2R7
# Time point:  6.8
# The test passed with an h value of:  2.442
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.4419119822469257, 0.5139244843295562, 0.7953485445264579, 1.9172533069325173, 2.4369705773196175]
# S1R4
# Reactor:  S1R4
# Time point:  4.1
# The test passed with an h value of:  3.325
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.3246867385459398, 1.6354594528796116, 2.8649483140895873, 0.1674482096334486, 0.1875003148897467]
# Reactor:  S1R4
# Time point:  4.8
# The test passed with an h value of:  2.526
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.5263524448263164, 2.294787256372434, 1.0922514042446814, 1.1814540664831141, 0.21612816609236057]
# Reactor:  S1R4
# Time point:  5.6
# The test passed with an h value of:  1.696
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.6960307645226664, 1.6939043329737562, 0.3479125644495188, 1.249060498478741, 0.49343782624256805]
# Reactor:  S1R4
# Time point:  6.8
# The test passed with an h value of:  2.382
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.3819667731648075, 1.12631797816239, 2.1009757495553574, 0.09935577550475791, 0.16442905322791002]
# S1R5
# Reactor:  S1R5
# Time point:  4.1
# The test failed with an h value of:  10.791
# co2
#
#
# The test failed with an h value of:  10.567
# h2
#
#
# bio
#
#
# The test failed with an h value of:  8.933
# ch4
#
#
# [10.790841825876774, 10.567031729361577, 3.2345644573266554, 8.932785340835323, 2.3085496001210903]
# Reactor:  S1R5
# Time point:  4.8
# The test failed with an h value of:  12.23
# co2
#
#
# h2
#
#
# The test failed with an h value of:  11.559
# bio
#
#
# ch4
#
#
# [12.229588445153096, 2.634331907940041, 11.55908458130161, 0.0026208683235377454, 3.564017613587621]
# Reactor:  S1R5
# Time point:  5.6
# The test failed with an h value of:  17.362
# co2
#
#
# h2
#
#
# The test failed with an h value of:  16.613
# bio
#
#
# ch4
#
#
# [17.361791256934183, 4.935408363649683, 16.613365662299675, 0.17287377341683724, 4.226285492672783]
# Reactor:  S1R5
# Time point:  6.8
# The test failed with an h value of:  9.333
# co2
#
#
# h2
#
#
# The test failed with an h value of:  9.299
# bio
#
#
# ch4
#
#
# [9.332864757372148, 3.3692059346180514, 9.298930578274975, 0.22325338422746677, 1.674196004121266]
# S2R6
# Reactor:  S2R6
# Time point:  4.1
# The test passed with an h value of:  0.947
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.9471069386456991, 0.9372414268452693, 0.25830695341269294, 0.6284521387534722, 0.20069826521940598]
# Reactor:  S2R6
# Time point:  4.8
# The test passed with an h value of:  0.496
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.4957758631591478, 0.49453018517946734, 0.12129418142045825, 0.3502205490306685, 0.11994864906323313]
# Reactor:  S2R6
# Time point:  5.6
# The test passed with an h value of:  1.005
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.0052295406859153, 0.25754541651225993, 0.9980325369735739, 0.0007615445187862265, 0.24653098152193567]
# Reactor:  S2R6
# Time point:  6.8
# The test passed with an h value of:  1.41
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.4103893976039226, 1.3279203236527304, 0.14635767847095246, 1.2687636392058816, 0.5731587862596366]
# S2R8
# Reactor:  S2R8
# Time point:  4.1
# The test failed with an h value of:  8.491
# co2
#
#
# h2
#
#
# The test failed with an h value of:  7.911
# bio
#
#
# ch4
#
#
# [8.491207914514996, 1.1843780741699976, 7.910816514724922, 0.08001055681962681, 3.0884058301805606]
# Reactor:  S2R8
# Time point:  4.8
# The test passed with an h value of:  1.807
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.8065626146815883, 0.04190361868396128, 1.0742946070491501, 0.6487600310470496, 1.4945892183818792]
# Reactor:  S2R8
# Time point:  5.6
# The test passed with an h value of:  0.958
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.9575804399761005, 0.16507832158277835, 0.33006839188400766, 0.6106305017229157, 0.9356947734183798]
# Reactor:  S2R8
# Time point:  6.8
# The test passed with an h value of:  0.045
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.045214619078673524, 0.04521939265613565, 0.010422196213109788, 0.03351240431185296, 0.011703539617098625]
# S1R7
# Reactor:  S1R7
# Time point:  4.1
# The test passed with an h value of:  0.388
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.3884063566478469, 0.02911917780693204, 0.3645479831288963, 0.02302104035860109, 0.1843554410254761]
# Reactor:  S1R7
# Time point:  4.8
# The test failed with an h value of:  10.201
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# The test failed with an h value of:  8.552
# [10.200808096494399, 0.6952041951368174, 4.936075669427693, 4.194064688771641, 8.552149047163734]
# Reactor:  S1R7
# Time point:  5.6
# The test passed with an h value of:  5.476
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [5.476076737911619, 0.6250727956161508, 2.3167595635293794, 2.8090009852603552, 4.985509112385537]
# Reactor:  S1R7
# Time point:  6.8
# The test passed with an h value of:  1.483
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.4832503763955898, 0.5797477939063231, 0.23893771284354937, 1.252268815500384, 1.4760962968346496]
# S2R2
# Reactor:  S2R2
# Time point:  4.1
# The test passed with an h value of:  2.927
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.9266006727158893, 1.3288162063181086, 2.5916293457076462, 0.09616414791131875, 0.23163935117521975]
# Reactor:  S2R2
# Time point:  4.8
# The test passed with an h value of:  3.444
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.443765576357511, 1.6233762694583964, 0.39306043010575614, 3.0334427112478566, 3.408405186723099]
# Reactor:  S2R2
# Time point:  5.6
# The test passed with an h value of:  2.019
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.019306803634291, 1.7618221999616932, 0.012226261461376207, 1.9902878697239659, 1.4191875435837988]
# Reactor:  S2R2
# Time point:  6.8
# The test passed with an h value of:  0.274
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.2741339312751898, 0.13986604081510895, 0.24584625190112733, 0.017132139972381208, 0.0157726538729659]
# S2R4
# Reactor:  S2R4
# Time point:  4.1
# The test passed with an h value of:  1.429
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.4289742214035617, 0.003608710087953125, 1.1106614656226947, 0.27199215859818376, 0.9597617841938033]
# Reactor:  S2R4
# Time point:  4.8
# The test failed with an h value of:  7.2
# co2
#
#
# h2
#
#
# The test failed with an h value of:  6.524
# bio
#
#
# ch4
#
#
# [7.199508817329621, 0.7089572958154351, 6.524052438953885, 0.18230496996454532, 2.9875138225043134]
# Reactor:  S2R4
# Time point:  5.6
# The test failed with an h value of:  15.486
# co2
#
#
# h2
#
#
# The test failed with an h value of:  10.524
# bio
#
#
# ch4
#
#
# The test failed with an h value of:  9.751
# [15.486389722067049, 0.003173854705507878, 10.524406123558684, 2.569216119298004, 9.751268693619338]
# Reactor:  S2R4
# Time point:  6.8
# The test failed with an h value of:  7.338
# co2
#
#
# h2
#
#
# The test failed with an h value of:  6.86
# bio
#
#
# ch4
#
#
# [7.33828600415227, 1.031866779996796, 6.859691618501223, 0.06954113029603735, 2.6628765211710896]
# S2R5
# Reactor:  S2R5
# Time point:  4.1
# The test failed with an h value of:  284.14
# co2
#
#
# h2
#
#
# The test failed with an h value of:  219.746
# bio
#
#
# The test failed with an h value of:  60.191
# ch4
#
#
# The test failed with an h value of:  210.165
# [284.1397626211273, 1.8431712796953459, 219.7456619326044, 60.191208670885, 210.16451211610124]
# Reactor:  S2R5
# Time point:  4.8
# The test failed with an h value of:  324.583
# co2
#
#
# The test failed with an h value of:  20.007
# h2
#
#
# The test failed with an h value of:  187.674
# bio
#
#
# The test failed with an h value of:  10.485
# ch4
#
#
# The test failed with an h value of:  211.861
# [324.58304524356646, 20.007193330162224, 187.6739593677016, 10.485064432945073, 211.86063549447817]
# Reactor:  S2R5
# Time point:  5.6
# The test failed with an h value of:  124.214
# co2
#
#
# The test failed with an h value of:  6.389
# h2
#
#
# The test failed with an h value of:  60.175
# bio
#
#
# The test failed with an h value of:  29.986
# ch4
#
#
# The test failed with an h value of:  69.471
# [124.21402769964048, 6.389130560677948, 60.17465059964094, 29.985974041044482, 69.47063461673278]
# Reactor:  S2R5
# Time point:  6.8
# The test failed with an h value of:  76.977
# co2
#
#
# h2
#
#
# The test failed with an h value of:  44.991
# bio
#
#
# The test failed with an h value of:  7.677
# ch4
#
#
# The test failed with an h value of:  40.399
# [76.9773819306967, 0.14683484875862307, 44.991134724826146, 7.676954121554642, 40.398740012980504]
# h_dict:
#             4.1       4.8       5.6       6.8
# h      8.491208  1.806563  0.957580  0.045215
# h_co2  1.184378  0.041904  0.165078  0.045219
# h_h2   7.910817  1.074295  0.330068  0.010422
# h_bio  0.080011  0.648760  0.610631  0.033512
# h_ch4  3.088406  1.494589  0.935695  0.011704
#             4.1        4.8       5.6       6.8
# h      0.388406  10.200808  5.476077  1.483250
# h_co2  0.029119   0.695204  0.625073  0.579748
# h_h2   0.364548   4.936076  2.316760  0.238938
# h_bio  0.023021   4.194065  2.809001  1.252269
# h_ch4  0.184355   8.552149  4.985509  1.476096
#             4.1       4.8       5.6       6.8
# h      2.926601  3.443766  2.019307  0.274134
# h_co2  1.328816  1.623376  1.761822  0.139866
# h_h2   2.591629  0.393060  0.012226  0.245846
# h_bio  0.096164  3.033443  1.990288  0.017132
# h_ch4  0.231639  3.408405  1.419188  0.015773
#             4.1       4.8        5.6       6.8
# h      1.428974  7.199509  15.486390  7.338286
# h_co2  0.003609  0.708957   0.003174  1.031867
# h_h2   1.110661  6.524052  10.524406  6.859692
# h_bio  0.271992  0.182305   2.569216  0.069541
# h_ch4  0.959762  2.987514   9.751269  2.662877
#               4.1         4.8         5.6        6.8
# h      284.139763  324.583045  124.214028  76.977382
# h_co2    1.843171   20.007193    6.389131   0.146835
# h_h2   219.745662  187.673959   60.174651  44.991135
# h_bio   60.191209   10.485064   29.985974   7.676954
# h_ch4  210.164512  211.860635   69.470635  40.398740

# %%
index_val_list = ["all","co2","h2","bio","ch4"]
h_dict= {}
for i in sheet_ls:
    print(i)
    df_temp = df[i]
#     print(df_temp)
    temp_dict = {}
    for t in time_point_ls:
        col = df_temp[t]
#         print(col)
        co2 = df_temp[t].loc["CO2"]
        h2 = df_temp[t].loc["H2"]
        bio = df_temp[t].loc["Biomass"]
        ch4 = df_temp[t].loc["CH4"]
        val_ls = [co2,h2,bio,ch4]
#         print("CO2: ",co2)
#         print("H2: ",h2)
#         print("Biomass: ",bio)
#         print("CH4: ",ch4)
        h_list = find_h(reactor=i,timepoint=t,val_ls=val_ls)
        print(h_list)
        temp_dict[t]=h_list
        if h_list[0] < 5.99: #95% confidence interval with 2 degrees of freedom
            pass
        else:
            min_val = min(h_list)
            index = h_list.index(min_val)
            print("Min_val",min_val)
            print(index)
            print("Drop this measurement: ",index_val_list[index])
            h_list[index] = "DROP"
            
    h_dict[i]=temp_dict
print("h_dict:\n",h_dict)
# Out:
# S1R2
# Reactor:  S1R2
# Time point:  4.1
# The test passed with an h value of:  3.453
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.4525059418758532, 2.1638826989789406, 2.5515173310010746, 0.4533841991576875, 0.024858611864535834]
# Reactor:  S1R2
# Time point:  4.8
# The test passed with an h value of:  4.078
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [4.078448070483947, 4.068820972290023, 0.7056388338346563, 3.0260525402814, 1.3220234870860157]
# Reactor:  S1R2
# Time point:  5.6
# The test passed with an h value of:  5.011
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [5.011363251979268, 4.5496241586926445, 1.9240097112714403, 2.395286055654171, 0.5297511277508339]
# Reactor:  S1R2
# Time point:  6.8
# The test passed with an h value of:  3.941
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.3819667731648075, 1.12631797816239, 2.1009757495553574, 0.09935577550475791, 0.16442905322791002]
# S1R5
# Reactor:  S1R5
# Time point:  4.1
# The test failed with an h value of:  10.791
# co2
#
#
# The test failed with an h value of:  10.567
# h2
#
#
# bio
#
#
# The test failed with an h value of:  8.933
# ch4
#
#
# [10.790841825876774, 10.567031729361577, 3.2345644573266554, 8.932785340835323, 2.3085496001210903]
# Min_val 2.3085496001210903
# 4
# Drop this measurement:  ch4
# Reactor:  S1R5
# Time point:  4.8
# The test failed with an h value of:  12.23
# co2
#
#
# h2
#
#
# The test failed with an h value of:  11.559
# bio
#
#
# ch4
#
#
# [12.229588445153096, 2.634331907940041, 11.55908458130161, 0.0026208683235377454, 3.564017613587621]
# Min_val 0.0026208683235377454
# 3
# Drop this measurement:  bio
# Reactor:  S1R5
# Time point:  5.6
# The test failed with an h value of:  17.362
# co2
#
#
# h2
#
#
# The test failed with an h value of:  16.613
# bio
#
#
# ch4
#
#
# [17.361791256934183, 4.935408363649683, 16.613365662299675, 0.17287377341683724, 4.226285492672783]
# Min_val 0.17287377341683724
# 3
# Drop this measurement:  bio
# Reactor:  S1R5
# Time point:  6.8
# The test failed with an h value of:  9.333
# co2
#
#
# h2
#
#
# The test failed with an h value of:  9.299
# bio
#
#
# ch4
#
#
# [9.332864757372148, 3.3692059346180514, 9.298930578274975, 0.22325338422746677, 1.674196004121266]
# Min_val 0.22325338422746677
# 3
# Drop this measurement:  bio
# S2R6
# Reactor:  S2R6
# Time point:  4.1
# The test passed with an h value of:  0.947
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.9471069386456991, 0.9372414268452693, 0.25830695341269294, 0.6284521387534722, 0.20069826521940598]
# Reactor:  S2R6
# Time point:  4.8
# The test passed with an h value of:  0.496
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.4957758631591478, 0.49453018517946734, 0.12129418142045825, 0.3502205490306685, 0.11994864906323313]
# Reactor:  S2R6
# Time point:  5.6
# The test passed with an h value of:  1.005
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.0052295406859153, 0.25754541651225993, 0.9980325369735739, 0.0007615445187862265, 0.24653098152193567]
# Reactor:  S2R6
# Time point:  6.8
# The test passed with an h value of:  1.41
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.4103893976039226, 1.3279203236527304, 0.14635767847095246, 1.2687636392058816, 0.5731587862596366]
# S2R8
# Reactor:  S2R8
# Time point:  4.1
# The test failed with an h value of:  8.491
# co2
#
#
# h2
#
#
# The test failed with an h value of:  7.911
# bio
#
#
# ch4
#
#
# [8.491207914514996, 1.1843780741699976, 7.910816514724922, 0.08001055681962681, 3.0884058301805606]
# Min_val 0.08001055681962681
# 3
# Drop this measurement:  bio
# Reactor:  S2R8
# Time point:  4.8
# The test passed with an h value of:  1.807
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.8065626146815883, 0.04190361868396128, 1.0742946070491501, 0.6487600310470496, 1.4945892183818792]
# Reactor:  S2R8
# Time point:  5.6
# The test passed with an h value of:  0.958
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.9575804399761005, 0.16507832158277835, 0.33006839188400766, 0.6106305017229157, 0.9356947734183798]
# Reactor:  S2R8
# Time point:  6.8
# The test passed with an h value of:  0.045
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.045214619078673524, 0.04521939265613565, 0.010422196213109788, 0.03351240431185296, 0.011703539617098625]
# S1R7
# Reactor:  S1R7
# Time point:  4.1
# The test passed with an h value of:  0.388
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.3884063566478469, 0.02911917780693204, 0.3645479831288963, 0.02302104035860109, 0.1843554410254761]
# Reactor:  S1R7
# Time point:  4.8
# The test failed with an h value of:  10.201
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# The test failed with an h value of:  8.552
# [10.200808096494399, 0.6952041951368174, 4.936075669427693, 4.194064688771641, 8.552149047163734]
# Min_val 0.6952041951368174
# 1
# Drop this measurement:  co2
# Reactor:  S1R7
# Time point:  5.6
# The test passed with an h value of:  5.476
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [5.476076737911619, 0.6250727956161508, 2.3167595635293794, 2.8090009852603552, 4.985509112385537]
# Reactor:  S1R7
# Time point:  6.8
# The test passed with an h value of:  1.483
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.4832503763955898, 0.5797477939063231, 0.23893771284354937, 1.252268815500384, 1.4760962968346496]
# S2R2
# Reactor:  S2R2
# Time point:  4.1
# The test passed with an h value of:  2.927
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.9266006727158893, 1.3288162063181086, 2.5916293457076462, 0.09616414791131875, 0.23163935117521975]
# Reactor:  S2R2
# Time point:  4.8
# The test passed with an h value of:  3.444
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [3.443765576357511, 1.6233762694583964, 0.39306043010575614, 3.0334427112478566, 3.408405186723099]
# Reactor:  S2R2
# Time point:  5.6
# The test passed with an h value of:  2.019
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [2.019306803634291, 1.7618221999616932, 0.012226261461376207, 1.9902878697239659, 1.4191875435837988]
# Reactor:  S2R2
# Time point:  6.8
# The test passed with an h value of:  0.274
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [0.2741339312751898, 0.13986604081510895, 0.24584625190112733, 0.017132139972381208, 0.0157726538729659]
# S2R4
# Reactor:  S2R4
# Time point:  4.1
# The test passed with an h value of:  1.429
# co2
#
#
# h2
#
#
# bio
#
#
# ch4
#
#
# [1.4289742214035617, 0.003608710087953125, 1.1106614656226947, 0.27199215859818376, 0.9597617841938033]
# Reactor:  S2R4
# Time point:  4.8
# The test failed with an h value of:  7.2
# co2
#
#
# h2
#
#
# The test failed with an h value of:  6.524
# bio
#
#
# ch4
#
#
# [7.199508817329621, 0.7089572958154351, 6.524052438953885, 0.18230496996454532, 2.9875138225043134]
# Min_val 0.18230496996454532
# 3
# Drop this measurement:  bio
# Reactor:  S2R4
# Time point:  5.6
# The test failed with an h value of:  15.486
# co2
#
#
# h2
#
#
# The test failed with an h value of:  10.524
# bio
#
#
# ch4
#
#
# The test failed with an h value of:  9.751
# [15.486389722067049, 0.003173854705507878, 10.524406123558684, 2.569216119298004, 9.751268693619338]
# Min_val 0.003173854705507878
# 1
# Drop this measurement:  co2
# Reactor:  S2R4
# Time point:  6.8
# The test failed with an h value of:  7.338
# co2
#
#
# h2
#
#
# The test failed with an h value of:  6.86
# bio
#
#
# ch4
#
#
# [7.33828600415227, 1.031866779996796, 6.859691618501223, 0.06954113029603735, 2.6628765211710896]
# Min_val 0.06954113029603735
# 3
# Drop this measurement:  bio
# S2R5
# Reactor:  S2R5
# Time point:  4.1
# The test failed with an h value of:  284.14
# co2
#
#
# h2
#
#
# The test failed with an h value of:  219.746
# bio
#
#
# The test failed with an h value of:  60.191
# ch4
#
#
# The test failed with an h value of:  210.165
# [284.1397626211273, 1.8431712796953459, 219.7456619326044, 60.191208670885, 210.16451211610124]
# Min_val 1.8431712796953459
# 1
# Drop this measurement:  co2
# Reactor:  S2R5
# Time point:  4.8
# The test failed with an h value of:  324.583
# co2
#
#
# The test failed with an h value of:  20.007
# h2
#
#
# The test failed with an h value of:  187.674
# bio
#
#
# The test failed with an h value of:  10.485
# ch4
#
#
# The test failed with an h value of:  211.861
# [324.58304524356646, 20.007193330162224, 187.6739593677016, 10.485064432945073, 211.86063549447817]
# Min_val 10.485064432945073
# 3
# Drop this measurement:  bio
# Reactor:  S2R5
# Time point:  5.6
# The test failed with an h value of:  124.214
# co2
#
#
# The test failed with an h value of:  6.389
# h2
#
#
# The test failed with an h value of:  60.175
# bio
#
#
# The test failed with an h value of:  29.986
# ch4
#
#
# The test failed with an h value of:  69.471
# [124.21402769964048, 6.389130560677948, 60.17465059964094, 29.985974041044482, 69.47063461673278]
# Min_val 6.389130560677948
# 1
# Drop this measurement:  co2
# Reactor:  S2R5
# Time point:  6.8
# The test failed with an h value of:  76.977
# co2
#
#
# h2
#
#
# The test failed with an h value of:  44.991
# bio
#
#
# The test failed with an h value of:  7.677
# ch4
#
#
# The test failed with an h value of:  40.399
# [76.9773819306967, 0.14683484875862307, 44.991134724826146, 7.676954121554642, 40.398740012980504]
# Min_val 0.14683484875862307
# 1
# Drop this measurement:  co2
# h_dict:
#  {'S1R2': {4.1: [3.4525059418758532, 2.1638826989789406, 2.5515173310010746, 0.4533841991576875, 0.024858611864535834], 4.8: [4.078448070483947, 4.068820972290023, 0.7056388338346563, 3.0260525402814, 1.3220234870860157], 5.6: [5.011363251979268, 4.5496241586926445, 1.9240097112714403, 2.395286055654171, 0.5297511277508339], 6.8: [3.9409663866578724, 2.0756816942710508, 3.2161954267513413, 0.25526257484944936, 0.15370170608089917]}, 'S2R1': {4.1: [1.894828354096774, 1.8775588794875984, 0.45701408753933587, 1.2864623144899556, 0.4534102858153997], 4.8: [1.219360188444546, 1.0972875684778507, 0.018986831990433668, 1.1806776409129844, 0.7782693630893877], 5.6: [2.5469808544553247, 2.155340393486413, 1.3067547183625041, 0.9236607170033756, 0.09200178021940661], 6.8: [3.0977216345250502, 1.846478267895493, 2.392788757675732, 0.3376702837819612, 0.04660208807661764]}, 'S2R3': {4.1: [0.6103852147323772, 0.5794941001862127, 0.23827843332635984, 0.3239965092204049, 0.0667635058667662], 4.8: [1.1184522292418437, 1.1183325480598498, 0.19966131211326008, 0.8475219706850636, 0.3452936969540549], 5.6: [2.730608157632672, 2.731082718071633, 0.42065108693798786, 2.1163472412190907, 0.9505004216727397], 6.8: [0.7697297907700624, 0.682360206152218, 0.3826135803176719, 0.3171551681544246, 0.036707035689259405]}, 'S2R7': {4.1: [0.02880295627782438, 0.022726311243794577, 2.8976637414116838e-05, 0.028667423285121715, 0.020088300204541314], 4.8: [1.0611926679098223, 0.00921995750921107, 0.8612512869250586, 0.17109168027510877, 0.6771252735897259], 5.6: [0.09571193587177448, 0.08705224822966809, 0.0031647994221984813, 0.0910191108710692, 0.05404886471789512], 6.8: [2.4419119822469257, 0.5139244843295562, 0.7953485445264579, 1.9172533069325173, 2.4369705773196175]}, 'S1R4': {4.1: [3.3246867385459398, 1.6354594528796116, 2.8649483140895873, 0.1674482096334486, 0.1875003148897467], 4.8: [
#  h_ch4  0.959762  2.987514   9.751269  2.662877,
#  'S2R5':               4.1         4.8         5.6        6.8
#  h      284.139763  324.583045  124.214028  76.977382
#  h_co2    1.843171   20.007193    6.389131   0.146835
#  h_h2   219.745662  187.673959   60.174651  44.991135
#  h_bio   60.191209   10.485064   29.985974   7.676954
#  h_ch4  210.164512  211.860635   69.470635  40.398740}

# %%
# h_gas_dict = {"h_co2":"co2","h_h2":"h2","h_bio":"bio","h_ch4":"ch4"}
# for i in sheet_ls:
#     print(i)
#     # for each sheet in the gas data
#     df_temp = df[i]
#     df_h_temp = df_h[i]
#     for t in time_point_ls:
#         col = df_h_temp[t]
#         col_dict = col.to_dict()
#         col_dict_flip = {value:key for key, value in col_dict.items()}
#         print(col_dict_flip)
# #         print(type(col))
# #         col_temp = col[1:]
#         min_h = min(col[1:])# only search after the h value = h_co2-->h_ch4
# #         print(min_h)
#         h_to_drop = col_dict_flip[min_h]
# #         print(h_to_drop)
#         print("measurement to drop: ", h_gas_dict[h_to_drop])

# %%
# h_dict= {}
df_out = df # make the new dataframe with the updated measurment values
h_gas_dict = {"h_co2":"co2","h_h2":"h2","h_bio":"bio","h_ch4":"ch4"}
for i in sheet_ls:
    print("Reactor: ",i)
    df_temp = df[i] # raw data
    df_h_temp = df_h[i] # data with the h values
    df_out_temp = df_out[i]
    print("df_out_temp_old",df_out_temp)

#     print(df_temp)
#     temp_dict = {}
    for t in time_point_ls:
        print("Time Point: ",t)
        col = df_temp[t] # data for the time point
#         print(col)
        co2 = df_temp[t].loc["CO2"]
        h2 = df_temp[t].loc["H2"]
        bio = df_temp[t].loc["Biomass"]
        ch4 = df_temp[t].loc["CH4"]
        val_ls = [co2,h2,bio,ch4]
        val_dict = {"co2":co2,"h2":h2,"bio":bio,"ch4":ch4}
        print("Old Value Dictionary", val_dict)
#         print("CO2: ",co2)
#         print("H2: ",h2)
#         print("Biomass: ",bio)
#         print("CH4: ",ch4)
        col_h = df_h_temp[t]
        col_dict = col_h.to_dict()
        col_dict_flip = {value:key for key, value in col_dict.items()}
        print(col_dict_flip)
#         print(type(col))
#         col_temp = col[1:]
        min_h = min(col_h[1:])# only search after the h value = h_co2-->h_ch4
#         print(min_h)
        h_to_drop = col_dict_flip[min_h]
#         print(h_to_drop)
        print("measurement to drop: ", h_gas_dict[h_to_drop])


        adj_vector_dict = find_adjustments(reactor=i,timepoint=t,val_ls=val_ls,drop_gas=h_gas_dict[h_to_drop])
        print(adj_vector_dict)
        updated_gas_measurement_ls = last_measurement(old_values_dict=val_dict,adj_vector_dict=adj_vector_dict,dropped_gas=h_gas_dict[h_to_drop])
        print("Updated_gas_measurements",updated_gas_measurement_ls)
        df_out_temp[t]=updated_gas_measurement_ls
        print("df_out_temp updated: ",df_out_temp)
        print("\n")
        
#         print(h_list)
#         temp_dict[t]=h_list
#     h_dict[i]=temp_dict
# print("h_dict:\n",h_dict)
# Out:
# Reactor:  S1R2
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        1

# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.437394  1.403002  1.391838  1.483083
# H2         5.585904  5.906588  6.189114  5.914516
# Biomass    0.082935  0.093327  0.096333  0.090458
# CH4        1.354459  1.226308  1.177113  1.271653
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 1.4030016805588623, 'h2': 5.906587517444549, 'bio': 0.0933265424051042, 'ch4': 1.226308120710584}
# {1.118452229241844: 'h', 1.11833254805985: 'h_co2', 0.1996613121132601: 'h_h2', 0.8475219706850636: 'h_bio', 0.3452936969540549: 'h_ch4'}
# measurement to drop:  h2
# {'co2': -0.04714245738259059, 'bio': 0.00020859610129629838, 'ch4': 0.03601596395928732}
# H2 dropped, calc new values
# Updated_gas_measurements [1.3558592231762718, 5.238845296862706, 0.0935351385064005, 1.2623240846698713]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.437394  1.355859  1.391838  1.483083
# H2         5.585904  5.238845  6.189114  5.914516
# Biomass    0.082935  0.093535  0.096333  0.090458
# CH4        1.354459  1.262324  1.177113  1.271653
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 1.39183758858001, 'h2': 6.189113965181553, 'bio': 0.09633318998673454, 'ch4': 1.177112830095686}
# {2.730608157632672: 'h', 2.731082718071633: 'h_co2', 0.4206510869379879: 'h_h2', 2.116347241219091: 'h_bio', 0.9505004216727397: 'h_ch4'}
# measurement to drop:  h2
# {'co2': -0.06883061026487744, 'bio': 0.0003297284200254363, 'ch4': 0.049231229812686704}
# H2 dropped, calc new values
# Updated_gas_measurements [1.3230069783151326, 5.101263643784789, 0.09666291840675997, 1.2263440599083726]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.437394  1.355859  1.323007  1.483083
# H2         5.585904  5.238845  5.101264  5.914516
# Biomass    0.082935  0.093535  0.096663  0.090458
# CH4        1.354459  1.262324  1.226344  1.271653
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 1.4830831256087187, 'h2': 5.914515600951463, 'bio': 0.09045823676460402, 'ch4': 1.271652608502221}
# {0.7697297907700624: 'h', 0.682360206152218: 'h_co2', 0.3826135803176719: 'h_h2', 0.3171551681544246: 'h_bio', 0.03670703568925941: 'h_ch4'}
# measurement to drop:  ch4
# {'co2': 0.020139078954232795, 'h2': -0.08007316399140614, 'bio': -3.696425801705169e-05}
# CH4 dropped, calc new values
# Updated_gas_measurements [1.5032222045629515, 5.834442436960057, 0.09042127250658696, 1.4128009320563646]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.437394  1.355859  1.323007  1.503222
# H2         5.585904  5.238845  5.101264  5.834442
# Biomass    0.082935  0.093535  0.096663  0.090421
# CH4        1.354459  1.262324  1.226344  1.412801
#
#
# Reactor:  S2R7
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.242055  1.096147  1.323889  1.246070
# H2         4.754023  4.797962  5.342798  3.871188
# Biomass    0.059142  0.061595  0.064679  0.064709
# CH4        1.183838  1.184431  1.248964  1.036689
# Time Point:  4.1
# Old Value Dictionary {'co2': 1.2420551785791705, 'h2': 4.75402349001326, 'bio': 0.05914161473608855, 'ch4': 1.18383775980169}
# {0.02880295627782438: 'h', 0.02272631124379458: 'h_co2', 2.897663741411684e-05: 'h_h2', 0.02866742328512172: 'h_bio', 0.02008830020454131: 'h_ch4'}
# measurement to drop:  h2
# {'co2': 0.0004836897556926686, 'bio': -1.0966586417050607e-06, 'ch4': -0.0004394095442737803}
# H2 dropped, calc new values
# Updated_gas_measurements [1.242538868334863, 4.853441660913611, 0.05914051807744685, 1.1833983502574164]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.242539  1.096147  1.323889  1.246070
# H2         4.853442  4.797962  5.342798  3.871188
# Biomass    0.059141  0.061595  0.064679  0.064709
# CH4        1.183398  1.184431  1.248964  1.036689
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 1.0961473331380804, 'h2': 4.797962430433589, 'bio': 0.06159481283782285, 'ch4': 1.184430864891771}
# {1.061192667909822: 'h', 0.00921995750921107: 'h_co2', 0.8612512869250586: 'h_h2', 0.1710916802751088: 'h_bio', 0.6771252735897259: 'h_ch4'}
# measurement to drop:  co2
# {'h2': 0.032688224879804606, 'bio': -1.091723198663241e-05, 'ch4': -0.007968142174729215}
# CO2 dropped, calc new values
# Updated_gas_measurements [1.238046618322878, 4.830650655313394, 0.06158389560583622, 1.1764627227170417]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.242539  1.238047  1.323889  1.246070
# H2         4.853442  4.830651  5.342798  3.871188
# Biomass    0.059141  0.061584  0.064679  0.064709
# CH4        1.183398  1.176463  1.248964  1.036689
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 1.323888618918116, 'h2': 5.342797514565998, 'bio': 0.06467934880817994, 'ch4': 1.248963857882275}
# {0.09571193587177448: 'h', 0.08705224822966809: 'h_co2', 0.003164799422198481: 'h_h2', 0.0910191108710692: 'h_bio', 0.05404886471789512: 'h_ch4'}
# measurement to drop:  h2
# {'co2': -0.005413975615957801, 'bio': 1.2922444500000685e-05, 'ch4': 0.004818514167203375}
# H2 dropped, calc new values
# Updated_gas_measurements [1.3184746433021581, 5.14622837589147, 0.06469227125267994, 1.2537823720494785]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.242539  1.238047  1.318475  1.246070
# H2         4.853442  4.830651  5.146228  3.871188
# Biomass    0.059141  0.061584  0.064692  0.064709
# CH4        1.183398  1.176463  1.253782  1.036689
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 1.246070068115316, 'h2': 3.871188059015036, 'bio': 0.06470856186583285, 'ch4': 1.036688686217663}
# {2.441911982246926: 'h', 0.5139244843295562: 'h_co2', 0.7953485445264579: 'h_h2', 1.917253306932517: 'h_bio', 2.436970577319618: 'h_ch4'}
# measurement to drop:  co2
# {'h2': 0.18928692029756755, 'bio': -0.00010717714154462938, 'ch4': -0.05429861792545463}
# CO2 dropped, calc new values
# Updated_gas_measurements [1.0469914530164965, 4.060474979312604, 0.06460138472428822, 0.9823900682922083]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.242539  1.238047  1.318475  1.046991
# H2         4.853442  4.830651  5.146228  4.060475
# Biomass    0.059141  0.061584  0.064692  0.064601
# CH4        1.183398  1.176463  1.253782  0.982390
#
#
# Reactor:  S1R4
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.818874  1.732808  1.591502  1.791142
# H2         6.766059  7.304605  6.920522  6.642645
# Biomass    0.040137  0.048042  0.053719  0.063685
# CH4        1.391097  1.448663  1.412239  1.397988
# Time Point:  4.1
# Old Value Dictionary {'co2': 1.818873548670266, 'h2': 6.766058792335635, 'bio': 0.04013669800894361, 'ch4': 1.391096835987835}
# {3.32468673854594: 'h', 1.635459452879612: 'h_co2', 2.864948314089587: 'h_h2', 0.1674482096334486: 'h_bio', 0.1875003148897467: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.03354831342595159, 'h2': -0.22908180885393434, 'ch4': 0.0191104505303889}
# Bio dropped, calc new values
# Updated_gas_measurements [1.8524218620962176, 6.536976983481701, 0.44221457557801347, 1.410207286518224]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 1.0071328641637725, 'h2': 5.16687731233133, 'bio': 0.050011769978202524, 'ch4': 1.600175189723909}
# {12.2295884451531: 'h', 2.634331907940041: 'h_co2', 11.55908458130161: 'h_h2', 0.002620868323537745: 'h_bio', 3.564017613587621: 'h_ch4'}
# measurement to drop:  bio
# {'co2': -0.0016119617608980601, 'h2': 0.02093586408069583, 'ch4': -0.003962842273895764}
# Bio dropped, calc new values
# Updated_gas_measurements [1.0055209024028744, 5.187813176412026, -0.5906914450471497, 1.5962123474500132]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.190702  1.005521  0.934968  0.973349
# H2         4.677384  5.187813  4.874096  4.520902
# Biomass    0.043286 -0.590691  0.065413  0.073326
# CH4        1.147416  1.596212  1.639192  1.427323
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 0.9349682682305924, 'h2': 4.874096141601072, 'bio': 0.06541292336754724, 'ch4': 1.639191754214368}
# {17.36179125693418: 'h', 4.935408363649683: 'h_co2', 16.61336566229967: 'h_h2', 0.1728737734168372: 'h_bio', 4.226285492672783: 'h_ch4'}
# measurement to drop:  bio
# {'co2': -0.01197322965980501, 'h2': 0.16056805409240685, 'ch4': -0.03583996803257009}
# Bio dropped, calc new values
# Updated_gas_measurements [0.9229950385707875, 5.034664195693479, -0.6803567476110217, 1.6033517861817979]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.190702  1.005521  0.922995  0.973349
# H2         4.677384  5.187813  5.034664  4.520902
# Biomass    0.043286 -0.590691 -0.680357  0.073326
# CH4        1.147416  1.596212  1.603352  1.427323
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 0.9733488248349547, 'h2': 4.520901654973267, 'bio': 0.07332576707796042, 'ch4': 1.427322601265}
# {9.332864757372148: 'h', 3.369205934618051: 'h_co2', 9.298930578274975: 'h_h2', 0.2232533842274668: 'h_bio', 1.674196004121266: 'h_ch4'}
# measurement to drop:  bio
# {'co2': -0.015972350938464778, 'h2': 0.17003383003079187, 'ch4': -0.03344772887948085}
# Bio dropped, calc new values
# Updated_gas_measurements [0.9573764738964898, 4.690935485004059, -0.43649839848903116, 1.3938748723855192]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.190702  1.005521  0.922995  0.957376
# H2         4.677384  5.187813  5.034664  4.690935
# Biomass    0.043286 -0.590691 -0.680357 -0.436498
# CH4        1.147416  1.596212  1.603352  1.393875
#
#
# Reactor:  S2R6
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.781977  1.762870  1.878882  1.968950
# H2         7.444196  7.274279  6.875409  6.954448
# Biomass    0.073737  0.064921  0.068074  0.063905
# CH4        1.586907  1.614661  1.566337  2.012791
# Time Point:  4.1
# Old Value Dictionary {'co2': 1.7819769478743204, 'h2': 7.444195951169815, 'bio': 0.07373672801704888, 'ch4': 1.586907205812918}
# {0.9471069386456991: 'h', 0.9372414268452693: 'h_co2', 0.2583069534126929: 'h_h2', 0.6284521387534722: 'h_bio', 0.200698265219406: 'h_ch4'}
# measurement to drop:  ch4
# {'co2': 0.05521023413110453, 'h2': -0.24087461147927042, 'bio': -4.664018773266196e-05}
# CH4 dropped, calc new values
# Updated_gas_measurements [1.8371871820054249, 7.203321339690544, 0.07369008782931621, 1.7634970941761088]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.837187  1.762870  1.878882  1.968950
# H2         7.203321  7.274279  6.875409  6.954448
# Biomass    0.073690  0.064921  0.068074  0.063905
# CH4        1.763497  1.614661  1.566337  2.012791
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 1.762870495890887, 'h2': 7.274278758835958, 'bio': 0.06492081225424973, 'ch4': 1.614660776108266}
# {0.4957758631591478: 'h', 0.4945301851794673: 'h_co2', 0.1212941814204583: 'h_h2', 0.3502205490306685: 'h_bio', 0.1199486490632331: 'h_ch4'}
# measurement to drop:  ch4
# {'co2': 0.04249389887130282, 'h2': -0.18088628919819394, 'bio': -2.8433530664825664e-05}
# CH4 dropped, calc new values
# Updated_gas_measurements [1.8053643947621898, 7.093392469637765, 0.0648923787235849, 1.7404720160386051]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.837187  1.805364  1.878882  1.968950
# H2         7.203321  7.093392  6.875409  6.954448
# Biomass    0.073690  0.064892  0.068074  0.063905
# CH4        1.763497  1.740472  1.566337  2.012791
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 1.8788820614325386, 'h2': 6.87540918505654, 'bio': 0.06807415238920426, 'ch4': 1.566337039272616}
# {1.005229540685915: 'h', 0.2575454165122599: 'h_co2', 0.9980325369735739: 'h_h2', 0.0007615445187862265: 'h_bio', 0.2465309815219357: 'h_ch4'}
# measurement to drop:  bio
# {'co2': -0.0023381869526103304, 'h2': 0.015450078295735276, 'ch4': -0.0015824906439354434}
# Bio dropped, calc new values
# Updated_gas_measurements [1.8765438744799283, 6.890859263352276, 0.31178932585125524, 1.5647545486286805]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.837187  1.805364  1.876544  1.968950
# H2         7.203321  7.093392  6.890859  6.954448
# Biomass    0.073690  0.064892  0.311789  0.063905
# CH4        1.763497  1.740472  1.564755  2.012791
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 1.968949715580803, 'h2': 6.954448432837465, 'bio': 0.06390467211265304, 'ch4': 2.012791222937345}
# {1.410389397603923: 'h', 1.32792032365273: 'h_co2', 0.1463576784709525: 'h_h2', 1.268763639205882: 'h_bio', 0.5731587862596366: 'h_ch4'}
# measurement to drop:  h2
# {'co2': 0.05265975403270014, 'bio': -5.547212437625029e-05, 'ch4': -0.05503095331211878}
# H2 dropped, calc new values
# Updated_gas_measurements [2.021609469613503, 7.960431482277148, 0.06384919998827679, 1.9577602696252263]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.837187  1.805364  1.876544  2.021609
# H2         7.203321  7.093392  6.890859  7.960431
# Biomass    0.073690  0.064892  0.311789  0.063849
# CH4        1.763497  1.740472  1.564755  1.957760
#
#
# Reactor:  S2R8
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.733503  1.100533  1.251422  1.314190
# H2         3.595594  5.125189  5.650556  5.260509
# Biomass    0.078256  0.052215  0.043253  0.038869
# CH4        1.006147  1.218592  1.312380  1.256753
# Time Point:  4.1
# Old Value Dictionary {'co2': 0.7335027123997236, 'h2': 3.595593632021824, 'bio': 0.0782564524319155, 'ch4': 1.006146955590701}
# {8.491207914514996: 'h', 1.184378074169998: 'h_co2', 7.910816514724922: 'h_h2', 0.08001055681962681: 'h_bio', 3.088405830180561: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.007058208956957515, 'h2': -0.08369233027576316, 'ch4': 0.012933153158600542}
# Bio dropped, calc new values
# Updated_gas_measurements [0.7405609213566812, 3.5119013017460605, -0.27851918739264664, 1.0190801087493015]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.740561  1.100533  1.251422  1.314190
# H2         3.511901  5.125189  5.650556  5.260509
# Biomass   -0.278519  0.052215  0.043253  0.038869
# CH4        1.019080  1.218592  1.312380  1.256753
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 1.1005329974254883, 'h2': 5.125188801868219, 'bio': 0.052215378831043144, 'ch4': 1.21859227381312}
# {1.806562614681588: 'h', 0.04190361868396128: 'h_co2', 1.07429460704915: 'h_h2', 0.6487600310470496: 'h_bio', 1.494589218381879: 'h_ch4'}
# measurement to drop:  co2
# {'h2': -0.07612047503515632, 'bio': 1.6011249579364364e-05, 'ch4': 0.017213079895550126}
# CO2 dropped, calc new values
# Updated_gas_measurements [1.2880367437892926, 5.049068326833062, 0.05223139008062251, 1.2358053537086702]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.740561  1.288037  1.251422  1.314190
# H2         3.511901  5.049068  5.650556  5.260509
# Biomass   -0.278519  0.052231  0.043253  0.038869
# CH4        1.019080  1.235805  1.312380  1.256753
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 1.25142172410659, 'h2': 5.650555878695396, 'bio': 0.04325289334810205, 'ch4': 1.312380219540792}
# {0.9575804399761005: 'h', 0.1650783215827784: 'h_co2', 0.3300683918840077: 'h_h2', 0.6106305017229157: 'h_bio', 0.9356947734183798: 'h_ch4'}
# measurement to drop:  co2
# {'h2': -0.16818416791508964, 'bio': 1.9970075169362244e-05, 'ch4': 0.03628959372246969}
# CO2 dropped, calc new values
# Updated_gas_measurements [1.3919426766865333, 5.482371710780306, 0.04327286342327141, 1.3486698132632617]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.740561  1.288037  1.391943  1.314190
# H2         3.511901  5.049068  5.482372  5.260509
# Biomass   -0.278519  0.052231  0.043273  0.038869
# CH4        1.019080  1.235805  1.348670  1.256753
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 1.314190191110397, 'h2': 5.260508912165113, 'bio': 0.03886903013714082, 'ch4': 1.256753049605356}
# {0.04521461907867352: 'h', 0.04521939265613565: 'h_co2', 0.01042219621310979: 'h_h2', 0.03351240431185296: 'h_bio', 0.01170353961709862: 'h_ch4'}
# measurement to drop:  h2
# {'co2': -0.009694247289274921, 'bio': 8.48017978361751e-06, 'ch4': 0.008865383898841613}
# H2 dropped, calc new values
# Updated_gas_measurements [1.304495943821122, 5.141259008674037, 0.038877510316924435, 1.2656184335041976]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.740561  1.288037  1.391943  1.304496
# H2         3.511901  5.049068  5.482372  5.141259
# Biomass   -0.278519  0.052231  0.043273  0.038878
# CH4        1.019080  1.235805  1.348670  1.265618
#
#
# Reactor:  S1R7
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.804613  0.637543  0.723712  0.830107
# H2         3.313656  3.765129  3.860744  3.820863
# Biomass    0.052285  0.058433  0.056686  0.058126
# CH4        0.821843  0.808177  0.835493  0.829411
# Time Point:  4.1
# Old Value Dictionary {'co2': 0.8046125040676684, 'h2': 3.313656381632494, 'bio': 0.052284532391012335, 'ch4': 0.8218426488204075}
# {0.3884063566478469: 'h', 0.02911917780693204: 'h_co2', 0.3645479831288963: 'h_h2', 0.02302104035860109: 'h_bio', 0.1843554410254761: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.00493530650865332, 'h2': -0.04130559753062202, 'ch4': 0.005014278450408895}
# Bio dropped, calc new values
# Updated_gas_measurements [0.8095478105763217, 3.2723507841018717, -0.017309116694510393, 0.8268569272708164]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.809548  0.637543  0.723712  0.830107
# H2         3.272351  3.765129  3.860744  3.820863
# Biomass   -0.017309  0.058433  0.056686  0.058126
# CH4        0.826857  0.808177  0.835493  0.829411
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 0.637542545711328, 'h2': 3.765129205070799, 'bio': 0.05843316720285524, 'ch4': 0.8081766400904442}
# {10.2008080964944: 'h', 0.6952041951368174: 'h_co2', 4.936075669427693: 'h_h2', 4.194064688771641: 'h_bio', 8.552149047163734: 'h_ch4'}
# measurement to drop:  co2
# {'h2': -0.23818633372013504, 'bio': 0.00011625791572948961, 'ch4': 0.04389647524651878}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.9106225404555479, 3.526942871350664, 0.05854942511858473, 0.852073115336963]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.809548  0.910623  0.723712  0.830107
# H2         3.272351  3.526943  3.860744  3.820863
# Biomass   -0.017309  0.058549  0.056686  0.058126
# CH4        0.826857  0.852073  0.835493  0.829411
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 0.7237123178100842, 'h2': 3.860744164709093, 'bio': 0.056685627164112774, 'ch4': 0.8354929465135548}
# {5.476076737911619: 'h', 0.6250727956161508: 'h_co2', 2.316759563529379: 'h_h2', 2.809000985260355: 'h_bio', 4.985509112385537: 'h_ch4'}
# measurement to drop:  co2
# {'h2': -0.23077319589447215, 'bio': 0.00010081747985427133, 'ch4': 0.04323036317235067}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.9355097543298724, 3.6299709688146207, 0.056786444643967045, 0.8787233096859054]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.809548  0.910623  0.935510  0.830107
# H2         3.272351  3.526943  3.629971  3.820863
# Biomass   -0.017309  0.058549  0.056786  0.058126
# CH4        0.826857  0.852073  0.878723  0.829411
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 0.8301067344453144, 'h2': 3.820862977808304, 'bio': 0.05812556109684977, 'ch4': 0.829411480653639}
# {1.48325037639559: 'h', 0.5797477939063231: 'h_co2', 0.2389377128435494: 'h_h2', 1.252268815500384: 'h_bio', 1.47609629683465: 'h_ch4'}
# measurement to drop:  h2
# {'co2': 0.028668872661353532, 'bio': -0.00014056495494410383, 'ch4': -0.028620869688876758}
# H2 dropped, calc new values
# Updated_gas_measurements [0.8587756071066679, 3.320669038540621, 0.057984996141905665, 0.8007906109647622]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.809548  0.910623  0.935510  0.858776
# H2         3.272351  3.526943  3.629971  3.320669
# Biomass   -0.017309  0.058549  0.056786  0.057985
# CH4        0.826857  0.852073  0.878723  0.800791
#
#
# Reactor:  S2R2
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.468410  1.048112  1.206198  1.374391
# H2         5.365122  5.316466  5.582461  5.281184
# Biomass    0.063619  0.063911  0.061582  0.061108
# CH4        1.108433  1.078575  1.126355  1.222044
# Time Point:  4.1
# Old Value Dictionary {'co2': 1.4684098380299377, 'h2': 5.365122076875487, 'bio': 0.06361870658567352, 'ch4': 1.10843319843414}
# {2.926600672715889: 'h', 1.328816206318109: 'h_co2', 2.591629345707646: 'h_h2', 0.09616414791131875: 'h_bio', 0.2316393511752197: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.02079466959402645, 'h2': -0.1369840687586718, 'ch4': 0.01153896949940517}
# Bio dropped, calc new values
# Updated_gas_measurements [1.4892045076239642, 5.228138008116815, 0.369232339690427, 1.1199721679335453]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.489205  1.048112  1.206198  1.374391
# H2         5.228138  5.316466  5.582461  5.281184
# Biomass    0.369232  0.063911  0.061582  0.061108
# CH4        1.119972  1.078575  1.126355  1.222044
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 1.0481119144338837, 'h2': 5.316465991728752, 'bio': 0.0639111897998175, 'ch4': 1.078574832188958}
# {3.443765576357511: 'h', 1.623376269458396: 'h_co2', 0.3930604301057561: 'h_h2', 3.033442711247857: 'h_bio', 3.408405186723099: 'h_ch4'}
# measurement to drop:  h2
# {'co2': 0.04575288099898808, 'bio': -0.00017012061176112318, 'ch4': -0.04845110594414265}
# H2 dropped, calc new values
# Updated_gas_measurements [1.0938647954328717, 4.249666181688858, 0.06374106918805637, 1.0301237262448155]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.489205  1.093865  1.206198  1.374391
# H2         5.228138  4.249666  5.582461  5.281184
# Biomass    0.369232  0.063741  0.061582  0.061108
# CH4        1.119972  1.030124  1.126355  1.222044
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 1.2061978121310466, 'h2': 5.582461120362863, 'bio': 0.061581980410164744, 'ch4': 1.126354981477462}
# {2.019306803634291: 'h', 1.761822199961693: 'h_co2', 0.01222626146137621: 'h_h2', 1.990287869723966: 'h_bio', 1.419187543583799: 'h_ch4'}
# measurement to drop:  h2
# {'co2': -0.009741195276470188, 'bio': 2.5391156318963305e-05, 'ch4': 0.00849426381063069}
# H2 dropped, calc new values
# Updated_gas_measurements [1.1964566168545765, 4.66424431963185, 0.06160737156648371, 1.1348492452880927]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.489205  1.093865  1.196457  1.374391
# H2         5.228138  4.249666  4.664244  5.281184
# Biomass    0.369232  0.063741  0.061607  0.061108
# CH4        1.119972  1.030124  1.134849  1.222044
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 1.3743911128551896, 'h2': 5.281183637479426, 'bio': 0.06110827286854809, 'ch4': 1.222044365952676}
# {0.2741339312751898: 'h', 0.1398660408151089: 'h_co2', 0.2458462519011273: 'h_h2', 0.01713213997238121: 'h_bio', 0.0157726538729659: 'h_ch4'}
# measurement to drop:  ch4
# {'co2': -0.012450353656212523, 'h2': 0.045958257928123324, 'bio': 1.2143340399852074e-05}
# CH4 dropped, calc new values
# Updated_gas_measurements [1.361940759198977, 5.327141895407549, 0.061120416208947946, 1.3008203429900291]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        1.489205  1.093865  1.196457  1.361941
# H2         5.228138  4.249666  4.664244  5.327142
# Biomass    0.369232  0.063741  0.061607  0.061120
# CH4        1.119972  1.030124  1.134849  1.300820
#
#
# Reactor:  S2R4
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.712473  0.564291  0.502139  0.547081
# H2         3.174762  2.774641  3.046241  2.655657
# Biomass    0.047218  0.051175  0.051779  0.047838
# CH4        0.776422  0.754026  0.741317  0.740755
# Time Point:  4.1
# Old Value Dictionary {'co2': 0.7124732885176452, 'h2': 3.174762011104715, 'bio': 0.04721797672938636, 'ch4': 0.7764224005965642}
# {1.428974221403562: 'h', 0.003608710087953125: 'h_co2', 1.110661465622695: 'h_h2', 0.2719921585981838: 'h_bio', 0.9597617841938033: 'h_ch4'}
# measurement to drop:  co2
# {'h2': 0.01359377476260279, 'bio': -6.093672021358792e-06, 'ch4': -0.0032521743836723474}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.8203821092702568, 3.1883557858673175, 0.047211883057365, 0.7731702262128919]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.820382  0.564291  0.502139  0.547081
# H2         3.188356  2.774641  3.046241  2.655657
# Biomass    0.047212  0.051175  0.051779  0.047838
# CH4        0.773170  0.754026  0.741317  0.740755
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': 0.564290688239051, 'h2': 2.774640838759819, 'bio': 0.051175313193330206, 'ch4': 0.754026162768601}
# {7.199508817329621: 'h', 0.7089572958154351: 'h_co2', 6.524052438953885: 'h_h2', 0.1823049699645453: 'h_bio', 2.987513822504313: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.008225773317967058, 'h2': -0.098138159770746, 'ch4': 0.014303236594852794}
# Bio dropped, calc new values
# Updated_gas_measurements [0.5725164615570181, 2.676502678989073, -0.195812937806438, 0.7683293993634538]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.820382  0.572516  0.502139  0.547081
# H2         3.188356  2.676503  3.046241  2.655657
# Biomass    0.047212 -0.195813  0.051779  0.047838
# CH4        0.773170  0.768329  0.741317  0.740755
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 0.5021391009635967, 'h2': 3.046240801987786, 'bio': 0.0517787243383425, 'ch4': 0.7413170338994117}
# {15.48638972206705: 'h', 0.003173854705507878: 'h_co2', 10.52440612355868: 'h_h2', 2.569216119298004: 'h_bio', 9.751268693619338: 'h_ch4'}
# measurement to drop:  co2
# {'h2': 0.012293601385675146, 'bio': -7.197803177657784e-06, 'ch4': -0.00291218268692435}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.7901763777476524, 3.058534403373461, 0.05177152653516484, 0.7384048512124873]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.820382  0.572516  0.790176  0.547081
# H2         3.188356  2.676503  3.058534  2.655657
# Biomass    0.047212 -0.195813  0.051772  0.047838
# CH4        0.773170  0.768329  0.738405  0.740755
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 0.5470806391487391, 'h2': 2.655657319990969, 'bio': 0.047838108030700224, 'ch4': 0.7407549140301343}
# {7.33828600415227: 'h', 1.031866779996796: 'h_co2', 6.859691618501223: 'h_h2', 0.06954113029603735: 'h_bio', 2.66287652117109: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.004955172412185296, 'h2': -0.05761738432992568, 'ch4': 0.008846993004489555}
# Bio dropped, calc new values
# Updated_gas_measurements [0.5520358115609244, 2.5980399356610433, -0.19756609547370355, 0.7496019070346238]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.820382  0.572516  0.790176  0.552036
# H2         3.188356  2.676503  3.058534  2.598040
# Biomass    0.047212 -0.195813  0.051772 -0.197566
# CH4        0.773170  0.768329  0.738405  0.749602
#
#
# Reactor:  S2R5
# df_out_temp_old                 4.1       4.8       5.6       6.8
# Timepoint
# CO2       -0.252642 -0.112302  0.075457  0.114538
# H2         0.917625  0.587765  1.735662  1.297190
# Biomass    0.026413  0.021019  0.017644  0.018072
# CH4        0.263494  0.276384  0.292662  0.332951
# Time Point:  4.1
# Old Value Dictionary {'co2': -0.25264207554035123, 'h2': 0.9176253050706791, 'bio': 0.026413170508412975, 'ch4': 0.2634943337372863}
# {284.1397626211273: 'h', 1.843171279695346: 'h_co2', 219.7456619326044: 'h_h2', 60.191208670885: 'h_bio', 210.1645121161012: 'h_ch4'}
# measurement to drop:  co2
# {'h2': 0.08175013473537202, 'bio': -0.00013726044170607997, 'ch4': -0.026962506723318874}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.2628077370806742, 0.999375439806051, 0.026275910066706893, 0.23653182701396744]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.262808 -0.112302  0.075457  0.114538
# H2         0.999375  0.587765  1.735662  1.297190
# Biomass    0.026276  0.021019  0.017644  0.018072
# CH4        0.236532  0.276384  0.292662  0.332951
#
#
# Time Point:  4.8
# Old Value Dictionary {'co2': -0.11230248839529888, 'h2': 0.5877650960378311, 'bio': 0.02101939617579425, 'ch4': 0.2763839720643325}
# {324.5830452435665: 'h', 20.00719333016222: 'h_co2', 187.6739593677016: 'h_h2', 10.48506443294507: 'h_bio', 211.8606354944782: 'h_ch4'}
# measurement to drop:  bio
# {'co2': 0.009928669140820698, 'h2': -0.13420640907953235, 'ch4': 0.058563700435033464}
# Bio dropped, calc new values
# Updated_gas_measurements [-0.10237381925447818, 0.45355868695829876, -0.43732149175384305, 0.33494767249936597]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.262808 -0.102374  0.075457  0.114538
# H2         0.999375  0.453559  1.735662  1.297190
# Biomass    0.026276 -0.437321  0.017644  0.018072
# CH4        0.236532  0.334948  0.292662  0.332951
#
#
# Time Point:  5.6
# Old Value Dictionary {'co2': 0.07545748233078098, 'h2': 1.73566181719784, 'bio': 0.017643880897757144, 'ch4': 0.2926620233460701}
# {124.2140276996405: 'h', 6.389130560677948: 'h_co2', 60.17465059964094: 'h_h2', 29.98597404104448: 'h_bio', 69.47063461673278: 'h_ch4'}
# measurement to drop:  co2
# {'h2': -0.36366868148966924, 'bio': 7.615712241873999e-05, 'ch4': 0.04135884631900097}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.351740907685247, 1.3719931357081707, 0.017720038020175882, 0.33402086966507105]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.262808 -0.102374  0.351741  0.114538
# H2         0.999375  0.453559  1.371993  1.297190
# Biomass    0.026276 -0.437321  0.017720  0.018072
# CH4        0.236532  0.334948  0.334021  0.332951
#
#
# Time Point:  6.8
# Old Value Dictionary {'co2': 0.1145382069186226, 'h2': 1.297189970520748, 'bio': 0.018071805567634727, 'ch4': 0.3329505679684885}
# {76.9773819306967: 'h', 0.1468348487586231: 'h_co2', 44.99113472482615: 'h_h2', 7.676954121554642: 'h_bio', 40.3987400129805: 'h_ch4'}
# measurement to drop:  co2
# {'h2': 0.034666268230018726, 'bio': -1.3634826863458073e-05, 'ch4': -0.009135229032340084}
# CO2 dropped, calc new values
# Updated_gas_measurements [0.3418735096769197, 1.3318562387507666, 0.01805817074077127, 0.3238153389361484]
# df_out_temp updated:                  4.1       4.8       5.6       6.8
# Timepoint
# CO2        0.262808 -0.102374  0.351741  0.341874
# H2         0.999375  0.453559  1.371993  1.331856
# Biomass    0.026276 -0.437321  0.017720  0.018058
# CH4        0.236532  0.334948  0.334021  0.323815

# %%
pathtoresult_edited = r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\Error_Analysis_Data_adjusted_SS2.xlsx"

# %%
# df_ls = []
with pd.ExcelWriter(pathtoresult_edited) as writer:
    for r in sheet_ls:
        df_temp = df_out[r]
#         data = h_dict[r]
#     #     print(data)
#         df_temp = pd.DataFrame.from_dict(h_dict[r])
#         df_temp = df_temp.set_index([pd.Index(["h", "h_co2","h_h2","h_bio","h_ch4"])])
#         print(df_temp)
        
        df_temp.to_excel(writer,sheet_name=r,engine="openpyxl")
