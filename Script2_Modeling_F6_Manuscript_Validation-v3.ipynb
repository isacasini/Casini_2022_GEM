# %%
# Imports
import cobra
from cobra.util.solver import linear_reaction_coefficients
import gurobipy
import cobra.util.array as cba
import pandas as pd
# STops the truncation of the results with "...""
pd.options.display.max_rows = 4000

import numpy as np

# for writing out files without overwriting other ones
from datetime import date
import os
import escher

# files for loopless and pFBA
from cobra.flux_analysis.loopless import add_loopless, loopless_solution
from cobra.flux_analysis import pfba

# files for FVA
from cobra.flux_analysis import flux_variability_analysis

# for writing out excel files
import xlsxwriter

import datetime
from os import path

import math

# %%
def rxnBalanced(model):
    """if positive H:1 and charge:1 then you add a H+ to the reactant side, if H:-1 and charge: -1
    then you add the H+ to the product side"""

    l = len(model.reactions)
    counter = 0

    for x in range(l):
        rxn_id = model.reactions[x].id
        #  The dictionary with the mass balance
        mbD = model.reactions.get_by_id(rxn_id).check_mass_balance()

        if bool(mbD) == True:
            counter += 1

            print("The mass and/or charge is not balanced in rxn", rxn_id)
            print("Balance: ", mbD)
    print("Number of unbalanced reactions is: ", counter)

# %%
# function to print matrix as table

def Smatrix2table(model, matrix):
    '''this function returns a matrix written as a table with labels'''
    shape = matrix.shape
    nummetabolites = shape[0]
    numreactions = shape[1]
    listMet =[]
    listRxn = []
    for m in range(len(model.metabolites)):
        metid = model.metabolites[m].id
        listMet.append(metid)
    for r in range(len(model.reactions)):
        rxnid = model.reactions[r].id
        listRxn.append(rxnid)
    
    table = pd.DataFrame(matrix,index=listMet,columns=listRxn)
    return table

# %%
# function to print out outputs of optimization in a nice looking DF, returns an alphabetized table and a list to put in the original order

def solution_as_table(model, solution):
    
    #series
    OV = solution.objective_value
    SS = solution.status
    FX = solution.fluxes
    SP = solution.shadow_prices
    RC = solution.reduced_costs
    
    #dict
    FX_d = solution.fluxes.to_dict()
    SP_d = solution.shadow_prices.to_dict()
    RC_d = solution.reduced_costs.to_dict()
    
    #dataframe
    FX_df = pd.DataFrame.from_dict(FX_d,orient = "index")
    SP_df = pd.DataFrame.from_dict(SP_d,orient = "index")
    RC_df = pd.DataFrame.from_dict(RC_d,orient = "index")
    
    #initialize dataframe
    frames = [FX_df,RC_df,SP_df]
    df = pd.concat(frames,axis =1)#,keys=['Reactions','Reactions','Metabolites'])
    df.columns = ['Fluxes','Reduced Costs','Shadow Prices']
    
    #makes the order in a list format
    orderrxn = list(FX_d.keys())
    ordermet = list(SP_d.keys())
    order = orderrxn+ordermet
    
    #prints values outside of the dataframe
    print ("Objective Value:\t",OV)
    print ("Solution Status:\t",SS)
    return df, order

# %%
# function to print out outputs of optimization in a nice looking DF, returns an alphabetized table and a list to put in the original order

def solution_as_table_short(model, solution):
    
    #series
    OV = solution.objective_value
    SS = solution.status
    FX = solution.fluxes

    #dict
    FX_d = solution.fluxes.to_dict()
 
    #dataframe
    FX_df = pd.DataFrame.from_dict(FX_d,orient = "index")

    #initialize dataframe
    frames = [FX_df]#,RC_df,SP_df]
    df = pd.concat(frames,axis =1)#,keys=['Reactions','Reactions','Metabolites'])
    df.columns = ['Fluxes']#,'Reduced Costs','Shadow Prices']
    
    #makes the order in a list format
    orderrxn = list(FX_d.keys())
    order = orderrxn#+ordermet

    #prints values outside of the dataframe
    print ("Objective Value:\t",OV)
    print ("Solution Status:\t",SS)
    return df, order

# %%
def nonzero_flux(model,solution):
    #dict
    FX_d = solution.fluxes.to_dict()
    
    for key, value in FX_d.items() :
        if value != 0.0:
            rxn = model.reactions.get_by_id(key).name
            print ("\033[1m",key, ":","\033[0m",rxn, ":", value)

# %%
def makeMap(directory, mapname, model, solution):
    os.chdir(directory)
    print(os.getcwd())
    
    builder = escher.Builder(model=model)
    reactiondata = solution.fluxes
    index = reactiondata.index

    reactiondict = {}
    for i in range(len(reactiondata)):
        key = reactiondata.index[i]
        value = reactiondata.values[i]
        valueint = float(value)
        reactiondict[key] = valueint
    
        #set values to the new 
    print(reactiondict)
    b = escher.Builder(map_json=mapname,
                   reaction_data=reactiondict,
                   # change the default colors
                   #reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                    #               {'type': 'mean', 'color': '#0000dd', 'size': 20},
                     #              {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=False)
    return b

# %%
# path to the model files
# path2model = r"F:\GEM_Models\Final_Model\Final_Publish\20220623_DH_model.xml"
# path2model = r"F:\GEM_Models\Final_Model\Final_Publish\20220623_ZZ_model.xml"
path2model = r"F:\GEM_Models\Final_Model\Final_Publish\20220623_MM_model.xml"

# %%
#  Reads in the model
model = cobra.io.read_sbml_model(path2model)
model
# Out:
# <Model iMMM22IC at 0x11338c29828>

# %%
print("Number of genes in the model: ",len(model.genes))
# Out:
# Number of genes in the model:  509

# %% [markdown]
# ## Validate model

# %%
cobra.io.sbml.validate_sbml_model(path2model, check_model=True) # Use with the newer COBRA
# Out:
# (<Model iMMM22IC at 0x1133963d710>,
#  {'SBML_FATAL': [],
#   'SBML_ERROR': [],
#   'SBML_SCHEMA_ERROR': [],
#   'SBML_WARNING': [],
#   'COBRA_FATAL': [],
#   'COBRA_ERROR': [],
#   'COBRA_WARNING': [],
#   'COBRA_CHECK': []})

# %% [markdown]
# ## Set solver

# %%
model.solver = "gurobi"
print("MODEL OBJECTIVE: \n",model.objective)
print("MODEL SOLVER: \n",model.solver)
# Out:
# MODEL OBJECTIVE:
#  Maximize
# 1.0*EX_biomass_e - 1.0*EX_biomass_e_reverse_5e4c9
# MODEL SOLVER:
#  \ LP format - for model browsing. Use MPS format to capture full model detail.
# Maximize
#   EX_biomass_e - EX_biomass_e_reverse_5e4c9
# Subject To
#  h2_c: - 2 MVHHDR + 2 MVHHDR_reverse_5da06 - FRH + FRH_reverse_2a109 - HMD
#    + HMD_reverse_23491 + 2 CARS - 2 CARS_reverse_24ade + 2 GCARS
#    - 2 GCARS_reverse_e0ab6 + 2 2GCARS - 2 2GCARS_reverse_c9167 + 2 PECARS
#    - 2 PECARS_reverse_1b82c + 2 2PECARS - 2 2PECARS_reverse_18dce
#    + 2 PICARS - 2 PICARS_reverse_1a275 + 2 2GPICARS
#    - 2 2GPICARS_reverse_e6c45 + GPECARS - GPECARS_reverse_5eced + 2GPECARS
#    - 2GPECARS_reverse_eeff2 + NIT1b2 - NIT1b2_reverse_497d5 - Eha
#    + Eha_reverse_5bd35 - Ehb + Ehb_reverse_822cd + tH2 - tH2_reverse_484e3
#    = 0
#  fdxox_c: - MVHHDR + MVHHDR_reverse_5da06 + FWD - FWD_reverse_c9261 + CbiL
#    - CbiL_reverse_f0d0a + 3 HTCAF - 3 HTCAF_reverse_9de33 + CoMF
#    - CoMF_reverse_5047b + CODH2 - CODH2_reverse_44594 + CODHr2
#    - CODHr2_reverse_d9f6f + POR2 - POR2_reverse_d1580 + OOR3r
#    - OOR3r_reverse_60215 - VOR + VOR_reverse_15672 + POR3
#    - POR3_reverse_bb6c8 + HcysS - HcysS_reverse_2b2c4 - IOR2
#    + IOR2_reverse_c7210 - IOR3 + IOR3_reverse_c98c8 - IOR
#    + IOR_reverse_9d121 + GLUSfx - GLUSfx_reverse_468d6 + HAMR2
#    - HAMR2_reverse_de260 + PFL2 - PFL2_reverse_665e8 + 8 ATSH2
#    - 8 ATSH2_reverse_2ab3f + 8 AtdensS - 8 AtdensS_reverse_2bf40 + 8 ATIH2
#    - 8 ATIH2_reverse_f26c7 + 8 ATGH2 - 8 ATGH2_reverse_5dc11 + 8 SATARFr
#    - 8 SATARFr_reverse_e1192 + 4 NIT1b2 - 4 NIT1b2_reverse_497d5 - Eha
#    + Eha_reverse_5bd35 - Ehb + Ehb_reverse_822cd = 0
#  hsfd_c: - MVHHDR + MVHHDR_reverse_5da06 + MCR - MCR_reverse_74d65 + FRD
#    - FRD_reverse_aff41 = 0
#  fdxrd_c: MVHHDR - MVHHDR_reverse_5da06 - FWD + FWD_reverse_c9261 - CbiL
#    + CbiL_reverse_f0d0a - 3 HTCAF + 3 HTCAF_reverse_9de33 - CoMF
#    + CoMF_reverse_5047b - CODH2 + CODH2_reverse_44594 - CODHr2
#    + CODHr2_reverse_d9f6f - POR2 + POR2_reverse_d1580 - OOR3r
#    + OOR3r_reverse_60215 + VOR - VOR_reverse_15672 - POR3
#    + POR3_reverse_bb6c8 - HcysS + HcysS_reverse_2b2c4 + IOR2
#    - IOR2_reverse_c7210 + IOR3 - IOR3_reverse_c98c8 + IOR
#    - IOR_reverse_9d121 - GLUSfx + GLUSfx_reverse_468d6 - HAMR2
#    + HAMR2_reverse_de260 - PFL2 + PFL2_reverse_665e8 - 8 ATSH2
#    + 8 ATSH2_reverse_2ab3f - 8 AtdensS + 8 AtdensS_reverse_2bf40 - 8 ATIH2
#    + 8 ATIH2_reverse_f26c7 - 8 ATGH2 + 8 ATGH2_reverse_5dc11 - 8 SATARFr
#    + 8 SATARFr_reverse_e1192 - 4 NIT1b2 + 4 NIT1b2_reverse_497d5 + Eha
#    - Eha_reverse_5bd35 + Ehb - Ehb_reverse_822cd = 0
#  com_c: MVHHDR - MVHHDR_reverse_5da06 - MTR + MTR_reverse_7c6fa + CoMF
#    - CoMF_reverse_5047b - FRD + FRD_reverse_aff41 - 0.1967 SMP_MM
#    + 0.1967 SMP_MM_reverse_5628c = 0
#  cob_c: MVHHDR - MVHHDR_reverse_5da06 - MCR + MCR_reverse_74d65 + COBS
#    - COBS_reverse_a75b7 - FRD + FRD_reverse_aff41 - 0.0816 SMP_MM
#    + 0.0816 SMP_MM_reverse_5628c = 0
#  h_c: 2 MVHHDR - 2 MVHHDR_reverse_5da06 - FRH + FRH_reverse_2a109 + HMD
#    - HMD_reverse_23491 - FTRM + FTRM_reverse_88db3 - FWD
#    + FWD_reverse_c9261 - MCH + MCH_reverse_3ada8 + 2 MTD
#    - 2 MTD_reverse_c4a6b + MER - MER_reverse_c1523 + NAt3_1
#    - NAt3_1_reverse_c24de - NAATP + NAATP_reverse_f73e1 + 2 CBPS
#    - 2 CBPS_reverse_80907 + MoaA - MoaA_reverse_c94da - MoeAB
#    + MoeAB_reverse_b752c + 2 GLUTRS - 2 GLUTRS_reverse_b214d - 2 GLUTRR
#    + 2 GLUTRR_reverse_355d5 + PPBNGS - PPBNGS_reverse_dc5a2 + UPP3MT
#    - UPP3MT_reverse_2adf0 + 2 SHCHD2 - 2 SHCHD2_reverse_d3585 + 2 SHCHF
#    - 2 SHCHF_reverse_fbf31 + 2 CFBA - 2 CFBA_reverse_ff041 + 2 CFBB
#    - 2 CFBB_reverse_817f4 - 4 CFBDC + 4 CFBDC_reverse_ce9d2 + 2 CbiX
#    - 2 CbiX_reverse_a657e - 2 CbiL + 2 CbiL_reverse_f0d0a + CODSCL4MT
#    - CODSCL4MT_reverse_4b39b + CODSCL5DA - CODSCL5DA_reverse_0b550 - CPC6R
#    + CPC6R_reverse_d9792 + CODSCL7MTDC2 - CODSCL7MTDC2_reverse_6e5ac
#    - 2 CODSCL8XI + 2 CODSCL8XI_reverse_a9154 + 2 CYRDAS
#    - 2 CYRDAS_reverse_c3ae6 + CYRDAR - CYRDAR_reverse_9aae4 + 4 ADCYRS
#    - 4 ADCYRS_reverse_3513c + ADCPS2 - ADCPS2_reverse_34636 + bzaAB
#    - bzaAB_reverse_d3356 + NN5HBPRT - NN5HBPRT_reverse_87b7e + 4 RZ5PP2_2
#    - 4 RZ5PP2_2_reverse_1cbf6 - LALDO3 + LALDO3_reverse_60a42 + 2 LCADi
#    - 2 LCADi_reverse_58cdc + 2PLS - 2PLS_reverse_98289 + 2 CofGH
#    - 2 CofGH_reverse_878ef + LPFPLT - LPFPLT_reverse_2dd8a + GF4GL_0
#    - GF4GL_0_reverse_2c56a + GF4GL_1 - GF4GL_1_reverse_9993b + 3 GTPCIII2
#    - 3 GTPCIII2_reverse_b8b32 + ArfB - ArfB_reverse_cdba9 - DROPPRx
#    + DROPPRx_reverse_fe59b - DRTPPD + DRTPPD_reverse_acb1d + DB4PS
#    - DB4PS_reverse_43dd1 + RBFSa - RBFSa_reverse_61d96 - RBFSb
#    + RBFSb_reverse_32299 + RBFLVK - RBFLVK_reverse_ab082 - MfnA
#    + MfnA_reverse_6f6e7 + MfnD - MfnD_reverse_63f6d - MfnE
#    + MfnE_reverse_b3764 + MfnF - MfnF_reverse_bfe43 - 4 HTCAF
#    + 4 HTCAF_reverse_9de33 + 2 MptA - 2 MptA_reverse_33497 + MptB
#    - MptB_reverse_2f3fe + MptB2 - MptB2_reverse_c5448 + 2 HPPK2
#    - 2 HPPK2_reverse_9a03f + 2 BRFSAPS - 2 BRFSAPS_reverse_4960f
#    + 2 dhrfapF - 2 dhrfapF_reverse_e7212 + dhadrpF - dhadrpF_reverse_d7756
#    + H4MPTS9 - H4MPTS9_reverse_4a57a + 2 dhadrF2 - 2 dhadrF2_reverse_6ad56
#    + dhadrprF - dhadrprF_reverse_0c0ca + dhadrdprF
#    - dhadrdprF_reverse_c4f18 + AHGDx - AHGDx_reverse_81b8f + H2MPTR
#    - H2MPTR_reverse_9ff06 + SLDx - SLDx_reverse_56c15 - SPDC
#    + SPDC_reverse_103db - 3 CoMF + 3 CoMF_reverse_5047b + HCITS
#    - HCITS_reverse_d9ad8 + AKACAL2 - AKACAL2_reverse_6febd + AKPCAL
#    - AKPCAL_reverse_7b11f - AKSDC + AKSDC_reverse_dedc1 - 7MHS
#    + 7MHS_reverse_c29a9 + 7MHTS - 7MHTS_reverse_102af + COBS
#    - COBS_reverse_a75b7 + 2 CF3Ha - 2 CF3Ha_reverse_82e9a + 2 CF3Hg
#    - 2 CF3Hg_reverse_e5f3c - DRP2 + DRP2_reverse_e24b0 + PoK
#    - PoK_reverse_33df1 - ASP1DC + ASP1DC_reverse_5dad1 + 2 PPSL
#    - 2 PPSL_reverse_b3b86 + 2 PPNCL2 - 2 PPNCL2_reverse_a65ee - PPCDC
#    + PPCDC_reverse_39306 + DPCOAK - DPCOAK_reverse_56ab9 + ACS
#    - ACS_reverse_37635 - 3 CODH2 + 3 CODH2_reverse_44594 + ACS3
#    - ACS3_reverse_373c7 - 2 CODHr2 + 2 CODHr2_reverse_d9f6f - POR2
#    + POR2_reverse_d1580 + PC - PC_reverse_88dba - MDH + MDH_reverse_ee52c
#    - MDHy + MDHy_reverse_5d499 + 3 PPS - 3 PPS_reverse_1c319 + PPC
#    - PPC_reverse_e854a - OOR3r + OOR3r_reverse_60215 + 2 FDHf420
#    - 2 FDHf420_reverse_f291b - GAPDP + GAPDP_reverse_9d791 + 2PGK
#    - 2PGK_reverse_7e0e7 - CDPGS + CDPGS_reverse_2a09c + 2 CDPGH
#    - 2 CDPGH_reverse_dc606 - ACLS + ACLS_reverse_66503 - KARA2_2
#    + KARA2_2_reverse_f810a + VOR - VOR_reverse_15672 + IPPS
#    - IPPS_reverse_d94c0 + IPMD - IPMD_reverse_d7a5e - OMCDC
#    + OMCDC_reverse_74477 + CITMS - CITMS_reverse_37134 - ACHBS
#    + ACHBS_reverse_13e5f - KARA2 + KARA2_reverse_65e99 + ACS2
#    - ACS2_reverse_7bf48 - POR3 + POR3_reverse_bb6c8 + 2 ASNS1
#    - 2 ASNS1_reverse_90309 - ASAD + ASAD_reverse_39a64 + H4THDPS
#    - H4THDPS_reverse_5f722 - H4THDPR + H4THDPR_reverse_617be - H4THDPR2
#    + H4THDPR2_reverse_1c503 - LDAPAT + LDAPAT_reverse_81d9c - DAPDC
#    + DAPDC_reverse_d3ab8 + THDPS - THDPS_reverse_41a90 + GLNS
#    - GLNS_reverse_59581 + ACGS - ACGS_reverse_c8939 - AGPR
#    + AGPR_reverse_5dce4 + OCBT - OCBT_reverse_f5568 + 2 ARGSS
#    - 2 ARGSS_reverse_5760d - ARGDC + ARGDC_reverse_08faf + RBK
#    - RBK_reverse_ee934 + DRBK - DRBK_reverse_7f901 + PRPPS
#    - PRPPS_reverse_dd7f2 + ATPPRT - ATPPRT_reverse_00060 + 2 PRATPP
#    - 2 PRATPP_reverse_99bf0 - PRMICI + PRMICI_reverse_af0a9 + 2 IG3PS
#    - 2 IG3PS_reverse_12008 + HISTDa - HISTDa_reverse_76147 + 2 HISTDb
#    - 2 HISTDb_reverse_acd55 + 3 HISTD - 3 HISTD_reverse_2a63b + PGCD
#    - PGCD_reverse_1bc76 + ALAD_L - ALAD_L_reverse_4f37b + SEPRS
#    - SEPRS_reverse_1e742 - CYSS + CYSS_reverse_62727 + CYSTRF
#    - CYSTRF_reverse_0085e - HSDxi + HSDxi_reverse_015b3 - HSDy
#    + HSDy_reverse_77ce7 + HSK - HSK_reverse_e4218 + SUA5
#    - SUA5_reverse_a15c0 + TCADES - TCADES_reverse_c4a74 - 3 HcysS
#    + 3 HcysS_reverse_2b2c4 + METAT - METAT_reverse_793ef - SIHF
#    + SIHF_reverse_1b247 - MTIS + MTIS_reverse_908cd + DHQS2
#    - DHQS2_reverse_25089 - SHK3Dr + SHK3Dr_reverse_d5c8f + SHKK
#    - SHKK_reverse_163fd - PPNDH + PPNDH_reverse_58300 + IOR2
#    - IOR2_reverse_c7210 + 2 PACCOAL - 2 PACCOAL_reverse_e1401 + IOR3
#    - IOR3_reverse_c98c8 + 2 PACCOAL2 - 2 PACCOAL2_reverse_6ff59 + ANS2
#    - ANS2_reverse_5a40c + ANS - ANS_reverse_4e062 + ANPRT
#    - ANPRT_reverse_e2684 - IGPS + IGPS_reverse_feb80 + IOR
#    - IOR_reverse_9d121 + PACCOAL3 - PACCOAL3_reverse_8bee9 - 2 GLUSfx
#    + 2 GLUSfx_reverse_468d6 + GLUS_F420 - GLUS_F420_reverse_2f3dd + PPA
#    - PPA_reverse_c5293 + PPA2 - PPA2_reverse_cb6ee + HCO3E
#    - HCO3E_reverse_97ea5 - 2 SPODM + 2 SPODM_reverse_2648f + CYSDS
#    - CYSDS_reverse_c49c8 - 3 HAMR2 + 3 HAMR2_reverse_de260 + CYANST
#    - CYANST_reverse_46415 + MCPST2 - MCPST2_reverse_75c45 + GLUPRT
#    - GLUPRT_reverse_1f180 + PPRGL - PPRGL_reverse_8395f + GART
#    - GART_reverse_61742 + PRFGS - PRFGS_reverse_db4e5 + PRAIS
#    - PRAIS_reverse_8e616 + 2 AIRC2 - 2 AIRC2_reverse_50d74 - AIRC3
#    + AIRC3_reverse_f015f + 2 PRASCSi - 2 PRASCSi_reverse_11704 + INSK
#    - INSK_reverse_93565 + IMPD - IMPD_reverse_6e625 + 3 GMPS2
#    - 3 GMPS2_reverse_aa6c4 + GSNK - GSNK_reverse_e6c23 + GUAPRT
#    - GUAPRT_reverse_ac1f5 - GK1 + GK1_reverse_11a40 + HXPRT
#    - HXPRT_reverse_c7021 - ADD + ADD_reverse_9eeb5 + ADPT
#    - ADPT_reverse_567cf + 2 ADSS - 2 ADSS_reverse_c75bb - ADK1
#    + ADK1_reverse_a6f90 + NTP1 - NTP1_reverse_46daa + NTP2
#    - NTP2_reverse_4113e + NTP3 - NTP3_reverse_eac23 + NTP4
#    - NTP4_reverse_a5bd6 + NTP5 - NTP5_reverse_252e0 + NTP6
#    - NTP6_reverse_9137c + NTP7 - NTP7_reverse_4a807 + NTP8
#    - NTP8_reverse_f4a9c + NTP9 - NTP9_reverse_ae219 + 2 XTPASE
#    - 2 XTPASE_reverse_8b01f + 2 NTPP10 - 2 NTPP10_reverse_bcc00 + 2 ITPASE2
#    - 2 ITPASE2_reverse_c76ab - ARTRADP + ARTRADP_reverse_842bc - PFL2
#    + PFL2_reverse_665e8 + ADNCYC - ADNCYC_reverse_013dc + PDE1
#    - PDE1_reverse_9a118 + 2 ADPRDP - 2 ADPRDP_reverse_6f5d7 - ARTRGDP
#    + ARTRGDP_reverse_5bcdf + ASPCT - ASPCT_reverse_c18b9 - DHORTS
#    + DHORTS_reverse_82d73 + DHORD72 - DHORD72_reverse_14509 + ORPT
#    - ORPT_reverse_19432 - OMPDC + OMPDC_reverse_45ba1 + UPPRT
#    - UPPRT_reverse_07052 - UMPK + UMPK_reverse_ae8e3 + 2 CTPS2
#    - 2 CTPS2_reverse_9c0ad + 2 CTPS1 - 2 CTPS1_reverse_0b562 - DCTPD2
#    + DCTPD2_reverse_164e0 + THEP1 - THEP1_reverse_a41c4 - CYTK1
#    + CYTK1_reverse_2fa21 + CYTDK1 - CYTDK1_reverse_36b6a - ARTRCTP
#    + ARTRCTP_reverse_048d7 - ARTRUTP + ARTRUTP_reverse_6d4b9 - DCTPD
#    + DCTPD_reverse_a48d6 + DCTPD3 - DCTPD3_reverse_b7116 + 2 DUTPDP
#    - 2 DUTPDP_reverse_1eccd - CYTK2 + CYTK2_reverse_bee82 - URIDK2r
#    + URIDK2r_reverse_1aa74 - DTMPK + DTMPK_reverse_44d5a + 3 F420SR
#    - 3 F420SR_reverse_93403 + 2 F4H2O - 2 F4H2O_reverse_acc21 + 2 F4NPR
#    - 2 F4NPR_reverse_24f5a + 8 FISC - 8 FISC_reverse_b1b5b + HMGCOAS
#    - HMGCOAS_reverse_0d18c - 2 HMGCOAR + 2 HMGCOAR_reverse_c376b + MEVK1
#    - MEVK1_reverse_46a93 - PMD + PMD_reverse_ee88c - IPK
#    + IPK_reverse_d42ff + DMATT - DMATT_reverse_3a731 + GRTT
#    - GRTT_reverse_f3afe + FRTT - FRTT_reverse_5200c + 7 TTHCUPD
#    - 7 TTHCUPD_reverse_e30a3 - G3PD2 + G3PD2_reverse_0c363 - G1PDH
#    + G1PDH_reverse_cf108 - G1PDH2 + G1PDH2_reverse_b7421 + GGGPS
#    - GGGPS_reverse_0615b + DGGGPS - DGGGPS_reverse_ac03c + CDGGGSAT
#    - CDGGGSAT_reverse_46571 - 16 ATSH2 + 16 ATSH2_reverse_2ab3f - AtdenS
#    + AtdenS_reverse_b6774 - 16 AtdensS + 16 AtdensS_reverse_2bf40
#    + CDGGIPT3 - CDGGIPT3_reverse_b0ce7 - 16 ATIH2 + 16 ATIH2_reverse_f26c7
#    + CDGGGPP3 - CDGGGPP3_reverse_f726b - 16 ATGH2 + 16 ATGH2_reverse_5dc11
#    - 16 SATARFr + 16 SATARFr_reverse_e1192 - DOGAS + DOGAS_reverse_3ea27
#    + FUDPDGLC - FUDPDGLC_reverse_497a7 - 3 GGDPR + 3 GGDPR_reverse_ea652
#    + PHYTES - PHYTES_reverse_45da8 + PHYTES2 - PHYTES2_reverse_e5cbe
#    + PYDXS - PYDXS_reverse_08e1a + G1PACT - G1PACT_reverse_51580
#    + 3 UACMAMO - 3 UACMAMO_reverse_b0219 - TDPDRR + TDPDRR_reverse_e7bd2
#    + ASPO2 - ASPO2_reverse_952c9 + ASPO2y - ASPO2y_reverse_e5832 + QULNS
#    - QULNS_reverse_66da1 - NNDPR + NNDPR_reverse_445ff + 2 NADS1
#    - 2 NADS1_reverse_0b93a + NADK - NADK_reverse_bba52 + NADK6
#    - NADK6_reverse_cfca2 + NADK7 - NADK7_reverse_fc6bb + NADK1
#    - NADK1_reverse_a61d5 + NADK2 - NADK2_reverse_52aca - TRDR
#    + TRDR_reverse_6372e + 2 NADHXD - 2 NADHXD_reverse_7b753 + 2 NADPHXD
#    - 2 NADPHXD_reverse_e3b94 + 3 ACALTROS - 3 ACALTROS_reverse_0687f
#    + 8 PSMNS - 8 PSMNS_reverse_40067 + 8 PSMNS2 - 8 PSMNS2_reverse_3f547
#    + 6 NIT1b2 - 6 NIT1b2_reverse_497d5 - AOXSr + AOXSr_reverse_6edad
#    + 3 DBTS - 3 DBTS_reverse_b5da6 + BTSMT - BTSMT_reverse_bfa0f + ThiC
#    - ThiC_reverse_ec7a1 + HMPK1 - HMPK1_reverse_8f692 + AHZS
#    - AHZS_reverse_05347 + 2 4MPETZS - 2 4MPETZS_reverse_64c45 - 2 TMPPP
#    + 2 TMPPP_reverse_f275c + 2 GTPCI - 2 GTPCI_reverse_1ee86 + CPH4S
#    - CPH4S_reverse_542c3 - CDGS + CDGS_reverse_6b7cb + CCGS
#    - CCGS_reverse_3ff79 + NIabc - NIabc_reverse_e360a + Coabc
#    - Coabc_reverse_75cd4 + FeoAB - FeoAB_reverse_8a06a + FE2abc
#    - FE2abc_reverse_2a151 + ZNabc - ZNabc_reverse_ce569 + ZNabc2
#    - ZNabc2_reverse_d0111 + MG2abc - MG2abc_reverse_07a52 + CA2abc
#    - CA2abc_reverse_259e7 + MOBDabc - MOBDabc_reverse_8421e + WO4abc
#    - WO4abc_reverse_ab45f + PIabc - PIabc_reverse_a066e + 2 Eha
#    - 2 Eha_reverse_5bd35 + 2 Ehb - 2 Ehb_reverse_822cd + tBTN
#    - tBTN_reverse_f73d2 + Cuabc - Cuabc_reverse_46883 + Cut1
#    - Cut1_reverse_225a4 + CD2abc1 - CD2abc1_reverse_18837 + CD2abc2
#    - CD2abc2_reverse_ce124 + CYSt2r - CYSt2r_reverse_6167b + PACt2r
#    - PACt2r_reverse_707ab + HPACt2r - HPACt2r_reverse_dcbf5 + IND3ACt2r
#    - IND3ACt2r_reverse_24b6b + ACt2r - ACt2r_reverse_64e05 + 5AOPt2
#    - 5AOPt2_reverse_4b80e + 4ABZt2r - 4ABZt2r_reverse_8aa72 + 2 PROTRS
#    - 2 PROTRS_reverse_9d634 + ATPM - ATPM_reverse_5b752
#    + 39.5203 PROTEIN_MM - 39.5203 PROTEIN_MM_reverse_a6e13 + 4.4355 DNA_MM
#    - 4.4355 DNA_MM_reverse_4cdb4 + 1.2615 RNA_MM
#    - 1.2615 RNA_MM_reverse_8c539 - 2 FDH_F420 + 2 FDH_F420_reverse_9344b
#    + FORt - FORt_reverse_40f9f = 0
#  f420_2_c: - FRH + FRH_reverse_2a109 + MTD - MTD_reverse_c4a6b + MER
#    - MER_reverse_c1523 + GF4GL_1 - GF4GL_1_reverse_9993b + dhadrpF
#    - dhadrpF_reverse_d7756 + H4MPTS9 - H4MPTS9_reverse_4a57a + H2MPTR
#    - H2MPTR_reverse_9ff06 - CF3Sa + CF3Sa_reverse_a566f - CF3Sg
#    + CF3Sg_reverse_83c4e + CF3Ha - CF3Ha_reverse_82e9a + CF3Hg
#    - CF3Hg_reverse_e5f3c + FDHf420 - FDHf420_reverse_f291b + GLUS_F420
#    - GLUS_F420_reverse_2f3dd + 3 F420SR - 3 F420SR_reverse_93403 + 2 F4H2O
#    - 2 F4H2O_reverse_acc21 + F4NPR - F4NPR_reverse_24f5a - 0.0361 SMP_MM
#    + 0.0361 SMP_MM_reverse_5628c - FDH_F420 + FDH_F420_reverse_9344b = 0
#  f420_2h2_c: FRH - FRH_reverse_2a109 - MTD + MTD_reverse_c4a6b - MER
#    + MER_reverse_c1523 - dhadrpF + dhadrpF_reverse_d7756 - H4MPTS9
#    + H4MPTS9_reverse_4a57a - H2MPTR + H2MPTR_reverse_9ff06 - FDHf420
#    + FDHf420_reverse_f291b - GLUS_F420 + GLUS_F420_reverse_2f3dd - 3 F420SR
#    + 3 F420SR_reverse_93403 - 2 F4H2O + 2 F4H2O_reverse_acc21 - F4NPR
#    + F4NPR_reverse_24f5a + FDH_F420 - FDH_F420_reverse_9344b = 0
#  meh4mpt_c: - HMD + HMD_reverse_23491 + MCH - MCH_reverse_3ada8 - MTD
#    + MTD_reverse_c4a6b = 0
#  myh4mpt_c: HMD - HMD_reverse_23491 + MTD - MTD_reverse_c4a6b - MER
#    + MER_reverse_c1523 - MOHMT2 + MOHMT2_reverse_ff6a1 + SHMT
#    - SHMT_reverse_bd6cb + FAE - FAE_reverse_e20a6 = 0
#  fmfra_c: - FTRM + FTRM_reverse_88db3 + FWD - FWD_reverse_c9261 = 0
#  h4mpt_c: - FTRM + FTRM_reverse_88db3 + MTR - MTR_reverse_7c6fa + H2MPTR
#    - H2MPTR_reverse_9ff06 + MOHMT2 - MOHMT2_reverse_ff6a1 + ACS3
#    - ACS3_reverse_373c7 + CODHr2 - CODHr2_reverse_d9f6f - SHMT
#    + SHMT_reverse_bd6cb + CoMetS - CoMetS_reverse_8883b - FAE
#    + FAE_reverse_e20a6 + TMDS2 - TMDS2_reverse_abfb9 - 0.0359 SMP_MM
#    + 0.0359 SMP_MM_reverse_5628c = 0
#  mfra_c: FTRM - FTRM_reverse_88db3 - FWD + FWD_reverse_c9261 + FMfr
#    - FMfr_reverse_c302d - 0.0373 SMP_MM + 0.0373 SMP_MM_reverse_5628c = 0
#  fh4mpt_c: FTRM - FTRM_reverse_88db3 - MCH + MCH_reverse_3ada8 = 0
#  co2_c: - FWD + FWD_reverse_c9261 + CODSCL6BMT2 - CODSCL6BMT2_reverse_1c0e9
#    + CobD - CobD_reverse_d40b2 + MfnA - MfnA_reverse_6f6e7 - HTCAF
#    + HTCAF_reverse_9de33 + BRFAPS - BRFAPS_reverse_0688b + BRAHPS
#    - BRAHPS_reverse_29b8b + SPDC - SPDC_reverse_103db + HICITD
#    - HICITD_reverse_0ed56 + TIH2CD - TIH2CD_reverse_291f9 + TIH3CD
#    - TIH3CD_reverse_46038 + AKSDC - AKSDC_reverse_dedc1 + ASP1DC
#    - ASP1DC_reverse_5dad1 + PPCDC - PPCDC_reverse_39306 - CODH2
#    + CODH2_reverse_44594 - CODHr2 + CODHr2_reverse_d9f6f - POR2
#    + POR2_reverse_d1580 - PPC + PPC_reverse_e854a - OOR3r
#    + OOR3r_reverse_60215 - FDHf420 + FDHf420_reverse_f291b + ACLS
#    - ACLS_reverse_66503 + VOR - VOR_reverse_15672 + OMCDC
#    - OMCDC_reverse_74477 + M3MOR - M3MOR_reverse_fd373 + ACHBS
#    - ACHBS_reverse_13e5f - POR3 + POR3_reverse_bb6c8 + DAPDC
#    - DAPDC_reverse_d3ab8 + ARGDC - ARGDC_reverse_08faf + PPNDH
#    - PPNDH_reverse_58300 + IOR2 - IOR2_reverse_c7210 + IOR3
#    - IOR3_reverse_c98c8 + PPND - PPND_reverse_5463c + IGPS
#    - IGPS_reverse_feb80 + IOR - IOR_reverse_9d121 - HCO3E
#    + HCO3E_reverse_97ea5 + ARTRADP - ARTRADP_reverse_842bc + ARTRGDP
#    - ARTRGDP_reverse_5bcdf + OMPDC - OMPDC_reverse_45ba1 + ARTRCTP
#    - ARTRCTP_reverse_048d7 + ARTRUTP - ARTRUTP_reverse_6d4b9 + PMD
#    - PMD_reverse_ee88c + AtdenS - AtdenS_reverse_b6774 + NNDPR
#    - NNDPR_reverse_445ff + AOXSr - AOXSr_reverse_6edad - DBTS
#    + DBTS_reverse_b5da6 + TMPPP - TMPPP_reverse_f275c + CO2t
#    - CO2t_reverse_7c42f + FDH_F420 - FDH_F420_reverse_9344b = 0
#  h2o_c: FWD - FWD_reverse_c9261 + MCH - MCH_reverse_3ada8 + NAATP
#    - NAATP_reverse_f73e1 - CBPS + CBPS_reverse_80907 - MoaC
#    + MoaC_reverse_60792 + 2 MoaE - 2 MoaE_reverse_bfb55 + MoeAB
#    - MoeAB_reverse_b752c + 2 PPBNGS - 2 PPBNGS_reverse_dc5a2 - HMBS
#    + HMBS_reverse_23a06 + UPP3S - UPP3S_reverse_8bb53 - 2 CFBB
#    + 2 CFBB_reverse_817f4 - CFBDC + CFBDC_reverse_ce9d2 - CODSCL5DA
#    + CODSCL5DA_reverse_0b550 - 2 CYRDAS + 2 CYRDAS_reverse_c3ae6 - 4 ADCYRS
#    + 4 ADCYRS_reverse_3513c - ADOCBLS2_2 + ADOCBLS2_2_reverse_894ee - LCADi
#    + LCADi_reverse_58cdc - 3 GTPCIII2 + 3 GTPCIII2_reverse_b8b32 - ArfB
#    + ArfB_reverse_cdba9 - DRTPPD + DRTPPD_reverse_acb1d - PMDPHT
#    + PMDPHT_reverse_8a0fd + 2 RBFSa - 2 RBFSa_reverse_61d96 + 2 FPAS
#    - 2 FPAS_reverse_a4762 + HTCAF - HTCAF_reverse_9de33 + 2 FMfr
#    - 2 FMfr_reverse_c302d - MptA + MptA_reverse_33497 - MptB
#    + MptB_reverse_2f3fe - MptB2 + MptB2_reverse_c5448 - DHNP3F
#    + DHNP3F_reverse_30a5b - DHNP2F + DHNP2F_reverse_ab040 - dhadrF
#    + dhadrF_reverse_1e977 - dhadrF2 + dhadrF2_reverse_6ad56 - PSLP
#    + PSLP_reverse_65f8f + CoMF - CoMF_reverse_5047b - HCITS
#    + HCITS_reverse_d9ad8 + SHCD2 - SHCD2_reverse_cfc42 - CHACH2
#    + CHACH2_reverse_ef23a - AKACAL2 + AKACAL2_reverse_6febd + RH2CD
#    - RH2CD_reverse_c55ff - CH2ACH + CH2ACH_reverse_2c16d - AKPCAL
#    + AKPCAL_reverse_7b11f + RH3CD - RH3CD_reverse_061db - CH3ACH
#    + CH3ACH_reverse_3437f - CF3Ha + CF3Ha_reverse_82e9a - CF3Hg
#    + CF3Hg_reverse_e5f3c - MOHMT2 + MOHMT2_reverse_ff6a1 + CODH2
#    - CODH2_reverse_44594 + CODHr2 - CODHr2_reverse_d9f6f + FUM
#    - FUM_reverse_d3642 - PPS + PPS_reverse_1c319 - PPC + PPC_reverse_e854a
#    - ENO + ENO_reverse_40eea - FBP + FBP_reverse_bf2c9 - CDPGH
#    + CDPGH_reverse_dc606 - DPGase + DPGase_reverse_3b298 + DHAD1
#    - DHAD1_reverse_39dca - IPPS + IPPS_reverse_d94c0 + IPPMIb
#    - IPPMIb_reverse_e37a1 - IPPMIa + IPPMIa_reverse_0594d - CITMS
#    + CITMS_reverse_37134 + CITCIa - CITCIa_reverse_6a08b - CITCIb
#    + CITCIb_reverse_a5ab2 + DHAD2 - DHAD2_reverse_755c6 - ASNS1
#    + ASNS1_reverse_90309 + H4THDPS - H4THDPS_reverse_5f722 + H4THDPR
#    - H4THDPR_reverse_617be + H4THDPR2 - H4THDPR2_reverse_1c503 - LDAPAT
#    + LDAPAT_reverse_81d9c + THDPS - THDPS_reverse_41a90 - AGMT
#    + AGMT_reverse_1c107 - PRATPP + PRATPP_reverse_99bf0 - PRAMPC
#    + PRAMPC_reverse_54696 + IGPDH - IGPDH_reverse_b1a3c - HISTP
#    + HISTP_reverse_5e409 - HISTDb + HISTDb_reverse_acd55 - HISTD
#    + HISTD_reverse_2a63b - PSP_L + PSP_L_reverse_cfa3c + SHMT
#    - SHMT_reverse_bd6cb - ALAD_L + ALAD_L_reverse_4f37b - CYSTRF
#    + CYSTRF_reverse_0085e - THRS + THRS_reverse_a994c + SUA5
#    - SUA5_reverse_a15c0 + HcysS - HcysS_reverse_2b2c4 - METAT
#    + METAT_reverse_793ef - ACHi + ACHi_reverse_12faa - SIHF
#    + SIHF_reverse_1b247 - SIHH + SIHH_reverse_886b4 - MTIS
#    + MTIS_reverse_908cd - DHQS2 + DHQS2_reverse_25089 + DHQTi
#    - DHQTi_reverse_c4498 + PPNDH - PPNDH_reverse_58300 + ANS2
#    - ANS2_reverse_5a40c + IGPS - IGPS_reverse_feb80 + TRPS2
#    - TRPS2_reverse_cd73f - PPA + PPA_reverse_c5293 - PPA2
#    + PPA2_reverse_cb6ee - MI1PP + MI1PP_reverse_76aa8 - HCO3E
#    + HCO3E_reverse_97ea5 - CYSDS + CYSDS_reverse_c49c8 + HAMR2
#    - HAMR2_reverse_de260 + FAE - FAE_reverse_e20a6 - GLUPRT
#    + GLUPRT_reverse_1f180 - PRFGS + PRFGS_reverse_db4e5 + IMPC
#    - IMPC_reverse_efa41 - NTD11 + NTD11_reverse_39abf - IMPD
#    + IMPD_reverse_6e625 - GMPS2 + GMPS2_reverse_aa6c4 - NTD9
#    + NTD9_reverse_d6a60 - NTD7 + NTD7_reverse_20dab - NTD10
#    + NTD10_reverse_8b9f0 - ADD + ADD_reverse_9eeb5 - NTP1
#    + NTP1_reverse_46daa - NTP2 + NTP2_reverse_4113e - NTP3
#    + NTP3_reverse_eac23 - NTP4 + NTP4_reverse_a5bd6 - NTP5
#    + NTP5_reverse_252e0 - NTP6 + NTP6_reverse_9137c - NTP7
#    + NTP7_reverse_4a807 - NTP8 + NTP8_reverse_f4a9c - NTP9
#    + NTP9_reverse_ae219 - XTPASE + XTPASE_reverse_8b01f - NTPP10
#    + NTPP10_reverse_bcc00 - ITPASE2 + ITPASE2_reverse_c76ab + RNDR2
#    - RNDR2_reverse_7df82 + ARTRADP - ARTRADP_reverse_842bc + RNDR1
#    - RNDR1_reverse_f4be1 - PDE1 + PDE1_reverse_9a118 - ADPRDP
#    + ADPRDP_reverse_6f5d7 + ARTRGDP - ARTRGDP_reverse_5bcdf + DHORTS
#    - DHORTS_reverse_82d73 - NTD2 + NTD2_reverse_a3382 - CTPS2
#    + CTPS2_reverse_9c0ad - DCTPD2 + DCTPD2_reverse_164e0 - THEP1
#    + THEP1_reverse_a41c4 - NTD4 + NTD4_reverse_0e18e + ARTRCTP
#    - ARTRCTP_reverse_048d7 + ARTRUTP - ARTRUTP_reverse_6d4b9 - DCTPD
#    + DCTPD_reverse_a48d6 - 2 DCTPD3 + 2 DCTPD3_reverse_b7116 - DUTPDP
#    + DUTPDP_reverse_1eccd + RNDR3 - RNDR3_reverse_bc84a - NTD3
#    + NTD3_reverse_6e80d - NTD1 + NTD1_reverse_d7db9 - NTD5
#    + NTD5_reverse_28a76 - NTD8 + NTD8_reverse_9dc69 - NTD6
#    + NTD6_reverse_c5bce + RNDR4 - RNDR4_reverse_aff84 + 3 F420SR
#    - 3 F420SR_reverse_93403 + 2 F4H2O - 2 F4H2O_reverse_acc21 - 6 FISC
#    + 6 FISC_reverse_b1b5b + 2 THIORDXi - 2 THIORDXi_reverse_27f13 - HMGCOAS
#    + HMGCOAS_reverse_0d18c + PMD - PMD_reverse_ee88c - AIS
#    + AIS_reverse_181cc - DGGPGP + DGGPGP_reverse_7fc6d - ARS
#    + ARS_reverse_a3c26 + 3 PYDXS - 3 PYDXS_reverse_08e1a - UACMAMO
#    + UACMAMO_reverse_b0219 + TDPGDH - TDPGDH_reverse_f570d + GMAND
#    - GMAND_reverse_b3087 - TRE6PP + TRE6PP_reverse_4fe3e - OAAS
#    + OAAS_reverse_c5168 + 2 QULNS - 2 QULNS_reverse_66da1 - NICRNSS
#    + NICRNSS_reverse_fe7b5 - NMNHYD + NMNHYD_reverse_d7656 - NADHHR
#    + NADHHR_reverse_94a5f - NADPHHR + NADPHHR_reverse_a7929 - ACGALS
#    + ACGALS_reverse_bcf5c - ACALTROS + ACALTROS_reverse_0687f + UACNACS
#    - UACNACS_reverse_1313a + UGALNACS - UGALNACS_reverse_4fa33 - 16 NIT1b2
#    + 16 NIT1b2_reverse_497d5 - AKSCAL + AKSCAL_reverse_d673f + 3 AHZS
#    - 3 AHZS_reverse_05347 - 4MPETZS + 4MPETZS_reverse_64c45 - PGLYCP
#    + PGLYCP_reverse_9063f - GTPCI + GTPCI_reverse_1ee86 - CPH4S
#    + CPH4S_reverse_542c3 + CCGS - CCGS_reverse_3ff79 - SUMQ1
#    + SUMQ1_reverse_9ede8 - NIabc + NIabc_reverse_e360a - Coabc
#    + Coabc_reverse_75cd4 - FeoAB + FeoAB_reverse_8a06a - FE2abc
#    + FE2abc_reverse_2a151 - ZNabc + ZNabc_reverse_ce569 - ZNabc2
#    + ZNabc2_reverse_d0111 - MG2abc + MG2abc_reverse_07a52 - CA2abc
#    + CA2abc_reverse_259e7 - MOBDabc + MOBDabc_reverse_8421e - WO4abc
#    + WO4abc_reverse_ab45f - PIabc + PIabc_reverse_a066e - Cuabc
#    + Cuabc_reverse_46883 - Cut1 + Cut1_reverse_225a4 - CD2abc1
#    + CD2abc1_reverse_18837 - CD2abc2 + CD2abc2_reverse_ce124 + H2Ot
#    - H2Ot_reverse_aa560 - ATPM + ATPM_reverse_5b752 - 39.5203 PROTEIN_MM
#    + 39.5203 PROTEIN_MM_reverse_a6e13 - 4.4355 DNA_MM
#    + 4.4355 DNA_MM_reverse_4cdb4 - 1.2615 RNA_MM
#    + 1.2615 RNA_MM_reverse_8c539 = 0
#  mh4mpt_c: MER - MER_reverse_c1523 - MTR + MTR_reverse_7c6fa - ACS3
#    + ACS3_reverse_373c7 - CODHr2 + CODHr2_reverse_d9f6f - CoMetS
#    + CoMetS_reverse_8883b - TMDS2 + TMDS2_reverse_abfb9 = 0
#  na1_c: - 2 MTR + 2 MTR_reverse_7c6fa - NAt3_1 + NAt3_1_reverse_c24de
#    + 4 NAATP - 4 NAATP_reverse_f73e1 + 2 Eha - 2 Eha_reverse_5bd35 + 2 Ehb
#    - 2 Ehb_reverse_822cd + PROt4 - PROt4_reverse_bb8de = 0
#  mcom_c: MTR - MTR_reverse_7c6fa - MCR + MCR_reverse_74d65 = 0
#  na1_e: 2 MTR - 2 MTR_reverse_7c6fa + NAt3_1 - NAt3_1_reverse_c24de
#    - 4 NAATP + 4 NAATP_reverse_f73e1 - 2 Eha + 2 Eha_reverse_5bd35 - 2 Ehb
#    + 2 Ehb_reverse_822cd - PROt4 + PROt4_reverse_bb8de - EX_na1_e
#    + EX_na1_e_reverse_c64df = 0
#  ch4_c: MCR - MCR_reverse_74d65 - CH4t + CH4t_reverse_be7dd = 0
#  h_e: - NAt3_1 + NAt3_1_reverse_c24de - tBTN + tBTN_reverse_f73d2 - CYSt2r
#    + CYSt2r_reverse_6167b - PACt2r + PACt2r_reverse_707ab - HPACt2r
#    + HPACt2r_reverse_dcbf5 - IND3ACt2r + IND3ACt2r_reverse_24b6b - ACt2r
#    + ACt2r_reverse_64e05 - 5AOPt2 + 5AOPt2_reverse_4b80e - 4ABZt2r
#    + 4ABZt2r_reverse_8aa72 - FORt + FORt_reverse_40f9f - EX_h_e
#    + EX_h_e_reverse_3e0c5 = 0
#  adp_c: - NAATP + NAATP_reverse_f73e1 + 2 CBPS - 2 CBPS_reverse_80907
#    + 2 CFBB - 2 CFBB_reverse_817f4 + CFBDC - CFBDC_reverse_ce9d2 + F430S
#    - F430S_reverse_459f5 + 2 CYRDAS - 2 CYRDAS_reverse_c3ae6 + 4 ADCYRS
#    - 4 ADCYRS_reverse_3513c + CobD - CobD_reverse_d40b2 + ADCPS2
#    - ADCPS2_reverse_34636 + MfnD - MfnD_reverse_63f6d + MfnE
#    - MfnE_reverse_b3764 + BRFSAPS - BRFSAPS_reverse_4960f + 7MHTS
#    - 7MHTS_reverse_102af + COBS - COBS_reverse_a75b7 + PoK
#    - PoK_reverse_33df1 + DPCOAK - DPCOAK_reverse_56ab9 + PC
#    - PC_reverse_88dba + SUCOAS - SUCOAS_reverse_22958 + PGK
#    - PGK_reverse_02696 + 2PGK - 2PGK_reverse_7e0e7 + CDPGS
#    - CDPGS_reverse_2a09c + ASPK - ASPK_reverse_115d7 + GLNS
#    - GLNS_reverse_59581 + ACGK - ACGK_reverse_684be + RBK
#    - RBK_reverse_ee934 + DRBK - DRBK_reverse_7f901 + HSK
#    - HSK_reverse_e4218 + SHKK - SHKK_reverse_163fd + PPRGL
#    - PPRGL_reverse_8395f + GART - GART_reverse_61742 + PRFGS
#    - PRFGS_reverse_db4e5 + PRAIS - PRAIS_reverse_8e616 + AIRC2
#    - AIRC2_reverse_50d74 + PRASCSi - PRASCSi_reverse_11704 + AICART2
#    - AICART2_reverse_de575 + INSK - INSK_reverse_93565 + GSNK
#    - GSNK_reverse_e6c23 + GK1 - GK1_reverse_11a40 + 2 ADK1
#    - 2 ADK1_reverse_a6f90 + NTP1 - NTP1_reverse_46daa + NDPK1
#    - NDPK1_reverse_9216a + NDPK5 - NDPK5_reverse_6973f + NDPK8
#    - NDPK8_reverse_13dd1 - RNDR1 + RNDR1_reverse_f4be1 + NDPK9
#    - NDPK9_reverse_43184 + NDPK10 - NDPK10_reverse_4956a + UMPK
#    - UMPK_reverse_ae8e3 + NDPK2 - NDPK2_reverse_10df6 + CTPS2
#    - CTPS2_reverse_9c0ad + CTPS1 - CTPS1_reverse_0b562 + NDPK3
#    - NDPK3_reverse_37ea6 + CYTK1 - CYTK1_reverse_2fa21 + CYTDK1
#    - CYTDK1_reverse_36b6a + NDPK7 - NDPK7_reverse_9dc79 + CYTK2
#    - CYTK2_reverse_bee82 + NDPK6 - NDPK6_reverse_d41ea + NDPK4
#    - NDPK4_reverse_9a1c8 + URIDK2r - URIDK2r_reverse_1aa74 + DTMPK
#    - DTMPK_reverse_44d5a + MEVK1 - MEVK1_reverse_46a93 + IPK
#    - IPK_reverse_d42ff + NADK - NADK_reverse_bba52 - NADHXD
#    + NADHXD_reverse_7b753 - NADPHXD + NADPHXD_reverse_e3b94 + 8 PSMNS
#    - 8 PSMNS_reverse_40067 + 8 PSMNS2 - 8 PSMNS2_reverse_3f547 + 16 NIT1b2
#    - 16 NIT1b2_reverse_497d5 + DBTS - DBTS_reverse_b5da6 + HMPK1
#    - HMPK1_reverse_8f692 + PMPK - PMPK_reverse_48b12 + TMPK
#    - TMPK_reverse_b7673 + CCGS - CCGS_reverse_3ff79 + NIabc
#    - NIabc_reverse_e360a + Coabc - Coabc_reverse_75cd4 + FE2abc
#    - FE2abc_reverse_2a151 + ZNabc - ZNabc_reverse_ce569 + ZNabc2
#    - ZNabc2_reverse_d0111 + MG2abc - MG2abc_reverse_07a52 + CA2abc
#    - CA2abc_reverse_259e7 + MOBDabc - MOBDabc_reverse_8421e + WO4abc
#    - WO4abc_reverse_ab45f + PIabc - PIabc_reverse_a066e + Cuabc
#    - Cuabc_reverse_46883 + Cut1 - Cut1_reverse_225a4 + CD2abc1
#    - CD2abc1_reverse_18837 + CD2abc2 - CD2abc2_reverse_ce124 + ATPM
#    - ATPM_reverse_5b752 + 39.5203 PROTEIN_MM
#    - 39.5203 PROTEIN_MM_reverse_a6e13 + 4.4355 DNA_MM
#    - 4.4355 DNA_MM_reverse_4cdb4 + 1.2615 RNA_MM
#    - 1.2615 RNA_MM_reverse_8c539 = 0
#  pi_c: - NAATP + NAATP_reverse_f73e1 + CBPS - CBPS_reverse_80907 + 2 CFBB
#    - 2 CFBB_reverse_817f4 + CFBDC - CFBDC_reverse_ce9d2 + F430S
#    - F430S_reverse_459f5 + 2 CYRDAS - 2 CYRDAS_reverse_c3ae6 + 4 ADCYRS
#    - 4 ADCYRS_reverse_3513c + ADCPS2 - ADCPS2_reverse_34636 + bzaAB
#    - bzaAB_reverse_d3356 + ADOCBLS2_2 - ADOCBLS2_2_reverse_894ee + GF4GL_0
#    - GF4GL_0_reverse_2c56a + GF4GL_1 - GF4GL_1_reverse_9993b + 2 GTPCIII2
#    - 2 GTPCIII2_reverse_b8b32 + PMDPHT - PMDPHT_reverse_8a0fd + RBFSa
#    - RBFSa_reverse_61d96 + MfnD - MfnD_reverse_63f6d + FPAS
#    - FPAS_reverse_a4762 + DHNP3F - DHNP3F_reverse_30a5b + DHNP2F
#    - DHNP2F_reverse_ab040 + BRFSAPS - BRFSAPS_reverse_4960f + dhadrF
#    - dhadrF_reverse_1e977 + dhadrF2 - dhadrF2_reverse_6ad56 + PSLP
#    - PSLP_reverse_65f8f + 7MHTS - 7MHTS_reverse_102af + PC
#    - PC_reverse_88dba + SUCOAS - SUCOAS_reverse_22958 + PPS
#    - PPS_reverse_1c319 + PPC - PPC_reverse_e854a + GAPDP
#    - GAPDP_reverse_9d791 + FBP - FBP_reverse_bf2c9 + CDPGS
#    - CDPGS_reverse_2a09c + DPGase - DPGase_reverse_3b298 + ASAD
#    - ASAD_reverse_39a64 + GLNS - GLNS_reverse_59581 + AGPR
#    - AGPR_reverse_5dce4 + OCBT - OCBT_reverse_f5568 + HISTP
#    - HISTP_reverse_5e409 + PSP_L - PSP_L_reverse_cfa3c + CYSS
#    - CYSS_reverse_62727 + THRS - THRS_reverse_a994c + METAT
#    - METAT_reverse_793ef - MTIP + MTIP_reverse_d413c + MGS
#    - MGS_reverse_26e2c + PSCVT - PSCVT_reverse_1a852 + CHORS
#    - CHORS_reverse_17772 + 2 PPA - 2 PPA_reverse_c5293 + PPA2
#    - PPA2_reverse_cb6ee + MI1PP - MI1PP_reverse_76aa8 + PPRGL
#    - PPRGL_reverse_8395f + GART - GART_reverse_61742 + PRFGS
#    - PRFGS_reverse_db4e5 + PRAIS - PRAIS_reverse_8e616 + AIRC2
#    - AIRC2_reverse_50d74 + PRASCSi - PRASCSi_reverse_11704 + AICART2
#    - AICART2_reverse_de575 + NTD11 - NTD11_reverse_39abf + NTD9
#    - NTD9_reverse_d6a60 + NTD7 - NTD7_reverse_20dab + NTD10
#    - NTD10_reverse_8b9f0 + ADSS - ADSS_reverse_c75bb + NTP1
#    - NTP1_reverse_46daa + NTP2 - NTP2_reverse_4113e + NTP3
#    - NTP3_reverse_eac23 + NTP4 - NTP4_reverse_a5bd6 + NTP5
#    - NTP5_reverse_252e0 + NTP6 - NTP6_reverse_9137c + NTP7
#    - NTP7_reverse_4a807 + NTP8 - NTP8_reverse_f4a9c + NTP9
#    - NTP9_reverse_ae219 + ASPCT - ASPCT_reverse_c18b9 + NTD2
#    - NTD2_reverse_a3382 + CTPS2 - CTPS2_reverse_9c0ad + CTPS1
#    - CTPS1_reverse_0b562 + THEP1 - THEP1_reverse_a41c4 + NTD4
#    - NTD4_reverse_0e18e + NTD3 - NTD3_reverse_6e80d + NTD1
#    - NTD1_reverse_d7db9 + NTD5 - NTD5_reverse_28a76 + NTD8
#    - NTD8_reverse_9dc69 + NTD6 - NTD6_reverse_c5bce + AIS
#    - AIS_reverse_181cc + DGGPGP - DGGPGP_reverse_7fc6d + FUDPDGLC
#    - FUDPDGLC_reverse_497a7 + PYDXS - PYDXS_reverse_08e1a + MAN1PT2
#    - MAN1PT2_reverse_861e0 + TRE6PP - TRE6PP_reverse_4fe3e + QULNS
#    - QULNS_reverse_66da1 + NICRNSS - NICRNSS_reverse_fe7b5 + NMNHYD
#    - NMNHYD_reverse_d7656 + NADHXD - NADHXD_reverse_7b753 + NADPHXD
#    - NADPHXD_reverse_e3b94 + 8 PSMNS - 8 PSMNS_reverse_40067 + 8 PSMNS2
#    - 8 PSMNS2_reverse_3f547 + 16 NIT1b2 - 16 NIT1b2_reverse_497d5 + DBTS
#    - DBTS_reverse_b5da6 + PGLYCP - PGLYCP_reverse_9063f + CCGS
#    - CCGS_reverse_3ff79 + NIabc - NIabc_reverse_e360a + Coabc
#    - Coabc_reverse_75cd4 + FeoAB - FeoAB_reverse_8a06a + FE2abc
#    - FE2abc_reverse_2a151 + ZNabc - ZNabc_reverse_ce569 + ZNabc2
#    - ZNabc2_reverse_d0111 + MG2abc - MG2abc_reverse_07a52 + CA2abc
#    - CA2abc_reverse_259e7 + MOBDabc - MOBDabc_reverse_8421e + WO4abc
#    - WO4abc_reverse_ab45f + 2 PIabc - 2 PIabc_reverse_a066e + Cuabc
#    - Cuabc_reverse_46883 + Cut1 - Cut1_reverse_225a4 + CD2abc1
#    - CD2abc1_reverse_18837 + CD2abc2 - CD2abc2_reverse_ce124 + ATPM
#    - ATPM_reverse_5b752 + 39.5203 PROTEIN_MM
#    - 39.5203 PROTEIN_MM_reverse_a6e13 + 4.4355 DNA_MM
#    - 4.4355 DNA_MM_reverse_4cdb4 + 1.2615 RNA_MM
#    - 1.2615 RNA_MM_reverse_8c539 = 0
#  atp_c: NAATP - NAATP_reverse_f73e1 - 2 CBPS + 2 CBPS_reverse_80907 - MPTAT
#    + MPTAT_reverse_75105 - GLUTRS + GLUTRS_reverse_b214d - 2 CFBB
#    + 2 CFBB_reverse_817f4 - CFBDC + CFBDC_reverse_ce9d2 - F430S
#    + F430S_reverse_459f5 - 2 CYRDAS + 2 CYRDAS_reverse_c3ae6 - CYRDAAT
#    + CYRDAAT_reverse_d0652 - 4 ADCYRS + 4 ADCYRS_reverse_3513c - CobD
#    + CobD_reverse_d40b2 - ADCPS2 + ADCPS2_reverse_34636 - FMNAT
#    + FMNAT_reverse_50ba1 - MfnD + MfnD_reverse_63f6d - MfnE
#    + MfnE_reverse_b3764 - HPPK2 + HPPK2_reverse_9a03f - BRFSAPS
#    + BRFSAPS_reverse_4960f - dhadrdprF + dhadrdprF_reverse_c4f18 - 7MHTS
#    + 7MHTS_reverse_102af - COBS + COBS_reverse_a75b7 - CF3Sa
#    + CF3Sa_reverse_a566f - PoK + PoK_reverse_33df1 - PPSL
#    + PPSL_reverse_b3b86 - PTPATi + PTPATi_reverse_381d9 - DPCOAK
#    + DPCOAK_reverse_56ab9 - ACS + ACS_reverse_37635 - PC + PC_reverse_88dba
#    - SUCOAS + SUCOAS_reverse_22958 - PPS + PPS_reverse_1c319 - PGK
#    + PGK_reverse_02696 - 2PGK + 2PGK_reverse_7e0e7 - CDPGS
#    + CDPGS_reverse_2a09c - ACS2 + ACS2_reverse_7bf48 - ASNS1
#    + ASNS1_reverse_90309 - ASPK + ASPK_reverse_115d7 - GLNS
#    + GLNS_reverse_59581 - ACGK + ACGK_reverse_684be - ARGSS
#    + ARGSS_reverse_5760d - RBK + RBK_reverse_ee934 - DRBK
#    + DRBK_reverse_7f901 - PRPPS + PRPPS_reverse_dd7f2 - ATPPRT
#    + ATPPRT_reverse_00060 - SEPRS + SEPRS_reverse_1e742 - HSK
#    + HSK_reverse_e4218 - SUA5 + SUA5_reverse_a15c0 - METAT
#    + METAT_reverse_793ef - SHKK + SHKK_reverse_163fd - PACCOAL
#    + PACCOAL_reverse_e1401 - PACCOAL2 + PACCOAL2_reverse_6ff59 - PACCOAL3
#    + PACCOAL3_reverse_8bee9 - PPRGL + PPRGL_reverse_8395f - GART
#    + GART_reverse_61742 - PRFGS + PRFGS_reverse_db4e5 - PRAIS
#    + PRAIS_reverse_8e616 - AIRC2 + AIRC2_reverse_50d74 - PRASCSi
#    + PRASCSi_reverse_11704 - AICART2 + AICART2_reverse_de575 - INSK
#    + INSK_reverse_93565 - GMPS2 + GMPS2_reverse_aa6c4 - GSNK
#    + GSNK_reverse_e6c23 - GK1 + GK1_reverse_11a40 - ADK1
#    + ADK1_reverse_a6f90 - NTP1 + NTP1_reverse_46daa - NDPK1
#    + NDPK1_reverse_9216a - NDPK5 + NDPK5_reverse_6973f - ARTRADP
#    + ARTRADP_reverse_842bc - NDPK8 + NDPK8_reverse_13dd1 - ADNCYC
#    + ADNCYC_reverse_013dc - NDPK9 + NDPK9_reverse_43184 - NDPK10
#    + NDPK10_reverse_4956a - UMPK + UMPK_reverse_ae8e3 - NDPK2
#    + NDPK2_reverse_10df6 - CTPS2 + CTPS2_reverse_9c0ad - CTPS1
#    + CTPS1_reverse_0b562 - NDPK3 + NDPK3_reverse_37ea6 - CYTK1
#    + CYTK1_reverse_2fa21 - CYTDK1 + CYTDK1_reverse_36b6a - NDPK7
#    + NDPK7_reverse_9dc79 - CYTK2 + CYTK2_reverse_bee82 - NDPK6
#    + NDPK6_reverse_d41ea - NDPK4 + NDPK4_reverse_9a1c8 - URIDK2r
#    + URIDK2r_reverse_1aa74 - DTMPK + DTMPK_reverse_44d5a - MEVK1
#    + MEVK1_reverse_46a93 - IPK + IPK_reverse_d42ff - NNATr
#    + NNATr_reverse_8ab73 - NADS1 + NADS1_reverse_0b93a - NADK
#    + NADK_reverse_bba52 - NMNAT + NMNAT_reverse_6a3d7 - 8 PSMNS
#    + 8 PSMNS_reverse_40067 - 8 PSMNS2 + 8 PSMNS2_reverse_3f547 - 16 NIT1b2
#    + 16 NIT1b2_reverse_497d5 - DBTS + DBTS_reverse_b5da6 - BACCL
#    + BACCL_reverse_8bcde - HMPK1 + HMPK1_reverse_8f692 - PMPK
#    + PMPK_reverse_48b12 - TMPK + TMPK_reverse_b7673 - CCGS
#    + CCGS_reverse_3ff79 - NIabc + NIabc_reverse_e360a - Coabc
#    + Coabc_reverse_75cd4 - FE2abc + FE2abc_reverse_2a151 - ZNabc
#    + ZNabc_reverse_ce569 - ZNabc2 + ZNabc2_reverse_d0111 - MG2abc
#    + MG2abc_reverse_07a52 - CA2abc + CA2abc_reverse_259e7 - MOBDabc
#    + MOBDabc_reverse_8421e - WO4abc + WO4abc_reverse_ab45f - PIabc
#    + PIabc_reverse_a066e - Cuabc + Cuabc_reverse_46883 - Cut1
#    + Cut1_reverse_225a4 - CD2abc1 + CD2abc1_reverse_18837 - CD2abc2
#    + CD2abc2_reverse_ce124 - PROTRS + PROTRS_reverse_9d634 - ATPM
#    + ATPM_reverse_5b752 - 39.5203 PROTEIN_MM
#    + 39.5203 PROTEIN_MM_reverse_a6e13 - 4.4355 DNA_MM
#    + 4.4355 DNA_MM_reverse_4cdb4 - 1.9886 RNA_MM
#    + 1.9886 RNA_MM_reverse_8c539 = 0
#  gln__L_c: - CBPS + CBPS_reverse_80907 - 2 CFBB + 2 CFBB_reverse_817f4
#    - 2 CYRDAS + 2 CYRDAS_reverse_c3ae6 - 4 ADCYRS + 4 ADCYRS_reverse_3513c
#    - ASNS1 + ASNS1_reverse_90309 + GLNS - GLNS_reverse_59581 - IG3PS
#    + IG3PS_reverse_12008 - ANS + ANS_reverse_4e062 - GLUSfx
#    + GLUSfx_reverse_468d6 - GLUS_F420 + GLUS_F420_reverse_2f3dd - GLUPRT
#    + GLUPRT_reverse_1f180 - PRFGS + PRFGS_reverse_db4e5 - GMPS2
#    + GMPS2_reverse_aa6c4 - CTPS2 + CTPS2_reverse_9c0ad - PYDXS
#    + PYDXS_reverse_08e1a - GF6PTA + GF6PTA_reverse_21fb1 - SUMQ1
#    + SUMQ1_reverse_9ede8 - 0.3979 PROTEIN_MM
#    + 0.3979 PROTEIN_MM_reverse_a6e13 = 0
#  hco3_c: - CBPS + CBPS_reverse_80907 - PC + PC_reverse_88dba - SUA5
#    + SUA5_reverse_a15c0 + HCO3E - HCO3E_reverse_97ea5 - AIRC2
#    + AIRC2_reverse_50d74 = 0
#  glu__L_c: CBPS - CBPS_reverse_80907 - GLUTRS + GLUTRS_reverse_b214d
#    + 2 CFBB - 2 CFBB_reverse_817f4 + 2 CYRDAS - 2 CYRDAS_reverse_c3ae6
#    + 4 ADCYRS - 4 ADCYRS_reverse_3513c - GF4GL_0 + GF4GL_0_reverse_2c56a
#    - GF4GL_1 + GF4GL_1_reverse_9993b - MfnD + MfnD_reverse_63f6d - FMfr
#    + FMfr_reverse_c302d - VALTA + VALTA_reverse_1d084 - LEUTA
#    + LEUTA_reverse_0b6fe - ILETA + ILETA_reverse_aec70 - ASPTA
#    + ASPTA_reverse_36525 + ASNS1 - ASNS1_reverse_90309 - LDAPAT
#    + LDAPAT_reverse_81d9c - GLNS + GLNS_reverse_59581 - ACGS
#    + ACGS_reverse_c8939 - ACOTA + ACOTA_reverse_c4379 - ORNTAC
#    + ORNTAC_reverse_b265a + IG3PS - IG3PS_reverse_12008 - HSTPT
#    + HSTPT_reverse_b3657 - PSERT + PSERT_reverse_cbee4 - PHETA1
#    + PHETA1_reverse_9d47a - TYRTA + TYRTA_reverse_e9311 + ANS
#    - ANS_reverse_4e062 + TRPTA - TRPTA_reverse_2159c - ALATA_L
#    + ALATA_L_reverse_e54ff + 2 GLUSfx - 2 GLUSfx_reverse_468d6
#    + 2 GLUS_F420 - 2 GLUS_F420_reverse_2f3dd + CYSTA - CYSTA_reverse_c084d
#    + GLUPRT - GLUPRT_reverse_1f180 + PRFGS - PRFGS_reverse_db4e5 + GMPS2
#    - GMPS2_reverse_aa6c4 + CTPS2 - CTPS2_reverse_9c0ad + PYDXS
#    - PYDXS_reverse_08e1a + GF6PTA - GF6PTA_reverse_21fb1 - 4 PSMNS
#    + 4 PSMNS_reverse_40067 - 4 PSMNS2 + 4 PSMNS2_reverse_3f547 + SUMQ1
#    - SUMQ1_reverse_9ede8 - 0.5363 PROTEIN_MM
#    + 0.5363 PROTEIN_MM_reverse_a6e13 = 0
#  cbp_c: CBPS - CBPS_reverse_80907 - OCBT + OCBT_reverse_f5568 - ASPCT
#    + ASPCT_reverse_c18b9 = 0
#  gtp_c: - MoaA + MoaA_reverse_c94da - MobAB + MobAB_reverse_963b6 - ACBIPGT
#    + ACBIPGT_reverse_bcc45 - 2PLS + 2PLS_reverse_98289 - LPPGS
#    + LPPGS_reverse_081f9 - GF4GL_0 + GF4GL_0_reverse_2c56a - GF4GL_1
#    + GF4GL_1_reverse_9993b - GTPCIII2 + GTPCIII2_reverse_b8b32 - MptA
#    + MptA_reverse_33497 - CF3Sg + CF3Sg_reverse_83c4e - ADSS
#    + ADSS_reverse_c75bb - NTP3 + NTP3_reverse_eac23 + NDPK1
#    - NDPK1_reverse_9216a - ARTRGDP + ARTRGDP_reverse_5bcdf - MAN1PT
#    + MAN1PT_reverse_c317b - NADK1 + NADK1_reverse_a61d5 - GTPCI
#    + GTPCI_reverse_1ee86 - FeoAB + FeoAB_reverse_8a06a - 0.9297 RNA_MM
#    + 0.9297 RNA_MM_reverse_8c539 = 0
#  amet_c: - MoaA + MoaA_reverse_c94da - 2 UPP3MT + 2 UPP3MT_reverse_2adf0
#    - CbiL + CbiL_reverse_f0d0a - CPC3MT + CPC3MT_reverse_c928c - CODSCL4MT
#    + CODSCL4MT_reverse_4b39b - CODSCL5BMT + CODSCL5BMT_reverse_a20e4
#    - CODSCL6BMT2 + CODSCL6BMT2_reverse_1c0e9 - CODSCL7MTDC2
#    + CODSCL7MTDC2_reverse_6e5ac - bzaAB + bzaAB_reverse_d3356 - 2 CofGH
#    + 2 CofGH_reverse_878ef - 2 dhrfapF + 2 dhrfapF_reverse_e7212
#    - 2 dhadrF2 + 2 dhadrF2_reverse_6ad56 + METAT - METAT_reverse_793ef
#    - PFL2 + PFL2_reverse_665e8 - AMAOTr + AMAOTr_reverse_a5426 - 2 BTSMT
#    + 2 BTSMT_reverse_bfa0f - ThiC + ThiC_reverse_ec7a1 - 0.0695 SMP_MM
#    + 0.0695 SMP_MM_reverse_5628c = 0
#  nadh_c: - MoaA + MoaA_reverse_c94da + SHCHD2 - SHCHD2_reverse_d3585
#    - 3 CFBDC + 3 CFBDC_reverse_ce9d2 - CYRDAR + CYRDAR_reverse_9aae4
#    - bzaAB + bzaAB_reverse_d3356 + LCADi - LCADi_reverse_58cdc - DROPPRx
#    + DROPPRx_reverse_fe59b + AHGDx - AHGDx_reverse_81b8f + SLDx
#    - SLDx_reverse_56c15 + HICITD - HICITD_reverse_0ed56 + TIH2CD
#    - TIH2CD_reverse_291f9 + TIH3CD - TIH3CD_reverse_46038 - 7MHS
#    + 7MHS_reverse_c29a9 - DRP2 + DRP2_reverse_e24b0 - MDH
#    + MDH_reverse_ee52c + IPMD - IPMD_reverse_d7a5e + M3MOR
#    - M3MOR_reverse_fd373 - H4THDPR2 + H4THDPR2_reverse_1c503 + HISTDa
#    - HISTDa_reverse_76147 + HISTDb - HISTDb_reverse_acd55 + 2 HISTD
#    - 2 HISTD_reverse_2a63b + PGCD - PGCD_reverse_1bc76 + ALAD_L
#    - ALAD_L_reverse_4f37b - HSDxi + HSDxi_reverse_015b3 + DHQS2
#    - DHQS2_reverse_25089 + PPND - PPND_reverse_5463c + IMPD
#    - IMPD_reverse_6e625 + DHORD72 - DHORD72_reverse_14509 - G1PDH
#    + G1PDH_reverse_cf108 + 2 UACMAMO - 2 UACMAMO_reverse_b0219 + ASPO2
#    - ASPO2_reverse_952c9 - NADHHR + NADHHR_reverse_94a5f + NADHXD
#    - NADHXD_reverse_7b753 + 2 ACALTROS - 2 ACALTROS_reverse_0687f
#    - 0.0419 SMP_MM + 0.0419 SMP_MM_reverse_5628c = 0
#  8cdhg3p_c: MoaA - MoaA_reverse_c94da - MoaC + MoaC_reverse_60792 = 0
#  dad_5_c: MoaA - MoaA_reverse_c94da + bzaAB - bzaAB_reverse_d3356 + 2 CofGH
#    - 2 CofGH_reverse_878ef + PFL2 - PFL2_reverse_665e8 + 2 BTSMT
#    - 2 BTSMT_reverse_bfa0f + ThiC - ThiC_reverse_ec7a1 - DAD5t
#    + DAD5t_reverse_3bb59 = 0
#  met__L_c: MoaA - MoaA_reverse_c94da + bzaAB - bzaAB_reverse_d3356
#    + 2 CofGH - 2 CofGH_reverse_878ef + CoMetS - CoMetS_reverse_8883b
#    - METAT + METAT_reverse_793ef + PFL2 - PFL2_reverse_665e8 + 2 BTSMT
#    - 2 BTSMT_reverse_bfa0f + ThiC - ThiC_reverse_ec7a1 - 0.2426 PROTEIN_MM
#    + 0.2426 PROTEIN_MM_reverse_a6e13 = 0
#  nad_c: MoaA - MoaA_reverse_c94da - SHCHD2 + SHCHD2_reverse_d3585 + 3 CFBDC
#    - 3 CFBDC_reverse_ce9d2 + CYRDAR - CYRDAR_reverse_9aae4 + bzaAB
#    - bzaAB_reverse_d3356 - LCADi + LCADi_reverse_58cdc + DROPPRx
#    - DROPPRx_reverse_fe59b - AHGDx + AHGDx_reverse_81b8f - SLDx
#    + SLDx_reverse_56c15 - HICITD + HICITD_reverse_0ed56 - TIH2CD
#    + TIH2CD_reverse_291f9 - TIH3CD + TIH3CD_reverse_46038 + 7MHS
#    - 7MHS_reverse_c29a9 + DRP2 - DRP2_reverse_e24b0 + MDH
#    - MDH_reverse_ee52c - IPMD + IPMD_reverse_d7a5e - M3MOR
#    + M3MOR_reverse_fd373 + H4THDPR2 - H4THDPR2_reverse_1c503 - HISTDa
#    + HISTDa_reverse_76147 - HISTDb + HISTDb_reverse_acd55 - 2 HISTD
#    + 2 HISTD_reverse_2a63b - PGCD + PGCD_reverse_1bc76 - ALAD_L
#    + ALAD_L_reverse_4f37b + HSDxi - HSDxi_reverse_015b3 - DHQS2
#    + DHQS2_reverse_25089 - PPND + PPND_reverse_5463c - IMPD
#    + IMPD_reverse_6e625 - DHORD72 + DHORD72_reverse_14509 + G1PDH
#    - G1PDH_reverse_cf108 - 2 UACMAMO + 2 UACMAMO_reverse_b0219 - ASPO2
#    + ASPO2_reverse_952c9 + NADS1 - NADS1_reverse_0b93a - NADK
#    + NADK_reverse_bba52 - NADK6 + NADK6_reverse_cfca2 - NADK7
#    + NADK7_reverse_fc6bb - NADK1 + NADK1_reverse_a61d5 - NADK2
#    + NADK2_reverse_52aca + NMNAT - NMNAT_reverse_6a3d7 - 2 ACALTROS
#    + 2 ACALTROS_reverse_0687f - AHZS + AHZS_reverse_05347 - 0.0419 SMP_MM
#    + 0.0419 SMP_MM_reverse_5628c = 0
#  cpmp_c: MoaC - MoaC_reverse_60792 - MoaE + MoaE_reverse_bfb55 = 0
#  ppi_c: MoaC - MoaC_reverse_60792 + MPTAT - MPTAT_reverse_75105 + MobAB
#    - MobAB_reverse_963b6 + GLUTRS - GLUTRS_reverse_b214d + ACBIPGT
#    - ACBIPGT_reverse_bcc45 + LPPGS - LPPGS_reverse_081f9 + FMNAT
#    - FMNAT_reverse_50ba1 + MfnF - MfnF_reverse_bfe43 + MptA
#    - MptA_reverse_33497 + BRFAPS - BRFAPS_reverse_0688b + BRAHPS
#    - BRAHPS_reverse_29b8b + dhrfapF - dhrfapF_reverse_e7212 + DHPS3
#    - DHPS3_reverse_29070 + dhadrprF - dhadrprF_reverse_0c0ca + h2mpt
#    - h2mpt_reverse_44a2f + CF3Sa - CF3Sa_reverse_a566f + CF3Sg
#    - CF3Sg_reverse_83c4e + PPSL - PPSL_reverse_b3b86 + PPNCL2
#    - PPNCL2_reverse_a65ee + PTPATi - PTPATi_reverse_381d9 + ACS
#    - ACS_reverse_37635 + GALUi - GALUi_reverse_c40d5 + ACS2
#    - ACS2_reverse_7bf48 + ASNS1 - ASNS1_reverse_90309 + ARGSS
#    - ARGSS_reverse_5760d + ATPPRT - ATPPRT_reverse_00060 + PRATPP
#    - PRATPP_reverse_99bf0 + SEPRS - SEPRS_reverse_1e742 + SUA5
#    - SUA5_reverse_a15c0 + METAT - METAT_reverse_793ef + PACCOAL
#    - PACCOAL_reverse_e1401 + PACCOAL2 - PACCOAL2_reverse_6ff59 + ANPRT
#    - ANPRT_reverse_e2684 + PACCOAL3 - PACCOAL3_reverse_8bee9 - PPA
#    + PPA_reverse_c5293 + PPA2 - PPA2_reverse_cb6ee + GLUPRT
#    - GLUPRT_reverse_1f180 + GMPS2 - GMPS2_reverse_aa6c4 + GUAPRT
#    - GUAPRT_reverse_ac1f5 + HXPRT - HXPRT_reverse_c7021 + ADPT
#    - ADPT_reverse_567cf + XTPASE - XTPASE_reverse_8b01f + NTPP10
#    - NTPP10_reverse_bcc00 + ITPASE2 - ITPASE2_reverse_c76ab + ADNCYC
#    - ADNCYC_reverse_013dc + ORPT - ORPT_reverse_19432 + UPPRT
#    - UPPRT_reverse_07052 + DCTPD3 - DCTPD3_reverse_b7116 + DUTPDP
#    - DUTPDP_reverse_1eccd + DMATT - DMATT_reverse_3a731 + GRTT
#    - GRTT_reverse_f3afe + FRTT - FRTT_reverse_5200c + 7 TTHCUPD
#    - 7 TTHCUPD_reverse_e30a3 + GGGPS - GGGPS_reverse_0615b + DGGGPS
#    - DGGGPS_reverse_ac03c + CDGGGS - CDGGGS_reverse_55052 + PHYTES
#    - PHYTES_reverse_45da8 + PHYTES2 - PHYTES2_reverse_e5cbe + UAGDP
#    - UAGDP_reverse_a5ec0 + G1PTT - G1PTT_reverse_acd22 + MAN1PT
#    - MAN1PT_reverse_c317b + NNDPR - NNDPR_reverse_445ff + NNATr
#    - NNATr_reverse_8ab73 + NADS1 - NADS1_reverse_0b93a + NMNAT
#    - NMNAT_reverse_6a3d7 + BACCL - BACCL_reverse_8bcde + TMPPP
#    - TMPPP_reverse_f275c + PROTRS - PROTRS_reverse_9d634 + 3.2495 DNA_MM
#    - 3.2495 DNA_MM_reverse_4cdb4 + 3.1072 RNA_MM
#    - 3.1072 RNA_MM_reverse_8c539 = 0
#  h2s_c: - 2 MoaE + 2 MoaE_reverse_bfb55 - CoMF + CoMF_reverse_5047b - CYSS
#    + CYSS_reverse_62727 - AHSERL2 + AHSERL2_reverse_2d820 - HcysS
#    + HcysS_reverse_2b2c4 + CYSDS - CYSDS_reverse_c49c8 + MCPST2
#    - MCPST2_reverse_75c45 + F420SR - F420SR_reverse_93403 - BTSMT
#    + BTSMT_reverse_bfa0f - AHZS + AHZS_reverse_05347 - H2St1
#    + H2St1_reverse_d4fe1 = 0
#  mpt_c: MoaE - MoaE_reverse_bfb55 - MPTAT + MPTAT_reverse_75105
#    - 0.0708 SMP_MM + 0.0708 SMP_MM_reverse_5628c = 0
#  mptamp_c: MPTAT - MPTAT_reverse_75105 - MoeAB + MoeAB_reverse_b752c = 0
#  mobd_c: - MoeAB + MoeAB_reverse_b752c + MOBDabc - MOBDabc_reverse_8421e
#    - 0.1737 SMP_MM + 0.1737 SMP_MM_reverse_5628c = 0
#  moco_c: MoeAB - MoeAB_reverse_b752c - MobAB + MobAB_reverse_963b6 = 0
#  amp_c: MoeAB - MoeAB_reverse_b752c + GLUTRS - GLUTRS_reverse_b214d + HPPK2
#    - HPPK2_reverse_9a03f + dhadrdprF - dhadrdprF_reverse_c4f18 + CF3Ha
#    - CF3Ha_reverse_82e9a + PPSL - PPSL_reverse_b3b86 + ACS
#    - ACS_reverse_37635 + PPS - PPS_reverse_1c319 + ACS2
#    - ACS2_reverse_7bf48 + ASNS1 - ASNS1_reverse_90309 + ARGSS
#    - ARGSS_reverse_5760d + PRPPS - PRPPS_reverse_dd7f2 + SEPRS
#    - SEPRS_reverse_1e742 + TCADES - TCADES_reverse_c4a74 + PACCOAL
#    - PACCOAL_reverse_e1401 + PACCOAL2 - PACCOAL2_reverse_6ff59 + PACCOAL3
#    - PACCOAL3_reverse_8bee9 + GMPS2 - GMPS2_reverse_aa6c4 - NTD7
#    + NTD7_reverse_20dab + ADPT - ADPT_reverse_567cf + ADSL1r
#    - ADSL1r_reverse_2ae14 - ADK1 + ADK1_reverse_a6f90 + PDE1
#    - PDE1_reverse_9a118 + ADPRDP - ADPRDP_reverse_6f5d7 + NADS1
#    - NADS1_reverse_0b93a + NADHXD - NADHXD_reverse_7b753 + NADPHXD
#    - NADPHXD_reverse_e3b94 + 4MPETZS - 4MPETZS_reverse_64c45 + PROTRS
#    - PROTRS_reverse_9d634 = 0
#  gmoco_c: MobAB - MobAB_reverse_963b6 - 0.0321 SMP_MM
#    + 0.0321 SMP_MM_reverse_5628c = 0
#  trnaglu_c: - GLUTRS + GLUTRS_reverse_b214d + GLUTRR - GLUTRR_reverse_355d5
#    = 0
#  glutrna_c: GLUTRS - GLUTRS_reverse_b214d - GLUTRR + GLUTRR_reverse_355d5
#    = 0
#  nadph_c: - GLUTRR + GLUTRR_reverse_355d5 - CPC6R + CPC6R_reverse_d9792
#    - LALDO3 + LALDO3_reverse_60a42 - MDHy + MDHy_reverse_5d499 - GAPDP
#    + GAPDP_reverse_9d791 - KARA2_2 + KARA2_2_reverse_f810a - KARA2
#    + KARA2_reverse_65e99 - ASAD + ASAD_reverse_39a64 - H4THDPR
#    + H4THDPR_reverse_617be - AGPR + AGPR_reverse_5dce4 - HSDy
#    + HSDy_reverse_77ce7 - SHK3Dr + SHK3Dr_reverse_d5c8f + F4NPR
#    - F4NPR_reverse_24f5a - 2 HMGCOAR + 2 HMGCOAR_reverse_c376b - G3PD2
#    + G3PD2_reverse_0c363 - G1PDH2 + G1PDH2_reverse_b7421 - 3 GGDPR
#    + 3 GGDPR_reverse_ea652 - TDPDRR + TDPDRR_reverse_e7bd2 + ASPO2y
#    - ASPO2y_reverse_e5832 - TRDR + TRDR_reverse_6372e - NADPHHR
#    + NADPHHR_reverse_a7929 + NADPHXD - NADPHXD_reverse_e3b94
#    - 0.0375 SMP_MM + 0.0375 SMP_MM_reverse_5628c = 0
#  glu1sa_c: GLUTRR - GLUTRR_reverse_355d5 - G1SAT + G1SAT_reverse_2ec2f = 0
#  nadp_c: GLUTRR - GLUTRR_reverse_355d5 + CPC6R - CPC6R_reverse_d9792
#    + LALDO3 - LALDO3_reverse_60a42 + MDHy - MDHy_reverse_5d499 + GAPDP
#    - GAPDP_reverse_9d791 + KARA2_2 - KARA2_2_reverse_f810a + KARA2
#    - KARA2_reverse_65e99 + ASAD - ASAD_reverse_39a64 + H4THDPR
#    - H4THDPR_reverse_617be + AGPR - AGPR_reverse_5dce4 + HSDy
#    - HSDy_reverse_77ce7 + SHK3Dr - SHK3Dr_reverse_d5c8f - F4NPR
#    + F4NPR_reverse_24f5a + 2 HMGCOAR - 2 HMGCOAR_reverse_c376b + G3PD2
#    - G3PD2_reverse_0c363 + G1PDH2 - G1PDH2_reverse_b7421 + 3 GGDPR
# ...
#  MGS <= 1000
#  MGS_reverse_26e2c = 0
#  E2M <= 1000
#  E2M_reverse_ce7a4 = 0
#  DKFPS2 <= 1000
#  DKFPS2_reverse_fcc87 <= 1000
#  ADHS <= 1000
#  ADHS_reverse_b9ffe <= 1000
#  DHQS2 <= 1000
#  DHQS2_reverse_25089 <= 1000
#  DHQTi <= 1000
#  DHQTi_reverse_c4498 <= 1000
#  SHK3Dr <= 1000
#  SHK3Dr_reverse_d5c8f <= 1000
#  SHKK <= 1000
#  SHKK_reverse_163fd = 0
#  PSCVT <= 1000
#  PSCVT_reverse_1a852 <= 1000
#  CHORS <= 1000
#  CHORS_reverse_17772 = 0
#  CHRPL <= 1000
#  CHRPL_reverse_46f50 = 0
#  PHETA1 <= 1000
#  PHETA1_reverse_9d47a <= 1000
#  PPNDH <= 1000
#  PPNDH_reverse_58300 = 0
#  IOR2 <= 1000
#  IOR2_reverse_c7210 <= 1000
#  PACCOAL <= 1000
#  PACCOAL_reverse_e1401 = 0
#  IOR3 <= 1000
#  IOR3_reverse_c98c8 <= 1000
#  PACCOAL2 <= 1000
#  PACCOAL2_reverse_6ff59 = 0
#  TYRTA <= 1000
#  TYRTA_reverse_e9311 <= 1000
#  PPND <= 1000
#  PPND_reverse_5463c <= 1000
#  CHORM <= 1000
#  CHORM_reverse_38aac = 0
#  ANS2 <= 1000
#  ANS2_reverse_5a40c = 0
#  ANS <= 1000
#  ANS_reverse_4e062 = 0
#  ANPRT <= 1000
#  ANPRT_reverse_e2684 = 0
#  PRAIi <= 1000
#  PRAIi_reverse_e568f <= 1000
#  IGPS <= 1000
#  IGPS_reverse_feb80 = 0
#  TRPS3 <= 1000
#  TRPS3_reverse_bdfbb <= 1000
#  TRPS2 <= 1000
#  TRPS2_reverse_cd73f = 0
#  IOR <= 1000
#  IOR_reverse_9d121 <= 1000
#  TRPTA <= 1000
#  TRPTA_reverse_2159c <= 1000
#  PACCOAL3 <= 1000
#  PACCOAL3_reverse_8bee9 = 0
#  ALATA_L <= 1000
#  ALATA_L_reverse_e54ff <= 1000
#  GLUSfx <= 1000
#  GLUSfx_reverse_468d6 = 0
#  GLUS_F420 <= 1000
#  GLUS_F420_reverse_2f3dd = 0
#  PPA <= 1000
#  PPA_reverse_c5293 <= 1000
#  PPA2 <= 1000
#  PPA2_reverse_cb6ee <= 1000
#  MI1PS <= 1000
#  MI1PS_reverse_72d0d = 0
#  MI1PP <= 1000
#  MI1PP_reverse_76aa8 <= 1000
#  UDPG4E <= 1000
#  UDPG4E_reverse_08c7f <= 1000
#  UDPGALM <= 1000
#  UDPGALM_reverse_dc620 <= 1000
#  HCO3E <= 1000
#  HCO3E_reverse_97ea5 <= 1000
#  SPODM <= 1000
#  SPODM_reverse_2648f = 0
#  CYSDS <= 1000
#  CYSDS_reverse_c49c8 <= 1000
#  HAMR2 <= 1000
#  HAMR2_reverse_de260 = 0
#  CYANST <= 1000
#  CYANST_reverse_46415 <= 1000
#  CYSTA <= 1000
#  CYSTA_reverse_c084d <= 1000
#  MCPST2 <= 1000
#  MCPST2_reverse_75c45 <= 1000
#  FAE <= 1000
#  FAE_reverse_e20a6 <= 1000
#  PPM <= 1000
#  PPM_reverse_4bb1e <= 1000
#  GLUPRT <= 1000
#  GLUPRT_reverse_1f180 <= 1000
#  PPRGL <= 1000
#  PPRGL_reverse_8395f = 0
#  GART <= 1000
#  GART_reverse_61742 = 0
#  PRFGS <= 1000
#  PRFGS_reverse_db4e5 = 0
#  PRAIS <= 1000
#  PRAIS_reverse_8e616 = 0
#  AIRC2 <= 1000
#  AIRC2_reverse_50d74 = 0
#  AIRC3 <= 1000
#  AIRC3_reverse_f015f = 0
#  PRASCSi <= 1000
#  PRASCSi_reverse_11704 = 0
#  ADSL2r <= 1000
#  ADSL2r_reverse_42348 <= 1000
#  AICART2 <= 1000
#  AICART2_reverse_de575 = 0
#  IMPC <= 1000
#  IMPC_reverse_efa41 = 0
#  NTD11 <= 1000
#  NTD11_reverse_39abf <= 1000
#  INSK <= 1000
#  INSK_reverse_93565 = 0
#  IMPD <= 1000
#  IMPD_reverse_6e625 <= 1000
#  GMPS2 <= 1000
#  GMPS2_reverse_aa6c4 = 0
#  NTD9 <= 1000
#  NTD9_reverse_d6a60 <= 1000
#  NTD7 <= 1000
#  NTD7_reverse_20dab <= 1000
#  NTD10 <= 1000
#  NTD10_reverse_8b9f0 <= 1000
#  GSNK <= 1000
#  GSNK_reverse_e6c23 = 0
#  GUAPRT <= 1000
#  GUAPRT_reverse_ac1f5 <= 1000
#  GK1 <= 1000
#  GK1_reverse_11a40 = 0
#  HXPRT <= 1000
#  HXPRT_reverse_c7021 <= 1000
#  ADD <= 1000
#  ADD_reverse_9eeb5 <= 1000
#  ADPT <= 1000
#  ADPT_reverse_567cf <= 1000
#  ADSS <= 1000
#  ADSS_reverse_c75bb = 0
#  ADSL1r <= 1000
#  ADSL1r_reverse_2ae14 <= 1000
#  ADK1 <= 1000
#  ADK1_reverse_a6f90 = 0
#  NTP1 <= 1000
#  NTP1_reverse_46daa = 0
#  NTP2 <= 1000
#  NTP2_reverse_4113e = 0
#  NTP3 <= 1000
#  NTP3_reverse_eac23 = 0
#  NTP4 <= 1000
#  NTP4_reverse_a5bd6 = 0
#  NTP5 <= 1000
#  NTP5_reverse_252e0 = 0
#  NTP6 <= 1000
#  NTP6_reverse_9137c = 0
#  NTP7 <= 1000
#  NTP7_reverse_4a807 = 0
#  NTP8 <= 1000
#  NTP8_reverse_f4a9c = 0
#  NTP9 <= 1000
#  NTP9_reverse_ae219 = 0
#  NDPK1 <= 1000
#  NDPK1_reverse_9216a = 0
#  XTPASE <= 1000
#  XTPASE_reverse_8b01f <= 1000
#  NTPP10 <= 1000
#  NTPP10_reverse_bcc00 <= 1000
#  ITPASE2 <= 1000
#  ITPASE2_reverse_c76ab <= 1000
#  NDPK5 <= 1000
#  NDPK5_reverse_6973f = 0
#  RNDR2 <= 1000
#  RNDR2_reverse_7df82 <= 1000
#  ARTRADP <= 1000
#  ARTRADP_reverse_842bc = 0
#  NDPK8 <= 1000
#  NDPK8_reverse_13dd1 = 0
#  RNDR1 <= 1000
#  RNDR1_reverse_f4be1 <= 1000
#  PFL <= 1000
#  PFL_reverse_af9ec = 0
#  PFL2 <= 1000
#  PFL2_reverse_665e8 <= 1000
#  ADNCYC <= 1000
#  ADNCYC_reverse_013dc = 0
#  PDE1 <= 1000
#  PDE1_reverse_9a118 <= 1000
#  NDPK9 <= 1000
#  NDPK9_reverse_43184 = 0
#  NDPK10 <= 1000
#  NDPK10_reverse_4956a = 0
#  ADPRDP <= 1000
#  ADPRDP_reverse_6f5d7 <= 1000
#  ARTRGDP <= 1000
#  ARTRGDP_reverse_5bcdf = 0
#  ASPCT <= 1000
#  ASPCT_reverse_c18b9 <= 1000
#  DHORTS <= 1000
#  DHORTS_reverse_82d73 <= 1000
#  DHORD72 <= 1000
#  DHORD72_reverse_14509 <= 1000
#  ORPT <= 1000
#  ORPT_reverse_19432 <= 1000
#  OMPDC <= 1000
#  OMPDC_reverse_45ba1 = 0
#  NTD2 <= 1000
#  NTD2_reverse_a3382 <= 1000
#  UPPRT <= 1000
#  UPPRT_reverse_07052 <= 1000
#  UMPK <= 1000
#  UMPK_reverse_ae8e3 = 0
#  NDPK2 <= 1000
#  NDPK2_reverse_10df6 = 0
#  CTPS2 <= 1000
#  CTPS2_reverse_9c0ad = 0
#  CTPS1 <= 1000
#  CTPS1_reverse_0b562 = 0
#  DCTPD2 <= 1000
#  DCTPD2_reverse_164e0 <= 1000
#  NDPK3 <= 1000
#  NDPK3_reverse_37ea6 = 0
#  THEP1 <= 1000
#  THEP1_reverse_a41c4 = 0
#  CYTK1 <= 1000
#  CYTK1_reverse_2fa21 = 0
#  NTD4 <= 1000
#  NTD4_reverse_0e18e <= 1000
#  CYTDK1 <= 1000
#  CYTDK1_reverse_36b6a = 0
#  ARTRCTP <= 1000
#  ARTRCTP_reverse_048d7 = 0
#  ARTRUTP <= 1000
#  ARTRUTP_reverse_6d4b9 = 0
#  DCTPD <= 1000
#  DCTPD_reverse_a48d6 <= 1000
#  DCTPD3 <= 1000
#  DCTPD3_reverse_b7116 = 0
#  DUTPDP <= 1000
#  DUTPDP_reverse_1eccd <= 1000
#  RNDR3 <= 1000
#  RNDR3_reverse_bc84a = 0
#  NDPK7 <= 1000
#  NDPK7_reverse_9dc79 = 0
#  CYTK2 <= 1000
#  CYTK2_reverse_bee82 = 0
#  NTD3 <= 1000
#  NTD3_reverse_6e80d <= 1000
#  NTD1 <= 1000
#  NTD1_reverse_d7db9 <= 1000
#  NTD5 <= 1000
#  NTD5_reverse_28a76 <= 1000
#  NTD8 <= 1000
#  NTD8_reverse_9dc69 <= 1000
#  NTD6 <= 1000
#  NTD6_reverse_c5bce <= 1000
#  RNDR4 <= 1000
#  RNDR4_reverse_aff84 = 0
#  NDPK6 <= 1000
#  NDPK6_reverse_d41ea = 0
#  NDPK4 <= 1000
#  NDPK4_reverse_9a1c8 = 0
#  TMDS <= 1000
#  TMDS_reverse_0a1f4 <= 1000
#  TMDS2 <= 1000
#  TMDS2_reverse_abfb9 <= 1000
#  URIDK2r <= 1000
#  URIDK2r_reverse_1aa74 = 0
#  DTMPK <= 1000
#  DTMPK_reverse_44d5a = 0
#  F420SR <= 1000
#  F420SR_reverse_93403 <= 1000
#  F4H2O <= 1000
#  F4H2O_reverse_acc21 = 0
#  F4NPR <= 1000
#  F4NPR_reverse_24f5a <= 1000
#  FISC <= 1000
#  FISC_reverse_b1b5b <= 1000
#  THIORDXi <= 1000
#  THIORDXi_reverse_27f13 <= 1000
#  ACACT1r <= 1000
#  ACACT1r_reverse_7e2ab <= 1000
#  HMGCOAS <= 1000
#  HMGCOAS_reverse_0d18c <= 1000
#  HMGCOAR <= 1000
#  HMGCOAR_reverse_c376b <= 1000
#  MEVK1 <= 1000
#  MEVK1_reverse_46a93 = 0
#  PMD <= 1000
#  PMD_reverse_ee88c = 0
#  IPK <= 1000
#  IPK_reverse_d42ff = 0
#  IPDDI <= 1000
#  IPDDI_reverse_6c5f9 <= 1000
#  DMATT <= 1000
#  DMATT_reverse_3a731 = 0
#  GRTT <= 1000
#  GRTT_reverse_f3afe = 0
#  FRTT <= 1000
#  FRTT_reverse_5200c = 0
#  TTHCUPD <= 1000
#  TTHCUPD_reverse_e30a3 = 0
#  G3PD2 <= 1000
#  G3PD2_reverse_0c363 <= 1000
#  G1PDH <= 1000
#  G1PDH_reverse_cf108 = 0
#  G1PDH2 <= 1000
#  G1PDH2_reverse_b7421 = 0
#  GGGPS <= 1000
#  GGGPS_reverse_0615b = 0
#  DGGGPS <= 1000
#  DGGGPS_reverse_ac03c = 0
#  CDGGGS <= 1000
#  CDGGGS_reverse_55052 <= 1000
#  CDGGGSAT <= 1000
#  CDGGGSAT_reverse_46571 = 0
#  ATSH2 <= 1000
#  ATSH2_reverse_2ab3f <= 1000
#  AtdenS <= 1000
#  AtdenS_reverse_b6774 = 0
#  AtdensS <= 1000
#  AtdensS_reverse_2bf40 <= 1000
#  CDGGIPT3 <= 1000
#  CDGGIPT3_reverse_b0ce7 = 0
#  AIS <= 1000
#  AIS_reverse_181cc <= 1000
#  ATIH2 <= 1000
#  ATIH2_reverse_f26c7 <= 1000
#  CDGGGPP3 <= 1000
#  CDGGGPP3_reverse_f726b <= 1000
#  DGGPGP <= 1000
#  DGGPGP_reverse_7fc6d <= 1000
#  ATGH2 <= 1000
#  ATGH2_reverse_5dc11 <= 1000
#  SATARFr <= 1000
#  SATARFr_reverse_e1192 <= 1000
#  ARS <= 1000
#  ARS_reverse_a3c26 <= 1000
#  MGAS <= 1000
#  MGAS_reverse_a709b <= 1000
#  DGAS <= 1000
#  DGAS_reverse_be6a2 <= 1000
#  DOGAS <= 1000
#  DOGAS_reverse_3ea27 <= 1000
#  FUDPDGLC <= 1000
#  FUDPDGLC_reverse_497a7 <= 1000
#  CARS <= 1000
#  CARS_reverse_24ade <= 1000
#  GCARS <= 1000
#  GCARS_reverse_e0ab6 <= 1000
#  2GCARS <= 1000
#  2GCARS_reverse_c9167 <= 1000
#  PECARS <= 1000
#  PECARS_reverse_1b82c <= 1000
#  2PECARS <= 1000
#  2PECARS_reverse_18dce <= 1000
#  PICARS <= 1000
#  PICARS_reverse_1a275 <= 1000
#  2GPICARS <= 1000
#  2GPICARS_reverse_e6c45 <= 1000
#  GPECARS <= 1000
#  GPECARS_reverse_5eced <= 1000
#  2GPECARS <= 1000
#  2GPECARS_reverse_eeff2 <= 1000
#  GGDPR <= 1000
#  GGDPR_reverse_ea652 = 0
#  PHYTES <= 1000
#  PHYTES_reverse_45da8 = 0
#  PHYTES2 <= 1000
#  PHYTES2_reverse_e5cbe = 0
#  PYDXS <= 1000
#  PYDXS_reverse_08e1a = 0
#  GF6PTA <= 1000
#  GF6PTA_reverse_21fb1 <= 1000
#  PGAMT <= 1000
#  PGAMT_reverse_52c23 <= 1000
#  G1PACT <= 1000
#  G1PACT_reverse_51580 <= 1000
#  UAGDP <= 1000
#  UAGDP_reverse_a5ec0 <= 1000
#  UAG2E <= 1000
#  UAG2E_reverse_83643 <= 1000
#  UACMAMO <= 1000
#  UACMAMO_reverse_b0219 <= 1000
#  G1PTT <= 1000
#  G1PTT_reverse_acd22 <= 1000
#  TDPGDH <= 1000
#  TDPGDH_reverse_f570d = 0
#  TDPDRE <= 1000
#  TDPDRE_reverse_26405 <= 1000
#  TDPDRR <= 1000
#  TDPDRR_reverse_e7bd2 <= 1000
#  MAN6PI <= 1000
#  MAN6PI_reverse_d96f0 <= 1000
#  PMANM <= 1000
#  PMANM_reverse_53eb0 <= 1000
#  MAN1PT2 <= 1000
#  MAN1PT2_reverse_861e0 = 0
#  MAN1PT <= 1000
#  MAN1PT_reverse_c317b = 0
#  GMAND <= 1000
#  GMAND_reverse_b3087 <= 1000
#  TRE6PS <= 1000
#  TRE6PS_reverse_96346 <= 1000
#  TRE6PP <= 1000
#  TRE6PP_reverse_4fe3e <= 1000
#  ASPO2 <= 1000
#  ASPO2_reverse_952c9 = 0
#  ASPO2y <= 1000
#  ASPO2y_reverse_e5832 = 0
#  OAAS <= 1000
#  OAAS_reverse_c5168 <= 1000
#  QULNS <= 1000
#  QULNS_reverse_66da1 = 0
#  NNDPR <= 1000
#  NNDPR_reverse_445ff <= 1000
#  NNATr <= 1000
#  NNATr_reverse_8ab73 = 0
#  NADS1 <= 1000
#  NADS1_reverse_0b93a = 0
#  NADK <= 1000
#  NADK_reverse_bba52 = 0
#  NADK6 <= 1000
#  NADK6_reverse_cfca2 <= 1000
#  NADK7 <= 1000
#  NADK7_reverse_fc6bb <= 1000
#  NADK1 <= 1000
#  NADK1_reverse_a61d5 = 0
#  NADK2 <= 1000
#  NADK2_reverse_52aca = 0
#  NICRNSS <= 1000
#  NICRNSS_reverse_fe7b5 <= 1000
#  NMNAT <= 1000
#  NMNAT_reverse_6a3d7 <= 1000
#  NMNHYD <= 1000
#  NMNHYD_reverse_d7656 <= 1000
#  TRDR <= 1000
#  TRDR_reverse_6372e <= 1000
#  NADHHR <= 1000
#  NADHHR_reverse_94a5f <= 1000
#  NADPHHR <= 1000
#  NADPHHR_reverse_a7929 <= 1000
#  NADHXE <= 1000
#  NADHXE_reverse_0862f <= 1000
#  NADPHXE <= 1000
#  NADPHXE_reverse_23992 <= 1000
#  NADHXD <= 1000
#  NADHXD_reverse_7b753 = 0
#  NADPHXD <= 1000
#  NADPHXD_reverse_e3b94 = 0
#  UAG4Ei <= 1000
#  UAG4Ei_reverse_6dc84 <= 1000
#  ACGALS <= 1000
#  ACGALS_reverse_bcf5c <= 1000
#  ACALTROS <= 1000
#  ACALTROS_reverse_0687f <= 1000
#  NACTALS <= 1000
#  NACTALS_reverse_6b6c6 <= 1000
#  UACNACS <= 1000
#  UACNACS_reverse_1313a <= 1000
#  PSMNS <= 1000
#  PSMNS_reverse_40067 = 0
#  UGALNACS <= 1000
#  UGALNACS_reverse_4fa33 <= 1000
#  PSMNS2 <= 1000
#  PSMNS2_reverse_3f547 = 0
#  NIT1b2 <= 1000
#  NIT1b2_reverse_497d5 = 0
#  AKSCAL <= 1000
#  AKSCAL_reverse_d673f = 0
#  AOXSr <= 1000
#  AOXSr_reverse_6edad <= 1000
#  AMAOTr <= 1000
#  AMAOTr_reverse_a5426 <= 1000
#  DBTS <= 1000
#  DBTS_reverse_b5da6 = 0
#  BTSMT <= 1000
#  BTSMT_reverse_bfa0f <= 1000
#  BACCL <= 1000
#  BACCL_reverse_8bcde = 0
#  ThiC <= 1000
#  ThiC_reverse_ec7a1 <= 1000
#  HMPK1 <= 1000
#  HMPK1_reverse_8f692 = 0
#  PMPK <= 1000
#  PMPK_reverse_48b12 = 0
#  AHZS <= 1000
#  AHZS_reverse_05347 <= 1000
#  4MPETZS <= 1000
#  4MPETZS_reverse_64c45 <= 1000
#  TMPPP <= 1000
#  TMPPP_reverse_f275c <= 1000
#  TMPK <= 1000
#  TMPK_reverse_b7673 = 0
#  PGLYCP <= 1000
#  PGLYCP_reverse_9063f <= 1000
#  GTPCI <= 1000
#  GTPCI_reverse_1ee86 = 0
#  CPH4S <= 1000
#  CPH4S_reverse_542c3 <= 1000
#  CDGS <= 1000
#  CDGS_reverse_6b7cb <= 1000
#  CCGS <= 1000
#  CCGS_reverse_3ff79 = 0
#  SUMQ1 <= 1000
#  SUMQ1_reverse_9ede8 <= 1000
#  NIabc <= 1000
#  NIabc_reverse_e360a = 0
#  Coabc <= 1000
#  Coabc_reverse_75cd4 = 0
#  FeoAB <= 1000
#  FeoAB_reverse_8a06a = 0
#  FE2abc <= 1000
#  FE2abc_reverse_2a151 = 0
#  ZNabc <= 1000
#  ZNabc_reverse_ce569 = 0
#  ZNabc2 <= 1000
#  ZNabc2_reverse_d0111 = 0
#  MGt5 <= 1000
#  MGt5_reverse_4dbb6 = 0
#  MG2abc <= 1000
#  MG2abc_reverse_07a52 = 0
#  CA2abc <= 1000
#  CA2abc_reverse_259e7 = 0
#  TrkAH <= 1000
#  TrkAH_reverse_45c63 <= 1000
#  MOBDabc <= 1000
#  MOBDabc_reverse_8421e = 0
#  WO4abc <= 1000
#  WO4abc_reverse_ab45f = 0
#  PIabc <= 1000
#  PIabc_reverse_a066e = 0
#  Eha <= 1000
#  Eha_reverse_5bd35 = 0
#  Ehb <= 1000
#  Ehb_reverse_822cd = 0
#  CO2t <= 1000
#  CO2t_reverse_7c42f <= 1000
#  CH4t <= 1000
#  CH4t_reverse_be7dd <= 1000
#  tH2 <= 1000
#  tH2_reverse_484e3 <= 1000
#  tBTN <= 1000
#  tBTN_reverse_f73d2 <= 1000
#  t2DGLC <= 1000
#  t2DGLC_reverse_73555 <= 1000
#  N2tr <= 1000
#  N2tr_reverse_d0650 <= 1000
#  PROt4 <= 1000
#  PROt4_reverse_bb8de <= 1000
#  Cuabc <= 1000
#  Cuabc_reverse_46883 = 0
#  Cut1 <= 1000
#  Cut1_reverse_225a4 = 0
#  CD2abc1 <= 1000
#  CD2abc1_reverse_18837 = 0
#  CD2abc2 <= 1000
#  CD2abc2_reverse_ce124 = 0
#  NH3te <= 1000
#  NH3te_reverse_b9f06 <= 1000
#  CYSt2r <= 1000
#  CYSt2r_reverse_6167b <= 1000
#  H2Ot <= 1000
#  H2Ot_reverse_aa560 <= 1000
#  H2St1 <= 1000
#  H2St1_reverse_d4fe1 <= 1000
#  COt <= 1000
#  COt_reverse_7eacb <= 1000
#  PACt2r <= 1000
#  PACt2r_reverse_707ab <= 1000
#  HPACt2r <= 1000
#  HPACt2r_reverse_dcbf5 <= 1000
#  IND3ACt2r <= 1000
#  IND3ACt2r_reverse_24b6b <= 1000
#  ACt2r <= 1000
#  ACt2r_reverse_64e05 <= 1000
#  5AOPt2 <= 1000
#  5AOPt2_reverse_4b80e <= 1000
#  PYRt <= 1000
#  PYRt_reverse_6fee7 <= 1000
#  FUMtr = 0
#  FUMtr_reverse_2b374 <= 1000
#  SUCCt = 0
#  SUCCt_reverse_2898f <= 1000
#  4ABZt2r <= 1000
#  4ABZt2r_reverse_8aa72 <= 1000
#  GLYC_Rt <= 1000
#  GLYC_Rt_reverse_11248 <= 1000
#  HPPt <= 1000
#  HPPt_reverse_7a7b6 <= 1000
#  NCAMt <= 1000
#  NCAMt_reverse_1ad6a <= 1000
#  UREAt <= 1000
#  UREAt_reverse_2c990 <= 1000
#  NACt <= 1000
#  NACt_reverse_82f9f <= 1000
#  GCALDt <= 1000
#  GCALDt_reverse_689f8 <= 1000
#  DHGLYt <= 1000
#  DHGLYt_reverse_8d6fa <= 1000
#  AMOBt <= 1000
#  AMOBt_reverse_a29ad <= 1000
#  ACALDt <= 1000
#  ACALDt_reverse_858fa <= 1000
#  DAD5t <= 1000
#  DAD5t_reverse_3bb59 <= 1000
#  PROTRS <= 1000
#  PROTRS_reverse_9d634 = 0
#  ATPM <= 1000
#  ATPM_reverse_5b752 = 0
#  PROTEIN_MM <= 1000
#  PROTEIN_MM_reverse_a6e13 = 0
#  DNA_MM <= 1000
#  DNA_MM_reverse_4cdb4 = 0
#  RNA_MM <= 1000
#  RNA_MM_reverse_8c539 = 0
#  SMP_MM <= 1000
#  SMP_MM_reverse_5628c = 0
#  LIPID_MM <= 1000
#  LIPID_MM_reverse_bee0c = 0
#  CELLWALL_MM <= 1000
#  CELLWALL_MM_reverse_cab57 = 0
#  BIOMASS_MM <= 1000
#  BIOMASS_MM_reverse_1bc28 = 0
#  BIOMASSt_MM <= 1000
#  BIOMASSt_MM_reverse_bf70a = 0
#  FDH_F420 <= 1000
#  FDH_F420_reverse_9344b <= 1000
#  FORt <= 1000
#  FORt_reverse_40f9f <= 1000
#  EX_hpp_e <= 1000
#  EX_hpp_e_reverse_20f15 <= 1000
#  EX_dhgly_e <= 1000
#  EX_dhgly_e_reverse_625d4 <= 1000
#  EX_acald_e <= 1000
#  EX_acald_e_reverse_c096e <= 1000
#  EX_nac_e <= 1000
#  EX_nac_e_reverse_23356 <= 1000
#  EX_gcald_e <= 1000
#  EX_gcald_e_reverse_a5965 <= 1000
#  EX_urea_e <= 1000
#  EX_urea_e_reverse_02f51 <= 1000
#  EX_amob_e <= 1000
#  EX_amob_e_reverse_266bd <= 1000
#  EX_biomass_e <= 1000
#  EX_biomass_e_reverse_5e4c9 <= 1000
#  EX_ncam_e <= 1000
#  EX_ncam_e_reverse_be287 <= 1000
#  EX_co2_e <= 1000
#  EX_co2_e_reverse_d0466 <= 1000
#  EX_ch4_e <= 1000
#  EX_ch4_e_reverse_48b92 <= 1000
#  EX_h2_e <= 1000
#  EX_h2_e_reverse_f55e9 <= 1000
#  EX_ni2_e <= 1000
#  EX_ni2_e_reverse_7ba33 <= 1000
#  EX_cobalt2_e <= 1000
#  EX_cobalt2_e_reverse_2bf0e <= 1000
#  EX_fe2_e <= 1000
#  EX_fe2_e_reverse_25e68 <= 1000
#  EX_zn2_e <= 1000
#  EX_zn2_e_reverse_3c725 <= 1000
#  EX_mg2_e <= 1000
#  EX_mg2_e_reverse_b1c98 <= 1000
#  EX_ca2_e <= 1000
#  EX_ca2_e_reverse_aac13 <= 1000
#  EX_k_e <= 1000
#  EX_k_e_reverse_42613 <= 1000
#  EX_mobd_e <= 1000
#  EX_mobd_e_reverse_c6396 <= 1000
#  EX_tungs_e <= 1000
#  EX_tungs_e_reverse_6ffff <= 1000
#  EX_na1_e <= 1000
#  EX_na1_e_reverse_c64df <= 1000
#  EX_pi_e <= 1000
#  EX_pi_e_reverse_1fb09 <= 1000
#  EX_h_e <= 1000
#  EX_h_e_reverse_3e0c5 <= 1000
#  EX_ppa_e <= 1000
#  EX_ppa_e_reverse_1faa3 <= 1000
#  EX_btn_e <= 1000
#  EX_btn_e_reverse_f2678 <= 1000
#  EX_2dglc_e <= 1000
#  EX_2dglc_e_reverse_eec03 <= 1000
#  EX_n2_e <= 1000
#  EX_n2_e_reverse_7780c <= 1000
#  EX_cys__L_e <= 1000
#  EX_cys__L_e_reverse_41339 <= 1000
#  EX_h2o_e <= 1000
#  EX_h2o_e_reverse_3ced4 <= 1000
#  EX_glyc__R_e <= 1000
#  EX_glyc__R_e_reverse_91560 <= 1000
#  EX_nh3_e <= 1000
#  EX_nh3_e_reverse_06cf9 <= 1000
#  EX_for_e <= 1000
#  EX_for_e_reverse_23269 <= 1000
#  EX_ac_e <= 1000
#  EX_ac_e_reverse_0be96 <= 1000
#  EX_5aop_e <= 1000
#  EX_5aop_e_reverse_6a527 <= 1000
#  EX_pyr_e <= 1000
#  EX_pyr_e_reverse_1f6de <= 1000
#  EX_succ_e <= 1000
#  EX_succ_e_reverse_a9039 <= 1000
#  EX_co_e <= 1000
#  EX_co_e_reverse_467c4 <= 1000
#  EX_h2s_e <= 1000
#  EX_h2s_e_reverse_c847c <= 1000
#  EX_pac_e <= 1000
#  EX_pac_e_reverse_62225 <= 1000
#  EX_4hphac_e <= 1000
#  EX_4hphac_e_reverse_c8444 <= 1000
#  EX_ind3ac_e <= 1000
#  EX_ind3ac_e_reverse_c3f48 <= 1000
#  EX_4abz_e <= 1000
#  EX_4abz_e_reverse_947a6 <= 1000
#  EX_fum_e <= 1000
#  EX_fum_e_reverse_e3432 <= 1000
#  EX_pro__L_e <= 1000
#  EX_pro__L_e_reverse_5f8c5 <= 1000
#  EX_dad_5_e <= 1000
#  EX_dad_5_e_reverse_f8e65 <= 1000
# End

# %% [markdown]
# ## Checks For Rxn Balance

# %%
# Values lower than zero indicate missing atoms on the product side 
#whereas positive values indicate missing atoms on the substrate side
# to add a metabolite to the substrate side, the coefficient should be less than zero
# to add a metabolite to the product side, the coefficient should be greater than zero
rxnBalanced(model)
# Out:
# The mass and/or charge is not balanced in rxn PROTEIN_MM
# Balance:  {'charge': -0.07839999999999492, 'C': -44.38330000000002, 'H': -88.98930000000001, 'N': -12.419299999999993, 'O': -22.22220000000013, 'S': -0.38570000000000004, 'P': -7.105427357601002e-15}
# The mass and/or charge is not balanced in rxn DNA_MM
# Balance:  {'charge': -0.0002999999999993008, 'C': -31.70360000000001, 'H': -39.827, 'N': -12.1633, 'O': -19.4957, 'P': -3.249200000000001}
# The mass and/or charge is not balanced in rxn RNA_MM
# Balance:  {'charge': -1.5543122344752192e-15, 'C': -29.621599999999994, 'H': -36.52440000000001, 'N': -11.8732, 'O': -21.78529999999999, 'P': -3.107199999999998}
# The mass and/or charge is not balanced in rxn SMP_MM
# Balance:  {'charge': -4.440899999999999, 'C': -26.574799999999996, 'H': -35.9709, 'N': -6.7433, 'Ni': -0.24509999999999998, 'O': -15.1221, 'P': -1.3828999999999998, 'S': -0.9665000000000001, 'Fe': -0.5281, 'Co': -0.489, 'Zn': -0.4247, 'Mg': -1.1429, 'Ca': -0.6931, 'K': -0.7105, 'Mo': -0.20579999999999998, 'W': -0.1121}
# The mass and/or charge is not balanced in rxn LIPID_MM
# Balance:  {'charge': 0.015200000000000002, 'C': -59.3645, 'H': -118.20320000000001, 'N': -0.1436, 'O': -10.144500000000004, 'P': -0.1888}
# The mass and/or charge is not balanced in rxn CELLWALL_MM
# Balance:  {'charge': 2.2836, 'C': -39.962999999999994, 'H': -60.5154, 'N': -7.9925999999999995, 'O': -21.6942}
# The mass and/or charge is not balanced in rxn EX_hpp_e
# Balance:  {'charge': 2.0, 'C': -3.0, 'H': -3.0, 'O': -6.0, 'P': -1.0}
# The mass and/or charge is not balanced in rxn EX_dhgly_e
# Balance:  {'C': -2.0, 'H': -3.0, 'N': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_acald_e
# Balance:  {'C': -2.0, 'H': -4.0, 'O': -1.0}
# The mass and/or charge is not balanced in rxn EX_nac_e
# Balance:  {'charge': 1.0, 'C': -6.0, 'H': -4.0, 'N': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_gcald_e
# Balance:  {'C': -2.0, 'H': -4.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_urea_e
# Balance:  {'C': -1.0, 'H': -4.0, 'N': -2.0, 'O': -1.0}
# The mass and/or charge is not balanced in rxn EX_amob_e
# Balance:  {'C': -15.0, 'H': -19.0, 'N': -5.0, 'O': -6.0, 'S': -1.0}
# The mass and/or charge is not balanced in rxn EX_ncam_e
# Balance:  {'C': -6.0, 'H': -6.0, 'N': -2.0, 'O': -1.0}
# The mass and/or charge is not balanced in rxn EX_co2_e
# Balance:  {'C': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_ch4_e
# Balance:  {'C': -1.0, 'H': -4.0}
# The mass and/or charge is not balanced in rxn EX_h2_e
# Balance:  {'H': -2.0}
# The mass and/or charge is not balanced in rxn EX_ni2_e
# Balance:  {'charge': -2.0, 'Ni': -1.0}
# The mass and/or charge is not balanced in rxn EX_cobalt2_e
# Balance:  {'charge': -2.0, 'Co': -1.0}
# The mass and/or charge is not balanced in rxn EX_fe2_e
# Balance:  {'charge': -2.0, 'Fe': -1.0}
# The mass and/or charge is not balanced in rxn EX_zn2_e
# Balance:  {'charge': -2.0, 'Zn': -1.0}
# The mass and/or charge is not balanced in rxn EX_mg2_e
# Balance:  {'charge': -2.0, 'Mg': -1.0}
# The mass and/or charge is not balanced in rxn EX_ca2_e
# Balance:  {'charge': -2.0, 'Ca': -1.0}
# The mass and/or charge is not balanced in rxn EX_k_e
# Balance:  {'charge': -1.0, 'K': -1.0}
# The mass and/or charge is not balanced in rxn EX_mobd_e
# Balance:  {'charge': 2.0, 'Mo': -1.0, 'O': -4.0}
# The mass and/or charge is not balanced in rxn EX_tungs_e
# Balance:  {'charge': 2.0, 'O': -4.0, 'W': -1.0}
# The mass and/or charge is not balanced in rxn EX_na1_e
# Balance:  {'charge': -1.0, 'Na': -1.0}
# The mass and/or charge is not balanced in rxn EX_pi_e
# Balance:  {'charge': 2.0, 'H': -1.0, 'O': -4.0, 'P': -1.0}
# The mass and/or charge is not balanced in rxn EX_h_e
# Balance:  {'charge': -1.0, 'H': -1.0}
# The mass and/or charge is not balanced in rxn EX_ppa_e
# Balance:  {'charge': 1.0, 'C': -3.0, 'H': -5.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_btn_e
# Balance:  {'charge': 1.0, 'C': -10.0, 'H': -15.0, 'N': -2.0, 'O': -3.0, 'S': -1.0}
# The mass and/or charge is not balanced in rxn EX_2dglc_e
# Balance:  {'C': -6.0, 'H': -12.0, 'O': -5.0}
# The mass and/or charge is not balanced in rxn EX_n2_e
# Balance:  {'N': -2.0}
# The mass and/or charge is not balanced in rxn EX_cys__L_e
# Balance:  {'C': -3.0, 'H': -7.0, 'N': -1.0, 'O': -2.0, 'S': -1.0}
# The mass and/or charge is not balanced in rxn EX_h2o_e
# Balance:  {'H': -2.0, 'O': -1.0}
# The mass and/or charge is not balanced in rxn EX_glyc__R_e
# Balance:  {'charge': 1.0, 'C': -3.0, 'H': -5.0, 'O': -4.0}
# The mass and/or charge is not balanced in rxn EX_nh3_e
# Balance:  {'charge': -1.0, 'H': -4.0, 'N': -1.0}
# The mass and/or charge is not balanced in rxn EX_for_e
# Balance:  {'charge': 1.0, 'C': -1.0, 'H': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_ac_e
# Balance:  {'charge': 1.0, 'C': -2.0, 'H': -3.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_5aop_e
# Balance:  {'C': -5.0, 'H': -9.0, 'N': -1.0, 'O': -3.0}
# The mass and/or charge is not balanced in rxn EX_pyr_e
# Balance:  {'charge': 1.0, 'C': -3.0, 'H': -3.0, 'O': -3.0}
# The mass and/or charge is not balanced in rxn EX_succ_e
# Balance:  {'charge': 2.0, 'C': -4.0, 'H': -4.0, 'O': -4.0}
# The mass and/or charge is not balanced in rxn EX_co_e
# Balance:  {'charge': -1.0, 'C': -1.0, 'H': -1.0, 'O': -1.0}
# The mass and/or charge is not balanced in rxn EX_h2s_e
# Balance:  {'charge': 1.0, 'H': -1.0, 'S': -1.0}
# The mass and/or charge is not balanced in rxn EX_pac_e
# Balance:  {'C': -8.0, 'H': -8.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_4hphac_e
# Balance:  {'C': -8.0, 'H': -8.0, 'O': -3.0}
# The mass and/or charge is not balanced in rxn EX_ind3ac_e
# Balance:  {'charge': 1.0, 'C': -10.0, 'H': -8.0, 'N': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_4abz_e
# Balance:  {'charge': 1.0, 'C': -7.0, 'H': -6.0, 'N': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_fum_e
# Balance:  {'charge': 2.0, 'C': -4.0, 'H': -2.0, 'O': -4.0}
# The mass and/or charge is not balanced in rxn EX_pro__L_e
# Balance:  {'C': -5.0, 'H': -9.0, 'N': -1.0, 'O': -2.0}
# The mass and/or charge is not balanced in rxn EX_dad_5_e
# Balance:  {'C': -10.0, 'H': -13.0, 'N': -5.0, 'O': -3.0}
# Number of unbalanced reactions is:  51

# %% [markdown]
# # Part 1: Prepare model for general use

# %% [markdown]
# # Turn off multiple option pathways (stylistic)

# %%
# reaction written together/apart (stylistic)
model.reactions.get_by_id("HISTDa").bounds = (0,0)
model.reactions.get_by_id("HISTDb").bounds = (0,0)
# model.reactions.get_by_id("HISTD").bounds = (0,0) # combined version

# model.reactions.CODH2.bounds = (0,0) # required to be on for growth on CO
# model.reactions.ACS3.bounds = (0,0) # required to be on for growth on CO
model.reactions.CODHr2.bounds = (0,0) # combined version (doesn't work for growth on CO)

# alternative to PFL, but accounting for activating enzymes (technically only present in DH)
model.reactions.get_by_id("PFL2").bounds = (0,0)

# %% [markdown]
# # Make model reaction wise microbe specific

# %%
# For ALL
# model.reactions.Ehb.bounds = (0,0) # want only one active (Eha)
# model.reactions.get_by_id("HMD").bounds = (-1000,1000) #(not sure if it should be zero) Also prevents loops
# model.reactions.get_by_id("MTD").bounds = (-1000,1000) # Also prevents loops
# model.reactions.FRH.bounds = (0,1000)
#--------------------------------------------------------------------------------------------------------------
# Make bounds (0,0) for DH and ZZ

# # Methanopepterin Biosynthesis (methylation at different point)
# # The following reactions that are turned off are for the Marburgensis, so when using MM we can comment them out
# model.reactions.get_by_id("DHPS3").bounds = (0,0) #(dhrfapF equivalent for Marburgensis)
# model.reactions.get_by_id("H4MPTS9").bounds = (0,0) # (dhadrpF equivalent for Marburgensis)
# model.reactions.get_by_id("dhadrF2").bounds = (0,0) # (dhadrF equivalent for Marburgensis)

# # Psuedomurein Biosynthesis (Galactosamine -Marburg vs glucosamine at different point)
# # The following reactions that are turned off are for the Z-245 and DH
# model.reactions.get_by_id("UGALNACS").bounds = (0,0) # UACNACS equivalent for Marburgensis
# model.reactions.get_by_id("PSMNS2").bounds = (0,0) # PSMNS equivalent for Marburgensis

#---------------------------------------------------------------------------------------------------------------
# Make bounds (0,0) for MM

# Methanopepterin Biosynthesis (methylation at different point)
# The following reactions that are turned off are for the Z-245 and DH, so when using DH/ZZ we can comment them out
model.reactions.get_by_id("dhrfapF").bounds = (0,0) #(DHPS3 equivalent for DH/Z-245)
model.reactions.get_by_id("dhadrpF").bounds = (0,0) # (H4MPTS9 equivalent for DH/Z-245)
model.reactions.get_by_id("dhadrF").bounds = (0,0) # (dhadrF2 equivalent for DH/Z-245)

# Psuedomurein Biosynthesis (Galactosamine -Marburg vs glucosamine at different point)
# The following reactions that are turned off are for the Marburgensis
model.reactions.get_by_id("UACNACS").bounds = (0,0) # UGALNACS equivalent for DH/Z-245
model.reactions.get_by_id("PSMNS").bounds = (0,0) # PSMNS2 equivalent for DH/Z-245

# homologus genes not found for MM
model.reactions.get_by_id("RNDR1").bounds = (0,0) # no gene in Marburg?
model.reactions.get_by_id("RNDR2").bounds = (0,0) # no gene in Marburg?
model.reactions.get_by_id("RNDR3").bounds = (0,0) # no gene in Marburg?
model.reactions.get_by_id("RNDR4").bounds = (0,0) # no gene in Marburg?
model.reactions.PFL.bounds = (0,0) # only in DH (0,1000) otherwise makes loop
model.reactions.PFL2.bounds = (0,0) # only in DH (0,1000) otherwise makes loop
#-----------------------------------------------------------------------------

# # Make bounds (0,0) for ZZ
# model.reactions.PFL.bounds = (0,0) # only in DH (0,1000) otherwise makes loop
# model.reactions.PFL2.bounds = (0,0) # only in DH (0,1000) otherwise makes loop

# Make bounds (0,0) for DH/MM and ZZ not grown on formate

# Energy Metabolism
model.reactions.get_by_id("FDH_F420").bounds = (0,0) # (-1000,1000) ONLY Z-245

# %% [markdown]
# # Define standard media with bounds differences by microbe
# Doesn't include energy sources

# %%
# For all microbes make the bounds (0,0) unless added to media
model.reactions.get_by_id("EX_4abz_e").bounds = (0,0) # this can be used as alternative to 4hbz_c (BRAHPS) (if added to media)
model.reactions.get_by_id("EX_4hphac_e").bounds = (0,0) # assimiliation of 4-Hydroxyphenylacetate (if added to media, in maripaludis)
model.reactions.get_by_id("EX_btn_e").bounds = (0,0) # assimiliation biotin (if added to media)
model.reactions.get_by_id("EX_ind3ac_e").bounds = (0,0) # assimiliation of Indole-3-acetate (if added to media, in maripaludis)

# DH and ZZ can never use, but MM can when provided (not standard media)
model.reactions.get_by_id("EX_ppa_e").bounds = (0,0) # ONLY MARBURGENSIS - exchange of propanoate (if added to media)
model.reactions.get_by_id("EX_pyr_e").bounds = (0,0) # ONLY MARBURGENSIS - assimiliation of pyruvate (if added to media, only by Marburgensis)
model.reactions.get_by_id("EX_5aop_e").bounds = (0,0) # ONLY MARBURGENSIS - assimiliation of 5 Aminolevulinate (if added to media, only by Marburgensis)
model.reactions.get_by_id("EX_fum_e").bounds = (0,0) # ONLY MARBURGENSIS - assimiliation of fumarate (if added to media, only by Marburgensis)
model.reactions.get_by_id("EX_succ_e").bounds = (0,0) # ONLY MARBURGENSIS - assimiliation of succinate (if added to media, only by Marburgensis)
model.reactions.get_by_id("EX_pac_e").bounds = (0,0) # ONLY MARBURGENSIS - assimiliation of phenylacetate (if added to media, evidence only in Marburgensis)
model.reactions.get_by_id("EX_pro__L_e").bounds = (0,0) # none added to the model and none measured...
model.reactions.get_by_id("EX_ac_e").bounds = (0,0) # MARBURGENSIS and maybe Z-245 - assimiliation of acetate (if added to media, only in Marburgensis, and Z-245)

# %% [markdown]
# # Growth constrained Energy/Carbon/Sulfur sources

# %%
# Energy (electron) sources
model.reactions.get_by_id("EX_h2_e").bounds = (-1000,0)

# Carbon sources
model.reactions.get_by_id("EX_co2_e").bounds = (-1000,0)

# Energy + Carbon souces
#Growth on formate requires the FDH_F420 (-1000,1000) and for CO2 to be let out (0,1000)
model.reactions.get_by_id("EX_for_e").bounds = (0,0) # ONLY Z-245 (or Marburgensis for assimiliation/growth of formate (if added to media, evidence only in Marburgensis (assimilation) and Z-245 (growth))
model.reactions.get_by_id("EX_co_e").bounds = (0,0) # assimiliation carbon monoxide (if added to gas, only by Marburgensis)
# for growth on CO
# model.reactions.Eha.bounds = (0,1000) # (-1000,1000) for CO otherwise (0,1000)

# Sulfur Sources
model.reactions.get_by_id("EX_cys__L_e").bounds = (-0.0145,1000) # 0.0145 assimiliation of cysteine (H2S must be left open?)
model.reactions.get_by_id("EX_h2s_e").bounds = (-1000,1000) # 

# Nitrogen Sources
model.reactions.get_by_id("EX_nh3_e").bounds = (-1000,1000) # not quantifiable
model.reactions.get_by_id("EX_n2_e").bounds = (0,0) # assimiliation of nitrogen (if added to gas)

# %% [markdown]
# # Limit Products

# %%
model.reactions.get_by_id("EX_ch4_e").bounds = (0,1000)
model.reactions.get_by_id("EX_biomass_e").bounds = (0,1000)

# %% [markdown]
# # Initalize ATPM reaction

# %%
model.reactions.get_by_id("ATPM").bounds = (1.5,1000)

# %% [markdown]
# # End part 1 with general constraints
# Using the constraints provided above, the model should be able to predict general phenotypes
# It will consume lots of cysteine if it is not constrained.

# %% [markdown]
# # Part 2: Experimental Data

# %% [markdown]
# ## FBA

# %%
# Define objective function
obj = {model.reactions.get_by_id("EX_biomass_e"):1}
# obj = {model.reactions.get_by_id("ATPM"):1}
model.objective = obj

# %%
# Defining ATPM
model.reactions.get_by_id("ATPM").bounds = (1.5,1000)
# model.reactions.get_by_id("ATPM").bounds = (23.5,23.5) #21.381

# ZZ
# model.reactions.get_by_id("ATPM").bounds = (15.01953,1000)

# %%
# From run F6_2
# Adjusted for dissolved CO2 but dropping all time points that are thought to be gross measurement error 
# AND the remaining points adjusted for mass balance (keeping dilution rate the same… not sure how to change that)

# DH AVG
# h2_exp = -175.41 #91.43
# co2_exp = -44.80 #22.87
# ch4_exp = 42.88 #22.85
# biomass_exp = 0.046 #0.002
# error = 0.001

# # ZZ AVG
# h2_exp = -117.73 #41.89
# #co2_exp = -28.47 #10.46 OLD old error 0.125
# #ch4_exp = 34.14 #6.05 OLD old error 0.125

# co2_exp = -30.37 #10.48
# ch4_exp = 28.47 #10.46
# biomass_exp = 0.045 #0.001
# error = 0.001

# MM AVG
h2_exp = -130.43 #17.12
co2_exp = -33.58 #4.28
ch4_exp = 31.61 #4.28
biomass_exp = 0.047 #0.001
error = 0.005

h2 = h2_exp
co2 = co2_exp
ch4 = ch4_exp
bm = biomass_exp


# Energy (electron) sources
model.reactions.get_by_id("EX_h2_e").bounds = (h2+h2*error,h2-h2*error)

# Carbon sources
model.reactions.get_by_id("EX_co2_e").bounds = (co2+co2*error,co2-co2*error)
model.reactions.get_by_id("EX_ac_e").bounds = (0,0)

# Energ + Carbon souces
#Formate requires the FDH_F420 (0,1000) and for CO2 to be let out
model.reactions.get_by_id("EX_for_e").bounds = (0,0)
model.reactions.get_by_id("EX_co_e").bounds = (0,0)

# Sulfur Sources
model.reactions.get_by_id("EX_cys__L_e").bounds = (-0.0145,1000)
model.reactions.get_by_id("EX_h2s_e").bounds = (-1000,1000)

# Nitrogen Sources
model.reactions.get_by_id("EX_nh3_e").bounds = (-1000,1000) # not quantifiable
model.reactions.get_by_id("EX_n2_e").bounds = (0,0) # assimiliation of nitrogen (if added to gas)

# Define products
model.reactions.get_by_id("EX_ch4_e").bounds = (ch4-ch4*error,ch4+ch4*error)
model.reactions.get_by_id("EX_biomass_e").bounds = (bm,bm)#(bm-bm*error,bm+bm*error)

# %%
solution = model.optimize()
print(solution)
# Out:
# <Solution 0.047 at 0x11339b9f3c8>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_biomass_e = 0.047</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2dglc_e</td>
#       <td>EX_2dglc_e</td>
#       <td>6.354E-05</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.0002932</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>33.49</td>
#       <td>1</td>
#       <td>99.87%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0002068</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys__L_e</td>
#       <td>EX_cys__L_e</td>
#       <td>0.0145</td>
#       <td>3</td>
#       <td>0.13%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.0002234</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2_e</td>
#       <td>EX_h2_e</td>
#       <td>130</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.0003005</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.0004834</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e</td>
#       <td>8.705E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh3_e</td>
#       <td>EX_nh3_e</td>
#       <td>0.5188</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e</td>
#       <td>0.0001037</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.03679</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>tungs_e</td>
#       <td>EX_tungs_e</td>
#       <td>4.742E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0001796</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>acald_e</td>
#       <td>EX_acald_e</td>
#       <td>-7.487E-06</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>amob_e</td>
#       <td>EX_amob_e</td>
#       <td>-4.831E-05</td>
#       <td>15</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>biomass_e</td>
#       <td>EX_biomass_e</td>
#       <td>-0.047</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ch4_e</td>
#       <td>EX_ch4_e</td>
#       <td>-31.45</td>
#       <td>1</td>
#       <td>99.76%</td>
#     </tr>
#     <tr>
#       <td>dad_5_e</td>
#       <td>EX_dad_5_e</td>
#       <td>-0.000331</td>
#       <td>10</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>dhgly_e</td>
#       <td>EX_dhgly_e</td>
#       <td>-7.779E-05</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>gcald_e</td>
#       <td>EX_gcald_e</td>
#       <td>-1.519E-05</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glyc__R_e</td>
#       <td>EX_glyc__R_e</td>
#       <td>-4.831E-05</td>
#       <td>3</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-65.99</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2s_e</td>
#       <td>EX_h2s_e</td>
#       <td>-0.0009908</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.5089</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hpp_e</td>
#       <td>EX_hpp_e</td>
#       <td>-0.02348</td>
#       <td>3</td>
#       <td>0.22%</td>
#     </tr>
#     <tr>
#       <td>nac_e</td>
#       <td>EX_nac_e</td>
#       <td>-7.487E-06</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ncam_e</td>
#       <td>EX_ncam_e</td>
#       <td>-2.775E-05</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>urea_e</td>
#       <td>EX_urea_e</td>
#       <td>-0.0001543</td>
#       <td>1</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
solution = solution.to_frame()
solution
# Out:
#                     fluxes  reduced_costs
# MVHHDR        3.152981e+01            0.0
# FRH           0.000000e+00            0.0
# HMD           6.515792e+01            0.0
# FTRM          3.217148e+01            0.0
# FWD           3.217148e+01            0.0
# MCH           3.217148e+01            0.0
# MTD          -3.298644e+01           -0.0
# MER           3.223226e+01            0.0
# MTR           3.145195e+01            0.0
# MCR           3.145195e+01            0.0
# NAt3_1       -4.371474e-01           -0.0
# NAATP         1.452460e+01            0.0
# CBPS          2.199233e-02            0.0
# MoaA          4.352670e-05            0.0
# MoaC          4.352670e-05            0.0
# MoaE          4.352670e-05            0.0
# MPTAT         1.357830e-05            0.0
# MoeAB         1.357830e-05            0.0
# MobAB         1.357830e-05            0.0
# GLUTRS        2.676744e-04            0.0
# GLUTRR        2.676744e-04            0.0
# G1SAT         2.676744e-04            0.0
# PPBNGS        1.338372e-04            0.0
# HMBS          3.345930e-05            0.0
# UPP3S         3.345930e-05            0.0
# UPP3MT        3.345930e-05            0.0
# SHCHD2        3.345930e-05            0.0
# SHCHF         1.294380e-05            0.0
# CFBA          1.302840e-05            0.0
# CFBB          1.302840e-05            0.0
# CFBDC         1.302840e-05            0.0
# F430S         1.302840e-05            0.0
# CbiX          7.487100e-06            0.0
# CbiL          7.487100e-06            0.0
# CPC3MT        7.487100e-06            0.0
# CODSCL4MT     7.487100e-06            0.0
# CODSCL5DA     7.487100e-06            0.0
# CODSCL5BMT    7.487100e-06            0.0
# CPC6R         7.487100e-06            0.0
# CODSCL6BMT2   7.487100e-06            0.0
# CODSCL7MTDC2  7.487100e-06            0.0
# CODSCL8XI     7.487100e-06            0.0
# CYRDAS        7.487100e-06            0.0
# CYRDAR        3.743550e-06            0.0
# CYRDAAT       7.487100e-06            0.0
# ADCYRS        7.487100e-06            0.0
# CobD          7.487100e-06            0.0
# ADCPS2        7.487100e-06            0.0
# ACBIPGT       7.487100e-06            0.0
# bzaAB         7.487100e-06            0.0
# NN5HBPRT      7.487100e-06            0.0
# RZ5PP2_2      7.487100e-06            0.0
# ADOCBLS2_2    7.487100e-06            0.0
# FCLPA         0.000000e+00           -0.0
# LALDO3        7.778970e-05            0.0
# LCADi         7.778970e-05            0.0
# 2PLS          7.778970e-05            0.0
# LPPGS         7.778970e-05            0.0
# CofGH         7.778970e-05            0.0
# LPFPLT        7.778970e-05            0.0
# GF4GL_0       5.486310e-05            0.0
# GF4GL_1       3.650490e-05            0.0
# GTPCIII2      1.500381e-04            0.0
# ArfB          1.500381e-04            0.0
# DROPPRx       1.500381e-04            0.0
# DRTPPD        1.500381e-04            0.0
# PMDPHT        1.500381e-04            0.0
# DB4PS         1.444968e-04            0.0
# RBFSa         1.444968e-04            0.0
# RBFSb         7.224840e-05            0.0
# RBFLVK        4.094640e-05            0.0
# FMNAT         1.501650e-05            0.0
# MfnA          1.577790e-05            0.0
# MfnD          1.577790e-05            0.0
# FPAS          1.577790e-05            0.0
# FPAT          1.577790e-05            0.0
# MfnE          1.577790e-05            0.0
# MfnF          1.577790e-05            0.0
# HTCAF         1.577790e-05            0.0
# FMfr          1.577790e-05            0.0
# MptA          1.518570e-05            0.0
# MptB          0.000000e+00            0.0
# MptB2         1.518570e-05            0.0
# DHNP3F        0.000000e+00           -0.0
# DHNP2F        1.518570e-05            0.0
# DHNPA2r       1.518570e-05            0.0
# HPPK2         1.518570e-05            0.0
# BRFAPS        0.000000e+00            0.0
# BRAHPS        1.518570e-05            0.0
# BRFSAPS       1.518570e-05            0.0
# BRFAPS2       1.518570e-05            0.0
# dhrfapF       0.000000e+00            0.0
# dhadrpF       0.000000e+00            0.0
# dhadrF        0.000000e+00            0.0
# DHPS3         1.518570e-05            0.0
# H4MPTS9       1.518570e-05            0.0
# dhadrF2       1.518570e-05            0.0
# dhadrprF      1.518570e-05            0.0
# dhadrdprF     1.518570e-05            0.0
# AHGDx        -1.518570e-05           -0.0
# h2mpt         1.518570e-05            0.0
# H2MPTR        1.518570e-05            0.0
# PSLS          8.320410e-05            0.0
# PSLP          8.320410e-05            0.0
# SLDx          8.320410e-05            0.0
# SPDC          8.320410e-05            0.0
# CoMF          8.320410e-05            0.0
# HCITS         8.282340e-05            0.0
# SHCD2         8.282340e-05            0.0
# CHACH2        8.282340e-05            0.0
# HICITD        8.282340e-05            0.0
# AKACAL2       8.282340e-05            0.0
# RH2CD         8.282340e-05            0.0
# CH2ACH        8.282340e-05            0.0
# TIH2CD        8.282340e-05            0.0
# AKPCAL        8.282340e-05            0.0
# RH3CD         8.282340e-05            0.0
# CH3ACH        8.282340e-05            0.0
# TIH3CD        8.282340e-05            0.0
# AKSDC         3.451680e-05            0.0
# 7MHS          3.451680e-05            0.0
# 7MHTS         3.451680e-05            0.0
# COBS          3.451680e-05            0.0
# CYSDES        0.000000e+00           -0.0
# CF3Sa         0.000000e+00            0.0
# CF3Sg         1.053270e-05            0.0
# CF3Ha        -1.070190e-05           -0.0
# CF3Hg         0.000000e+00            0.0
# MOHMT2        1.539720e-05            0.0
# DRP2          1.539720e-05            0.0
# PoK           1.539720e-05            0.0
# ASP1DC        1.539720e-05            0.0
# PPSL          1.539720e-05            0.0
# PPNCL2        1.539720e-05            0.0
# PPCDC         1.539720e-05            0.0
# PTPATi        1.539720e-05            0.0
# DPCOAK        1.539720e-05            0.0
# ACS           0.000000e+00            0.0
# CODH2         7.713844e-01            0.0
# ACS3          7.714122e-01            0.0
# CODHr2        0.000000e+00            0.0
# POR2          6.730444e-01            0.0
# PC            0.000000e+00            0.0
# MDH           5.438713e-02            0.0
# MDHy          0.000000e+00            0.0
# FUM           5.438713e-02            0.0
# FRD           7.786010e-02            0.0
# SUCOAS        7.786010e-02            0.0
# PPS           3.970292e-01            0.0
# PPC           1.884526e-01            0.0
# OOR3r         7.786010e-02            0.0
# FDHf420       2.273644e-02            0.0
# ENO           1.850114e-01            0.0
# PGM           1.850114e-01            0.0
# PGK           1.288991e-01            0.0
# GAPDP         1.288991e-01            0.0
# DRPA          0.000000e+00           -0.0
# TPI           6.658431e-02            0.0
# FBA           6.500682e-02            0.0
# FBP           4.152478e-02            0.0
# PGI          -1.394302e-03           -0.0
# PGMT          1.339312e-03            0.0
# GALUi         1.339312e-03            0.0
# 2PGK          0.000000e+00            0.0
# CDPGS         0.000000e+00            0.0
# CDPGH         0.000000e+00            0.0
# DPGase        0.000000e+00           -0.0
# ACLS          5.059943e-02            0.0
# KARA1_2       5.059943e-02            0.0
# KARA2_2       5.059943e-02            0.0
# DHAD1         5.059943e-02            0.0
# VALTA         2.329207e-02            0.0
# VOR           0.000000e+00           -0.0
# IPPS          2.729196e-02            0.0
# IPPMIb        2.729196e-02            0.0
# IPPMIa        2.729196e-02            0.0
# IPMD          2.729196e-02            0.0
# OMCDC         2.729196e-02            0.0
# LEUTA         2.729196e-02            0.0
# CITMS         1.817885e-02            0.0
# CITCIa        1.817885e-02            0.0
# CITCIb        1.817885e-02            0.0
# M3MOR         1.817885e-02            0.0
# ACHBS         1.817885e-02            0.0
# KARA2         1.817885e-02            0.0
# DHAD2         1.817885e-02            0.0
# ILETA         1.817885e-02            0.0
# ACS2          0.000000e+00            0.0
# POR3          0.000000e+00           -0.0
# ppa_T         0.000000e+00           -0.0
# ASPTA         1.339630e-01            0.0
# ASNS1         1.411128e-02            0.0
# ASPK          7.560142e-02            0.0
# ASAD          7.560142e-02            0.0
# H4THDPS       2.831167e-02            0.0
# H4THDPR       0.000000e+00            0.0
# H4THDPR2      2.831167e-02            0.0
# LDAPAT        2.831167e-02            0.0
# DAPE          2.831167e-02            0.0
# DAPDC         2.831167e-02            0.0
# THDPS         0.000000e+00            0.0
# GLNS          9.486187e-02            0.0
# ACGS          0.000000e+00            0.0
# ACGK          2.856972e-02            0.0
# AGPR          2.856972e-02            0.0
# ACOTA         2.856972e-02            0.0
# ORNTAC        2.856972e-02            0.0
# OCBT          1.609968e-02            0.0
# ARGSS         1.609968e-02            0.0
# ARGSL         1.609968e-02            0.0
# ARGDC         1.542681e-04            0.0
# AGMT          1.542681e-04            0.0
# ORNCD         1.247004e-02            0.0
# RBK           0.000000e+00            0.0
# DRBK          0.000000e+00            0.0
# AH6PI         2.295781e-02            0.0
# HPS           2.295781e-02            0.0
# RPI           2.276539e-02            0.0
# PRPPS         2.276539e-02            0.0
# ATPPRT        6.497280e-03            0.0
# PRATPP        6.497280e-03            0.0
# PRAMPC        6.497280e-03            0.0
# PRMICI        6.497280e-03            0.0
# IG3PS         6.497280e-03            0.0
# IGPDH         6.497280e-03            0.0
# HSTPT         6.497280e-03            0.0
# HISTP         6.497280e-03            0.0
# HISTDa        0.000000e+00            0.0
# HISTDb        0.000000e+00            0.0
# HISTD         6.497280e-03            0.0
# PGCD          5.611230e-02            0.0
# PSERT         5.611230e-02            0.0
# PSP_L         5.611230e-02            0.0
# SHMT          3.783649e-02            0.0
# ALAD_L       -7.455779e-02           -0.0
# SEPRS         0.000000e+00            0.0
# CYSS          0.000000e+00           -0.0
# CYSTRF        0.000000e+00           -0.0
# HSDxi         1.552042e-02            0.0
# HSDy          0.000000e+00            0.0
# HSERTA        0.000000e+00            0.0
# AHSERL2       0.000000e+00            0.0
# HSK           1.552042e-02            0.0
# THRS          1.552042e-02            0.0
# SUA5          0.000000e+00            0.0
# TCADES        0.000000e+00            0.0
# HcysS         8.287289e-03            0.0
# CoMetS        8.429502e-03            0.0
# METAT         5.508729e-04            0.0
# ACHi          1.422126e-04            0.0
# SIHF          0.000000e+00           -0.0
# SIHH          0.000000e+00            0.0
# MTIS          0.000000e+00            0.0
# MTIP          0.000000e+00           -0.0
# MTRI          0.000000e+00           -0.0
# MGS           2.355983e-02            0.0
# E2M           2.355983e-02            0.0
# DKFPS2        2.348204e-02            0.0
# ADHS          2.348204e-02            0.0
# DHQS2         2.348204e-02            0.0
# DHQTi         2.348204e-02            0.0
# SHK3Dr        2.348204e-02            0.0
# SHKK          2.348204e-02            0.0
# PSCVT         2.348204e-02            0.0
# CHORS         2.348204e-02            0.0
# CHRPL         1.518570e-05            0.0
# PHETA1        1.147514e-02            0.0
# PPNDH         1.147514e-02            0.0
# IOR2          0.000000e+00           -0.0
# PACCOAL       0.000000e+00            0.0
# IOR3          0.000000e+00           -0.0
# PACCOAL2      0.000000e+00            0.0
# TYRTA         9.142384e-03            0.0
# PPND          9.142384e-03            0.0
# CHORM         2.061753e-02            0.0
# ANS2          0.000000e+00            0.0
# ANS           2.849328e-03            0.0
# ANPRT         2.849328e-03            0.0
# PRAIi         2.849328e-03            0.0
# IGPS          2.849328e-03            0.0
# TRPS3         2.849328e-03            0.0
# TRPS2         2.849328e-03            0.0
# IOR           0.000000e+00           -0.0
# TRPTA         0.000000e+00           -0.0
# PACCOAL3      0.000000e+00            0.0
# ALATA_L      -3.821948e-02           -0.0
# GLUSfx        0.000000e+00            0.0
# GLUS_F420     0.000000e+00            0.0
# PPA           1.094243e-01            0.0
# PPA2          7.487100e-06            0.0
# MI1PS         5.499000e-05            0.0
# MI1PP         0.000000e+00           -0.0
# UDPG4E        0.000000e+00           -0.0
# UDPGALM       0.000000e+00           -0.0
# HCO3E         2.935044e-02            0.0
# SPODM         0.000000e+00            0.0
# CYSDS        -4.590502e-01           -0.0
# HAMR2         0.000000e+00            0.0
# CYANST        0.000000e+00           -0.0
# CYSTA         3.823612e-01            0.0
# MCPST2        3.823612e-01            0.0
# FAE           2.295781e-02            0.0
# PPM           0.000000e+00           -0.0
# GLUPRT        7.393344e-03            0.0
# PPRGL         7.393344e-03            0.0
# GART          7.393344e-03            0.0
# PRFGS         7.393344e-03            0.0
# PRAIS         7.393344e-03            0.0
# AIRC2         7.358109e-03            0.0
# AIRC3         7.358109e-03            0.0
# PRASCSi       7.358109e-03            0.0
# ADSL2r        7.358109e-03            0.0
# AICART2       1.385539e-02            0.0
# IMPC          1.385539e-02            0.0
# NTD11         0.000000e+00            0.0
# INSK          0.000000e+00            0.0
# IMPD          3.868448e-03            0.0
# GMPS2         3.868448e-03            0.0
# NTD9          0.000000e+00            0.0
# NTD7         -1.422126e-04           -0.0
# NTD10         0.000000e+00           -0.0
# GSNK          0.000000e+00            0.0
# GUAPRT        0.000000e+00           -0.0
# GK1           3.953725e-03            0.0
# HXPRT        -9.986941e-03           -0.0
# ADD          -9.986941e-03           -0.0
# ADPT          9.986941e-03            0.0
# ADSS          0.000000e+00            0.0
# ADSL1r        0.000000e+00            0.0
# ADK1          4.644421e-01            0.0
# NTP1          0.000000e+00            0.0
# NTP2          0.000000e+00            0.0
# NTP3          0.000000e+00            0.0
# NTP4          0.000000e+00            0.0
# NTP5          0.000000e+00            0.0
# NTP6          0.000000e+00            0.0
# NTP7          0.000000e+00            0.0
# NTP8          0.000000e+00            0.0
# NTP9          0.000000e+00            0.0
# NDPK1         4.122882e-03            0.0
# XTPASE        0.000000e+00           -0.0
# NTPP10        0.000000e+00           -0.0
# ITPASE2       0.000000e+00            0.0
# NDPK5         0.000000e+00            0.0
# RNDR2         0.000000e+00            0.0
# ARTRADP       4.705452e-04            0.0
# NDPK8         0.000000e+00            0.0
# RNDR1         0.000000e+00            0.0
# PFL           0.000000e+00            0.0
# PFL2          0.000000e+00            0.0
# ADNCYC        0.000000e+00            0.0
# PDE1          0.000000e+00           -0.0
# NDPK9         0.000000e+00            0.0
# NDPK10        0.000000e+00            0.0
# ADPRDP        0.000000e+00           -0.0
# ARTRGDP       4.457856e-04            0.0
# ASPCT         5.892653e-03            0.0
# DHORTS        5.892653e-03            0.0
# DHORD72       5.892653e-03            0.0
# ORPT          5.892653e-03            0.0
# OMPDC         5.892653e-03            0.0
# NTD2          0.000000e+00           -0.0
# UPPRT         0.000000e+00           -0.0
# UMPK          5.892653e-03            0.0
# NDPK2         2.446818e-02            0.0
# CTPS2         0.000000e+00            0.0
# CTPS1         0.000000e+00            0.0
# DCTPD2       -2.361900e-03           -0.0
# NDPK3         1.531175e-03            0.0
# THEP1         0.000000e+00            0.0
# CYTK1         2.461108e-04            0.0
# NTD4          0.000000e+00           -0.0
# CYTDK1        0.000000e+00            0.0
# ARTRCTP       0.000000e+00            0.0
# ARTRUTP       9.163308e-04            0.0
# DCTPD        -4.457856e-04           -0.0
# DCTPD3        0.000000e+00            0.0
# DUTPDP        4.705452e-04            0.0
# RNDR3         0.000000e+00            0.0
# NDPK7         0.000000e+00            0.0
# CYTK2         0.000000e+00            0.0
# NTD3          0.000000e+00           -0.0
# NTD1          0.000000e+00            0.0
# NTD5          0.000000e+00            0.0
# NTD8          0.000000e+00           -0.0
# NTD6          0.000000e+00           -0.0
# RNDR4         0.000000e+00            0.0
# NDPK6         0.000000e+00            0.0
# NDPK4         4.705452e-04            0.0
# TMDS          0.000000e+00           -0.0
# TMDS2         4.705452e-04            0.0
# URIDK2r       0.000000e+00            0.0
# DTMPK         4.705452e-04            0.0
# F420SR       -8.320410e-05           -0.0
# F4H2O         0.000000e+00            0.0
# F4NPR         7.316579e-01            0.0
# FISC          0.000000e+00           -0.0
# THIORDXi      0.000000e+00           -0.0
# ACACT1r       1.179865e-02            0.0
# HMGCOAS       1.179865e-02            0.0
# HMGCOAR       1.179865e-02            0.0
# MEVK1         1.179865e-02            0.0
# PMD           1.179865e-02            0.0
# IPK           1.179865e-02            0.0
# IPDDI         2.949664e-03            0.0
# DMATT         2.949664e-03            0.0
# GRTT          2.949664e-03            0.0
# FRTT          2.949664e-03            0.0
# TTHCUPD       0.000000e+00            0.0
# G3PD2         0.000000e+00           -0.0
# G1PDH         1.475076e-03            0.0
# G1PDH2        0.000000e+00            0.0
# GGGPS         1.474832e-03            0.0
# DGGGPS        1.474832e-03            0.0
# CDGGGS        1.474832e-03            0.0
# CDGGGSAT      1.754792e-04            0.0
# ATSH2         2.688400e-05            0.0
# AtdenS        1.485952e-04            0.0
# AtdensS       1.485952e-04            0.0
# CDGGIPT3      5.499000e-05            0.0
# AIS           5.499000e-05            0.0
# ATIH2         5.499000e-05            0.0
# CDGGGPP3      2.444000e-07            0.0
# DGGPGP        2.444000e-07            0.0
# ATGH2         2.444000e-07            0.0
# SATARFr       1.244118e-03            0.0
# ARS           1.244118e-03            0.0
# MGAS          8.595548e-04            0.0
# DGAS          4.797572e-04            0.0
# DOGAS         6.354400e-05            0.0
# FUDPDGLC      6.354400e-05            0.0
# CARS          4.289220e-05            0.0
# GCARS         3.592680e-05            0.0
# 2GCARS        3.336060e-05            0.0
# PECARS        5.584540e-05            0.0
# 2PECARS       7.576400e-06            0.0
# PICARS        2.285140e-05            0.0
# 2GPICARS      2.847260e-05            0.0
# GPECARS       2.065180e-05            0.0
# 2GPECARS      3.067220e-05            0.0
# GGDPR         0.000000e+00            0.0
# PHYTES        0.000000e+00            0.0
# PHYTES2       0.000000e+00            0.0
# PYDXS         4.792590e-05            0.0
# GF6PTA        1.717267e-02            0.0
# PGAMT         1.717267e-02            0.0
# G1PACT        1.717267e-02            0.0
# UAGDP         1.717267e-02            0.0
# UAG2E         0.000000e+00           -0.0
# UACMAMO       0.000000e+00           -0.0
# G1PTT         0.000000e+00           -0.0
# TDPGDH        0.000000e+00            0.0
# TDPDRE        0.000000e+00           -0.0
# TDPDRR        0.000000e+00           -0.0
# MAN6PI        0.000000e+00            0.0
# PMANM         0.000000e+00            0.0
# MAN1PT2       0.000000e+00            0.0
# MAN1PT        0.000000e+00            0.0
# GMAND         0.000000e+00           -0.0
# TRE6PS        0.000000e+00           -0.0
# TRE6PP        0.000000e+00           -0.0
# ASPO2         0.000000e+00            0.0
# ASPO2y        0.000000e+00            0.0
# OAAS         -1.024083e-04           -0.0
# QULNS         1.024083e-04            0.0
# NNDPR         1.024083e-04            0.0
# NNATr         9.492120e-05            0.0
# NADS1         9.492120e-05            0.0
# NADK          3.172500e-05            0.0
# NADK6         0.000000e+00            0.0
# NADK7         0.000000e+00            0.0
# NADK1         0.000000e+00            0.0
# NADK2         0.000000e+00            0.0
# NICRNSS       0.000000e+00           -0.0
# NMNAT         0.000000e+00           -0.0
# NMNHYD        0.000000e+00            0.0
# TRDR          3.823612e-01            0.0
# NADHHR        0.000000e+00            0.0
# NADPHHR       0.000000e+00           -0.0
# NADHXE        0.000000e+00           -0.0
# NADPHXE       0.000000e+00            0.0
# NADHXD        0.000000e+00            0.0
# NADPHXD       0.000000e+00            0.0
# UAG4Ei        1.717267e-02            0.0
# ACGALS        8.586336e-03            0.0
# ACALTROS      8.586336e-03            0.0
# NACTALS       8.586336e-03            0.0
# UACNACS       0.000000e+00            0.0
# PSMNS         0.000000e+00            0.0
# UGALNACS      8.586336e-03            0.0
# PSMNS2        4.293168e-03            0.0
# NIT1b2        0.000000e+00            0.0
# AKSCAL        4.830660e-05            0.0
# AOXSr         4.830660e-05            0.0
# AMAOTr        4.830660e-05            0.0
# DBTS          4.830660e-05            0.0
# BTSMT         4.830660e-05            0.0
# BACCL         0.000000e+00            0.0
# ThiC          2.774880e-05            0.0
# HMPK1         0.000000e+00            0.0
# PMPK          2.774880e-05            0.0
# AHZS          2.774880e-05            0.0
# 4MPETZS       2.774880e-05            0.0
# TMPPP         2.774880e-05            0.0
# TMPK          2.774880e-05            0.0
# PGLYCP        0.000000e+00           -0.0
# GTPCI         0.000000e+00            0.0
# CPH4S         0.000000e+00           -0.0
# CDGS          0.000000e+00           -0.0
# CCGS          0.000000e+00            0.0
# SUMQ1         0.000000e+00           -0.0
# NIabc         1.036773e-04            0.0
# Coabc         2.068470e-04            0.0
# FeoAB         0.000000e+00            0.0
# FE2abc        2.233863e-04            0.0
# ZNabc         1.796481e-04            0.0
# ZNabc2        0.000000e+00            0.0
# MGt5          4.834467e-04            0.0
# MG2abc        0.000000e+00            0.0
# CA2abc        2.931813e-04            0.0
# TrkAH         3.005415e-04            0.0
# MOBDabc       8.705340e-05            0.0
# WO4abc        4.741830e-05            0.0
# PIabc         3.679107e-02            0.0
# Eha           2.184186e+00            0.0
# Ehb           0.000000e+00            0.0
# CO2t          3.374790e+01            0.0
# CH4t          3.145195e+01            0.0
# tH2           1.304012e+02            0.0
# tBTN          0.000000e+00           -0.0
# t2DGLC        6.354400e-05            0.0
# N2tr          0.000000e+00            0.0
# PROt4         0.000000e+00           -0.0
# Cuabc         0.000000e+00            0.0
# Cut1          0.000000e+00            0.0
# CD2abc1       0.000000e+00            0.0
# CD2abc2       0.000000e+00            0.0
# NH3te         6.051406e-01            0.0
# CYSt2r       -7.179658e-02           -0.0
# H2Ot         -6.633779e+01           -0.0
# H2St1        -8.530580e-02           -0.0
# COt           0.000000e+00            0.0
# PACt2r        0.000000e+00            0.0
# HPACt2r       0.000000e+00            0.0
# IND3ACt2r     0.000000e+00            0.0
# ACt2r         0.000000e+00           -0.0
# 5AOPt2        0.000000e+00           -0.0
# PYRt          0.000000e+00           -0.0
# FUMtr         0.000000e+00           -0.0
# SUCCt         0.000000e+00           -0.0
# 4ABZt2r       0.000000e+00            0.0
# GLYC_Rt       4.830660e-05            0.0
# HPPt          2.348204e-02            0.0
# NCAMt         2.774880e-05            0.0
# UREAt         1.542681e-04            0.0
# NACt          7.487100e-06            0.0
# GCALDt        1.518570e-05            0.0
# DHGLYt        7.778970e-05            0.0
# AMOBt         4.830660e-05            0.0
# ACALDt        7.487100e-06            0.0
# DAD5t         3.309552e-04            0.0
# PROTRS        0.000000e+00            0.0
# ATPM          1.156716e+01            0.0
# PROTEIN_MM    3.384000e-02            0.0
# DNA_MM        5.640000e-04            0.0
# RNA_MM        3.431000e-03            0.0
# SMP_MM        4.230000e-04            0.0
# LIPID_MM      1.222000e-03            0.0
# CELLWALL_MM   7.520000e-03            0.0
# BIOMASS_MM    4.700000e-02            0.0
# BIOMASSt_MM   4.700000e-02            0.0
# FDH_F420      0.000000e+00            0.0
# FORt          0.000000e+00           -0.0
# EX_hpp_e      2.348204e-02            0.0
# EX_dhgly_e    7.778970e-05            0.0
# EX_acald_e    7.487100e-06            0.0
# EX_nac_e      7.487100e-06            0.0
# EX_gcald_e    1.518570e-05            0.0
# EX_urea_e     1.542681e-04            0.0
# EX_amob_e     4.830660e-05            0.0
# EX_biomass_e  4.700000e-02            2.0
# EX_ncam_e     2.774880e-05            0.0
# EX_co2_e     -3.374790e+01           -0.0
# EX_ch4_e      3.145195e+01           -0.0
# EX_h2_e      -1.304012e+02           -0.0
# EX_ni2_e     -1.036773e-04           -0.0
# EX_cobalt2_e -2.068470e-04           -0.0
# EX_fe2_e     -2.233863e-04           -0.0
# EX_zn2_e     -1.796481e-04           -0.0
# EX_mg2_e     -4.834467e-04           -0.0
# EX_ca2_e     -2.931813e-04           -0.0
# EX_k_e       -3.005415e-04           -0.0
# EX_mobd_e    -8.705340e-05           -0.0
# EX_tungs_e   -4.741830e-05           -0.0
# EX_na1_e      0.000000e+00           -0.0
# EX_pi_e      -3.679107e-02           -0.0
# EX_h_e        5.089440e-01            0.0
# EX_ppa_e      0.000000e+00           -0.0
# EX_btn_e      0.000000e+00           -0.0
# EX_2dglc_e   -6.354400e-05           -0.0
# EX_n2_e       0.000000e+00           -0.0
# EX_cys__L_e   7.179658e-02            0.0
# EX_h2o_e      6.633779e+01            0.0
# EX_glyc__R_e  4.830660e-05            0.0
# EX_nh3_e     -6.051406e-01           -0.0
# EX_for_e      0.000000e+00           -0.0
# EX_ac_e       0.000000e+00           -0.0
# EX_5aop_e     0.000000e+00           -0.0
# EX_pyr_e      0.000000e+00           -0.0
# EX_succ_e     0.000000e+00           -0.0
# EX_co_e       0.000000e+00           -0.0
# EX_h2s_e     -8.530580e-02           -0.0
# EX_pac_e      0.000000e+00           -0.0
# EX_4hphac_e   0.000000e+00           -0.0
# EX_ind3ac_e   0.000000e+00           -0.0
# EX_4abz_e     0.000000e+00           -0.0
# EX_fum_e      0.000000e+00           -0.0
# EX_pro__L_e   0.000000e+00           -0.0
# EX_dad_5_e    3.309552e-04            0.0

# %%
# Write out experimentally constrained model (matlab) to be used with in GIMME in the COBRA Toolbox
# cobra.io.save_matlab_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_DH_model_bound_adjval.mat")
# cobra.io.write_sbml_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_DH_model_bound_adjval.xml")
# cobra.io.save_json_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_DH_model_bound_adjval.json")

# cobra.io.save_matlab_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_ZZ_model_bound_adjval.mat")
# cobra.io.write_sbml_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_ZZ_model_bound_adjval.xml")
# cobra.io.save_json_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_ZZ_model_bound_adjval.json")

# cobra.io.save_matlab_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_MM_model_bound_adjval.mat")
# cobra.io.write_sbml_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_MM_model_bound_adjval.xml")
# cobra.io.save_json_model(model, r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA6\20220623_MM_model_bound_adjval.json")

# %% [markdown]
# ## Display in Map

# %%
path = r"F:\GEM_Models\Final_Model"
mapnormal = makeMap(path,"DH_map_final_final.json",model,solution)
# mapnormal = makeMap(path,"ZZ_map_final_final.json",model,solution)
# mapnormal = makeMap(path,"MM_map_final_final.json",model,solution)

mapnormal.display_in_browser()#notebook()#browser()

# %% [markdown]
# ## Export to Text File

# %%
with open(r"F:\Experimental_Work\Reactors_Ley\F6_Exp2\FBA4\FBA_DH_Bio.txt", "w") as outfile:
    outfile.write(str(solution))
    outfile.close()

# %% [markdown]
# # Part 2.5 pFBA with Experimental Data

# %%
# Define objective function
obj = {model.reactions.get_by_id("EX_biomass_e"):1}
# obj = {model.reactions.get_by_id("ATPM"):1}
model.objective = obj

# %%
solutionpfba = pfba(model)
solutionpfba = solutionpfba.to_frame()
solutionpfba

# %% [markdown]
# ## Display in Map

# %%
path = r"F:\GEM_Models\Final_Model"
mapnormal = makeMap(path,"DH_map_final_final.json",model,solutionpfba)
# mapnormal = makeMap(path,"ZZ_map_final_final.json",model,solution)
# mapnormal = makeMap(path,"MM_map_final_final.json",model,solution)

mapnormal.display_in_browser()#notebook()#browser()

# %% [markdown]
# ## Export to Text File

# %%
# with open(r"C:\Users\Isabella\Downloads\pFBA_20211220.txt", "w") as outfile:
#     outfile.write(str(solutionpfba))
#     outfile.close()
